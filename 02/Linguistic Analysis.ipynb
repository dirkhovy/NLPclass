# %% [markdown]
# # Linguistic Analysis
#
# Let's look at the different levels of linguistic analysis. First, we need some text. Let's take *Moby Dick* from Project Gutenberg, as a list of strings:

# %%
documents = [line.strip() for line in open('../data/moby_dick.txt', encoding='utf8').readlines()]
print(documents[1])
# Out:
# Call me Ishmael .

# %% [markdown]
# We will use the `spacy` library for a lot of the analyses. Here, we load it:

# %%
import spacy

nlp = spacy.load('en')

# %% [markdown]
# ### Usage:
#
# We can now call `nlp()` as a function on any text. By default, it will perform a number of analyses:
# - tokenization
# - sentence splitting
# - lemmatization
# - part of speech tagging
# - dependency parsing
# - named entity recognition
#
# To speed up analysis, we can disable some of these analyses if we do not need it:
# ```
# nlp = spacy.load('en', disable=['tokenizer', 'tagger', 'parser', 'ner'])
# ```

# %% [markdown]
# The result is an iterator over the sentences (if called on a text), or tokens (if called on a sentence). Each token has a range of properties see [here](https://spacy.io/api/token#attributes). We will use a few of them in the following:
#
# - `text`: the actual word
# - `lemma_`: the dictionary entry of a word
# - `pos_`: the part of speech
# - `dep`: dependency relation
# - `is_punct`: check whether word is punctuation
# - `is_stop`: check whether word is a stop word

# %% [markdown]
# ## Tokenization
# Before we do anything, we need to insert spaces into the data.

# %%
tokens = [[token.text for token in nlp(sentence)] for sentence in documents[:100]]
tokens
# Out:
# [['Loomings', '.'],
#  ['Call', 'me', 'Ishmael', '.'],
#  ['Some',
#   'years',
#   'ago',
#   '--',
#   'never',
#   'mind',
#   'how',
#   'long',
#   'precisely',
#   '--',
#   'having',
#   'little',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purse',
#   ',',
#   'and',
#   'nothing',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   ',',
#   'I',
#   'thought',
#   'I',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'little',
#   'and',
#   'see',
#   'the',
#   'watery',
#   'part',
#   'of',
#   'the',
#   'world',
#   '.'],
#  ['It',
#   'is',
#   'a',
#   'way',
#   'I',
#   'have',
#   'of',
#   'driving',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regulating',
#   'the',
#   'circulation',
#   '.'],
#  ['Whenever',
#   'I',
#   'find',
#   'myself',
#   'growing',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   ';',
#   'whenever',
#   'it',
#   'is',
#   'a',
#   'damp',
#   ',',
#   'drizzly',
#   'November',
#   'in',
#   'my',
#   'soul',
#   ';',
#   'whenever',
#   'I',
#   'find',
#   'myself',
#   'involuntarily',
#   'pausing',
#   'before',
#   'coffin',
#   'warehouses',
#   ',',
#   'and',
#   'bringing',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'every',
#   'funeral',
#   'I',
#   'meet',
#   ';',
#   'and',
#   'especially',
#   'whenever',
#   'my',
#   'hypos',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   ',',
#   'that',
#   'it',
#   'requires',
#   'a',
#   'strong',
#   'moral',
#   'principle',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliberately',
#   'stepping',
#   'into',
#   'the',
#   'street',
#   ',',
#   'and',
#   'methodically',
#   'knocking',
#   'people',
#   "'",
#   's',
#   'hats',
#   'off',
#   '--',
#   'then',
#   ',',
#   'I',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'I',
#   'can',
#   '.'],
#  ['This', 'is', 'my', 'substitute', 'for', 'pistol', 'and', 'ball', '.'],
#  ['With',
#   'a',
#   'philosophical',
#   'flourish',
#   'Cato',
#   'throws',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   ';',
#   'I',
#   'quietly',
#   'take',
#   'to',
#   'the',
#   'ship',
#   '.'],
#  ['There', 'is', 'nothing', 'surprising', 'in', 'this', '.'],
#  ['If',
#   'they',
#   'but',
#   'knew',
#   'it',
#   ',',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degree',
#   ',',
#   'some',
#   'time',
#   'or',
#   'other',
#   ',',
#   'cherish',
#   'very',
#   'nearly',
#   'the',
#   'same',
#   'feelings',
#   'towards',
#   'the',
#   'ocean',
#   'with',
#   'me',
#   '.'],
#  ['There',
#   'now',
#   'is',
#   'your',
#   'insular',
#   'city',
#   'of',
#   'the',
#   'Manhattoes',
#   ',',
#   'belted',
#   'round',
#   'by',
#   'wharves',
#   'as',
#   'Indian',
#   'isles',
#   'by',
#   'coral',
#   'reefs',
#   '--',
#   'commerce',
#   'surrounds',
#   'it',
#   'with',
#   'her',
#   'surf',
#   '.'],
#  ['Right',
#   'and',
#   'left',
#   ',',
#   'the',
#   'streets',
#   'take',
#   'you',
#   'waterward',
#   '.'],
#  ['Its',
#   'extreme',
#   'downtown',
#   'is',
#   'the',
#   'battery',
#   ',',
#   'where',
#   'that',
#   'noble',
#   'mole',
#   'is',
#   'washed',
#   'by',
#   'waves',
#   ',',
#   'and',
#   'cooled',
#   'by',
#   'breezes',
#   ',',
#   'which',
#   'a',
#   'few',
#   'hours',
#   'previous',
#   'were',
#   'out',
#   'of',
#   'sight',
#   'of',
#   'land',
#   '.'],
#  ['Look', 'at', 'the', 'crowds', 'of', 'water', '-', 'gazers', 'there', '.'],
#  ['Circumambulate',
#   'the',
#   'city',
#   'of',
#   'a',
#   'dreamy',
#   'Sabbath',
#   'afternoon',
#   '.'],
#  ['Go',
#   'from',
#   'Corlears',
#   'Hook',
#   'to',
#   'Coenties',
#   'Slip',
#   ',',
#   'and',
#   'from',
#   'thence',
#   ',',
#   'by',
#   'Whitehall',
#   ',',
#   'northward',
#   '.'],
#  ['What',
#   'do',
#   'you',
#   'see',
#   '?',
#   '--',
#   'Posted',
#   'like',
#   'silent',
#   'sentinels',
#   'all',
#   'around',
#   'the',
#   'town',
#   ',',
#   'stand',
#   'thousands',
#   'upon',
#   'thousands',
#   'of',
#   'mortal',
#   'men',
#   'fixed',
#   'in',
#   'ocean',
#   'reveries',
#   '.'],
#  ['Some',
#   'leaning',
#   'against',
#   'the',
#   'spiles',
#   ';',
#   'some',
#   'seated',
#   'upon',
#   'the',
#   'pier',
#   '-',
#   'heads',
#   ';',
#   'some',
#   'looking',
#   'over',
#   'the',
#   'bulwarks',
#   'of',
#   'ships',
#   'from',
#   'China',
#   ';',
#   'some',
#   'high',
#   'aloft',
#   'in',
#   'the',
#   'rigging',
#   ',',
#   'as',
#   'if',
#   'striving',
#   'to',
#   'get',
#   'a',
#   'still',
#   'better',
#   'seaward',
#   'peep',
#   '.'],
#  ['But',
#   'these',
#   'are',
#   'all',
#   'landsmen',
#   ';',
#   'of',
#   'week',
#   'days',
#   'pent',
#   'up',
#   'in',
#   'lath',
#   'and',
#   'plaster',
#   '--',
#   'tied',
#   'to',
#   'counters',
#   ',',
#   'nailed',
#   'to',
#   'benches',
#   ',',
#   'clinched',
#   'to',
#   'desks',
#   '.'],
#  ['How', 'then', 'is', 'this', '?'],
#  ['Are', 'the', 'green', 'fields', 'gone', '?'],
#  ['What', 'do', 'they', 'here', '?'],
#  ['But', 'look', '!'],
#  ['here',
#   'come',
#   'more',
#   'crowds',
#   ',',
#   'pacing',
#   'straight',
#   'for',
#   'the',
#   'water',
#   ',',
#   'and',
#   'seemingly',
#   'bound',
#   'for',
#   'a',
#   'dive',
#   '.'],
#  ['Strange', '!'],
#  ['Nothing',
#   'will',
#   'content',
#   'them',
#   'but',
#   'the',
#   'extremest',
#   'limit',
#   'of',
#   'the',
#   'land',
#   ';',
#   'loitering',
#   'under',
#   'the',
#   'shady',
#   'lee',
#   'of',
#   'yonder',
#   'warehouses',
#   'will',
#   'not',
#   'suffice',
#   '.'],
#  ['No', '.'],
#  ['They',
#   'must',
#   'get',
#   'just',
#   'as',
#   'nigh',
#   'the',
#   'water',
#   'as',
#   'they',
#   'possibly',
#   'can',
#   'without',
#   'falling',
#   'in',
#   '.'],
#  ['And',
#   'there',
#   'they',
#   'stand',
#   '--',
#   'miles',
#   'of',
#   'them',
#   '--',
#   'leagues',
#   '.'],
#  ['Inlanders',
#   'all',
#   ',',
#   'they',
#   'come',
#   'from',
#   'lanes',
#   'and',
#   'alleys',
#   ',',
#   'streets',
#   'and',
#   'avenues',
#   '--',
#   'north',
#   ',',
#   'east',
#   ',',
#   'south',
#   ',',
#   'and',
#   'west',
#   '.'],
#  ['Yet', 'here', 'they', 'all', 'unite', '.'],
#  ['Tell',
#   'me',
#   ',',
#   'does',
#   'the',
#   'magnetic',
#   'virtue',
#   'of',
#   'the',
#   'needles',
#   'of',
#   'the',
#   'compasses',
#   'of',
#   'all',
#   'those',
#   'ships',
#   'attract',
#   'them',
#   'thither',
#   '?'],
#  ['Once', 'more', '.'],
#  ['Say',
#   'you',
#   'are',
#   'in',
#   'the',
#   'country',
#   ';',
#   'in',
#   'some',
#   'high',
#   'land',
#   'of',
#   'lakes',
#   '.'],
#  ['Take',
#   'almost',
#   'any',
#   'path',
#   'you',
#   'please',
#   ',',
#   'and',
#   'ten',
#   'to',
#   'one',
#   'it',
#   'carries',
#   'you',
#   'down',
#   'in',
#   'a',
#   'dale',
#   ',',
#   'and',
#   'leaves',
#   'you',
#   'there',
#   'by',
#   'a',
#   'pool',
#   'in',
#   'the',
#   'stream',
#   '.'],
#  ['There', 'is', 'magic', 'in', 'it', '.'],
#  ['Let',
#   'the',
#   'most',
#   'absent',
#   '-',
#   'minded',
#   'of',
#   'men',
#   'be',
#   'plunged',
#   'in',
#   'his',
#   'deepest',
#   'reveries',
#   '--',
#   'stand',
#   'that',
#   'man',
#   'on',
#   'his',
#   'legs',
#   ',',
#   'set',
#   'his',
#   'feet',
#   'a',
#   '-',
#   'going',
#   ',',
#   'and',
#   'he',
#   'will',
#   'infallibly',
#   'lead',
#   'you',
#   'to',
#   'water',
#   ',',
#   'if',
#   'water',
#   'there',
#   'be',
#   'in',
#   'all',
#   'that',
#   'region',
#   '.'],
#  ['Should',
#   'you',
#   'ever',
#   'be',
#   'athirst',
#   'in',
#   'the',
#   'great',
#   'American',
#   'desert',
#   ',',
#   'try',
#   'this',
#   'experiment',
#   ',',
#   'if',
#   'your',
#   'caravan',
#   'happen',
#   'to',
#   'be',
#   'supplied',
#   'with',
#   'a',
#   'metaphysical',
#   'professor',
#   '.'],
#  ['Yes',
#   ',',
#   'as',
#   'every',
#   'one',
#   'knows',
#   ',',
#   'meditation',
#   'and',
#   'water',
#   'are',
#   'wedded',
#   'for',
#   'ever',
#   '.'],
#  ['But', 'here', 'is', 'an', 'artist', '.'],
#  ['He',
#   'desires',
#   'to',
#   'paint',
#   'you',
#   'the',
#   'dreamiest',
#   ',',
#   'shadiest',
#   ',',
#   'quietest',
#   ',',
#   'most',
#   'enchanting',
#   'bit',
#   'of',
#   'romantic',
#   'landscape',
#   'in',
#   'all',
#   'the',
#   'valley',
#   'of',
#   'the',
#   'Saco',
#   '.'],
#  ['What', 'is', 'the', 'chief', 'element', 'he', 'employs', '?'],
#  ['There',
#   'stand',
#   'his',
#   'trees',
#   ',',
#   'each',
#   'with',
#   'a',
#   'hollow',
#   'trunk',
#   ',',
#   'as',
#   'if',
#   'a',
#   'hermit',
#   'and',
#   'a',
#   'crucifix',
#   'were',
#   'within',
#   ';',
#   'and',
#   'here',
#   'sleeps',
#   'his',
#   'meadow',
#   ',',
#   'and',
#   'there',
#   'sleep',
#   'his',
#   'cattle',
#   ';',
#   'and',
#   'up',
#   'from',
#   'yonder',
#   'cottage',
#   'goes',
#   'a',
#   'sleepy',
#   'smoke',
#   '.'],
#  ['Deep',
#   'into',
#   'distant',
#   'woodlands',
#   'winds',
#   'a',
#   'mazy',
#   'way',
#   ',',
#   'reaching',
#   'to',
#   'overlapping',
#   'spurs',
#   'of',
#   'mountains',
#   'bathed',
#   'in',
#   'their',
#   'hill',
#   '-',
#   'side',
#   'blue',
#   '.'],
#  ['But',
#   'though',
#   'the',
#   'picture',
#   'lies',
#   'thus',
#   'tranced',
#   ',',
#   'and',
#   'though',
#   'this',
#   'pine',
#   '-',
#   'tree',
#   'shakes',
#   'down',
#   'its',
#   'sighs',
#   'like',
#   'leaves',
#   'upon',
#   'this',
#   'shepherd',
#   "'",
#   's',
#   'head',
#   ',',
#   'yet',
#   'all',
#   'were',
#   'vain',
#   ',',
#   'unless',
#   'the',
#   'shepherd',
#   "'",
#   's',
#   'eye',
#   'were',
#   'fixed',
#   'upon',
#   'the',
#   'magic',
#   'stream',
#   'before',
#   'him',
#   '.'],
#  ['Go',
#   'visit',
#   'the',
#   'Prairies',
#   'in',
#   'June',
#   ',',
#   'when',
#   'for',
#   'scores',
#   'on',
#   'scores',
#   'of',
#   'miles',
#   'you',
#   'wade',
#   'knee',
#   '-',
#   'deep',
#   'among',
#   'Tiger',
#   '-',
#   'lilies',
#   '--',
#   'what',
#   'is',
#   'the',
#   'one',
#   'charm',
#   'wanting',
#   '?',
#   '--',
#   'Water',
#   '--',
#   'there',
#   'is',
#   'not',
#   'a',
#   'drop',
#   'of',
#   'water',
#   'there',
#   '!'],
#  ['Were',
#   'Niagara',
#   'but',
#   'a',
#   'cataract',
#   'of',
#   'sand',
#   ',',
#   'would',
#   'you',
#   'travel',
#   'your',
#   'thousand',
#   'miles',
#   'to',
#   'see',
#   'it',
#   '?'],
#  ['Why',
#   'did',
#   'the',
#   'poor',
#   'poet',
#   'of',
#   'Tennessee',
#   ',',
#   'upon',
#   'suddenly',
#   'receiving',
#   'two',
#   'handfuls',
#   'of',
#   'silver',
#   ',',
#   'deliberate',
#   'whether',
#   'to',
#   'buy',
#   'him',
#   'a',
#   'coat',
#   ',',
#   'which',
#   'he',
#   'sadly',
#   'needed',
#   ',',
#   'or',
#   'invest',
#   'his',
#   'money',
#   'in',
#   'a',
#   'pedestrian',
#   'trip',
#   'to',
#   'Rockaway',
#   'Beach',
#   '?'],
#  ['Why',
#   'is',
#   'almost',
#   'every',
#   'robust',
#   'healthy',
#   'boy',
#   'with',
#   'a',
#   'robust',
#   'healthy',
#   'soul',
#   'in',
#   'him',
#   ',',
#   'at',
#   'some',
#   'time',
#   'or',
#   'other',
#   'crazy',
#   'to',
#   'go',
#   'to',
#   'sea',
#   '?'],
#  ['Why',
#   'upon',
#   'your',
#   'first',
#   'voyage',
#   'as',
#   'a',
#   'passenger',
#   ',',
#   'did',
#   'you',
#   'yourself',
#   'feel',
#   'such',
#   'a',
#   'mystical',
#   'vibration',
#   ',',
#   'when',
#   'first',
#   'told',
#   'that',
#   'you',
#   'and',
#   'your',
#   'ship',
#   'were',
#   'now',
#   'out',
#   'of',
#   'sight',
#   'of',
#   'land',
#   '?'],
#  ['Why', 'did', 'the', 'old', 'Persians', 'hold', 'the', 'sea', 'holy', '?'],
#  ['Why',
#   'did',
#   'the',
#   'Greeks',
#   'give',
#   'it',
#   'a',
#   'separate',
#   'deity',
#   ',',
#   'and',
#   'own',
#   'brother',
#   'of',
#   'Jove',
#   '?'],
#  ['Surely', 'all', 'this', 'is', 'not', 'without', 'meaning', '.'],
#  ['And',
#   'still',
#   'deeper',
#   'the',
#   'meaning',
#   'of',
#   'that',
#   'story',
#   'of',
#   'Narcissus',
#   ',',
#   'who',
#   'because',
#   'he',
#   'could',
#   'not',
#   'grasp',
#   'the',
#   'tormenting',
#   ',',
#   'mild',
#   'image',
#   'he',
#   'saw',
#   'in',
#   'the',
#   'fountain',
#   ',',
#   'plunged',
#   'into',
#   'it',
#   'and',
#   'was',
#   'drowned',
#   '.'],
#  ['But',
#   'that',
#   'same',
#   'image',
#   ',',
#   'we',
#   'ourselves',
#   'see',
#   'in',
#   'all',
#   'rivers',
#   'and',
#   'oceans',
#   '.'],
#  ['It',
#   'is',
#   'the',
#   'image',
#   'of',
#   'the',
#   'ungraspable',
#   'phantom',
#   'of',
#   'life',
#   ';',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   '.'],
#  ['Now',
#   ',',
#   'when',
#   'I',
#   'say',
#   'that',
#   'I',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'going',
#   'to',
#   'sea',
#   'whenever',
#   'I',
#   'begin',
#   'to',
#   'grow',
#   'hazy',
#   'about',
#   'the',
#   'eyes',
#   ',',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lungs',
#   ',',
#   'I',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'inferred',
#   'that',
#   'I',
#   'ever',
#   'go',
#   'to',
#   'sea',
#   'as',
#   'a',
#   'passenger',
#   '.'],
#  ['For',
#   'to',
#   'go',
#   'as',
#   'a',
#   'passenger',
#   'you',
#   'must',
#   'needs',
#   'have',
#   'a',
#   'purse',
#   ',',
#   'and',
#   'a',
#   'purse',
#   'is',
#   'but',
#   'a',
#   'rag',
#   'unless',
#   'you',
#   'have',
#   'something',
#   'in',
#   'it',
#   '.'],
#  ['Besides',
#   ',',
#   'passengers',
#   'get',
#   'sea',
#   '-',
#   'sick',
#   '--',
#   'grow',
#   'quarrelsome',
#   '--',
#   'don',
#   "'",
#   't',
#   'sleep',
#   'of',
#   'nights',
#   '--',
#   'do',
#   'not',
#   'enjoy',
#   'themselves',
#   'much',
#   ',',
#   'as',
#   'a',
#   'general',
#   'thing',
#   ';',
#   '--',
#   'no',
#   ',',
#   'I',
#   'never',
#   'go',
#   'as',
#   'a',
#   'passenger',
#   ';',
#   'nor',
#   ',',
#   'though',
#   'I',
#   'am',
#   'something',
#   'of',
#   'a',
#   'salt',
#   ',',
#   'do',
#   'I',
#   'ever',
#   'go',
#   'to',
#   'sea',
#   'as',
#   'a',
#   'Commodore',
#   ',',
#   'or',
#   'a',
#   'Captain',
#   ',',
#   'or',
#   'a',
#   'Cook',
#   '.'],
#  ['I',
#   'abandon',
#   'the',
#   'glory',
#   'and',
#   'distinction',
#   'of',
#   'such',
#   'offices',
#   'to',
#   'those',
#   'who',
#   'like',
#   'them',
#   '.'],
#  ['For',
#   'my',
#   'part',
#   ',',
#   'I',
#   'abominate',
#   'all',
#   'honourable',
#   'respectable',
#   'toils',
#   ',',
#   'trials',
#   ',',
#   'and',
#   'tribulations',
#   'of',
#   'every',
#   'kind',
#   'whatsoever',
#   '.'],
#  ['It',
#   'is',
#   'quite',
#   'as',
#   'much',
#   'as',
#   'I',
#   'can',
#   'do',
#   'to',
#   'take',
#   'care',
#   'of',
#   'myself',
#   ',',
#   'without',
#   'taking',
#   'care',
#   'of',
#   'ships',
#   ',',
#   'barques',
#   ',',
#   'brigs',
#   ',',
#   'schooners',
#   ',',
#   'and',
#   'what',
#   'not',
#   '.'],
#  ['And',
#   'as',
#   'for',
#   'going',
#   'as',
#   'cook',
#   ',',
#   '--',
#   'though',
#   'I',
#   'confess',
#   'there',
#   'is',
#   'considerable',
#   'glory',
#   'in',
#   'that',
#   ',',
#   'a',
#   'cook',
#   'being',
#   'a',
#   'sort',
#   'of',
#   'officer',
#   'on',
#   'ship',
#   '-',
#   'board',
#   '--',
#   'yet',
#   ',',
#   'somehow',
#   ',',
#   'I',
#   'never',
#   'fancied',
#   'broiling',
#   'fowls',
#   ';',
#   '--',
#   'though',
#   'once',
#   'broiled',
#   ',',
#   'judiciously',
#   'buttered',
#   ',',
#   'and',
#   'judgmatically',
#   'salted',
#   'and',
#   'peppered',
#   ',',
#   'there',
#   'is',
#   'no',
#   'one',
#   'who',
#   'will',
#   'speak',
#   'more',
#   'respectfully',
#   ',',
#   'not',
#   'to',
#   'say',
#   'reverentially',
#   ',',
#   'of',
#   'a',
#   'broiled',
#   'fowl',
#   'than',
#   'I',
#   'will',
#   '.'],
#  ['It',
#   'is',
#   'out',
#   'of',
#   'the',
#   'idolatrous',
#   'dotings',
#   'of',
#   'the',
#   'old',
#   'Egyptians',
#   'upon',
#   'broiled',
#   'ibis',
#   'and',
#   'roasted',
#   'river',
#   'horse',
#   ',',
#   'that',
#   'you',
#   'see',
#   'the',
#   'mummies',
#   'of',
#   'those',
#   'creatures',
#   'in',
#   'their',
#   'huge',
#   'bake',
#   '-',
#   'houses',
#   'the',
#   'pyramids',
#   '.'],
#  ['No',
#   ',',
#   'when',
#   'I',
#   'go',
#   'to',
#   'sea',
#   ',',
#   'I',
#   'go',
#   'as',
#   'a',
#   'simple',
#   'sailor',
#   ',',
#   'right',
#   'before',
#   'the',
#   'mast',
#   ',',
#   'plumb',
#   'down',
#   'into',
#   'the',
#   'forecastle',
#   ',',
#   'aloft',
#   'there',
#   'to',
#   'the',
#   'royal',
#   'mast',
#   '-',
#   'head',
#   '.'],
#  ['True',
#   ',',
#   'they',
#   'rather',
#   'order',
#   'me',
#   'about',
#   'some',
#   ',',
#   'and',
#   'make',
#   'me',
#   'jump',
#   'from',
#   'spar',
#   'to',
#   'spar',
#   ',',
#   'like',
#   'a',
#   'grasshopper',
#   'in',
#   'a',
#   'May',
#   'meadow',
#   '.'],
#  ['And',
#   'at',
#   'first',
#   ',',
#   'this',
#   'sort',
#   'of',
#   'thing',
#   'is',
#   'unpleasant',
#   'enough',
#   '.'],
#  ['It',
#   'touches',
#   'one',
#   "'",
#   's',
#   'sense',
#   'of',
#   'honour',
#   ',',
#   'particularly',
#   'if',
#   'you',
#   'come',
#   'of',
#   'an',
#   'old',
#   'established',
#   'family',
#   'in',
#   'the',
#   'land',
#   ',',
#   'the',
#   'Van',
#   'Rensselaers',
#   ',',
#   'or',
#   'Randolphs',
#   ',',
#   'or',
#   'Hardicanutes',
#   '.'],
#  ['And',
#   'more',
#   'than',
#   'all',
#   ',',
#   'if',
#   'just',
#   'previous',
#   'to',
#   'putting',
#   'your',
#   'hand',
#   'into',
#   'the',
#   'tar',
#   '-',
#   'pot',
#   ',',
#   'you',
#   'have',
#   'been',
#   'lording',
#   'it',
#   'as',
#   'a',
#   'country',
#   'schoolmaster',
#   ',',
#   'making',
#   'the',
#   'tallest',
#   'boys',
#   'stand',
#   'in',
#   'awe',
#   'of',
#   'you',
#   '.'],
#  ['The',
#   'transition',
#   'is',
#   'a',
#   'keen',
#   'one',
#   ',',
#   'I',
#   'assure',
#   'you',
#   ',',
#   'from',
#   'a',
#   'schoolmaster',
#   'to',
#   'a',
#   'sailor',
#   ',',
#   'and',
#   'requires',
#   'a',
#   'strong',
#   'decoction',
#   'of',
#   'Seneca',
#   'and',
#   'the',
#   'Stoics',
#   'to',
#   'enable',
#   'you',
#   'to',
#   'grin',
#   'and',
#   'bear',
#   'it',
#   '.'],
#  ['But', 'even', 'this', 'wears', 'off', 'in', 'time', '.'],
#  ['What',
#   'of',
#   'it',
#   ',',
#   'if',
#   'some',
#   'old',
#   'hunks',
#   'of',
#   'a',
#   'sea',
#   '-',
#   'captain',
#   'orders',
#   'me',
#   'to',
#   'get',
#   'a',
#   'broom',
#   'and',
#   'sweep',
#   'down',
#   'the',
#   'decks',
#   '?'],
#  ['What',
#   'does',
#   'that',
#   'indignity',
#   'amount',
#   'to',
#   ',',
#   'weighed',
#   ',',
#   'I',
#   'mean',
#   ',',
#   'in',
#   'the',
#   'scales',
#   'of',
#   'the',
#   'New',
#   'Testament',
#   '?'],
#  ['Do',
#   'you',
#   'think',
#   'the',
#   'archangel',
#   'Gabriel',
#   'thinks',
#   'anything',
#   'the',
#   'less',
#   'of',
#   'me',
#   ',',
#   'because',
#   'I',
#   'promptly',
#   'and',
#   'respectfully',
#   'obey',
#   'that',
#   'old',
#   'hunks',
#   'in',
#   'that',
#   'particular',
#   'instance',
#   '?'],
#  ['Who', 'ain', "'", 't', 'a', 'slave', '?'],
#  ['Tell', 'me', 'that', '.'],
#  ['Well',
#   ',',
#   'then',
#   ',',
#   'however',
#   'the',
#   'old',
#   'sea',
#   '-',
#   'captains',
#   'may',
#   'order',
#   'me',
#   'about',
#   '--',
#   'however',
#   'they',
#   'may',
#   'thump',
#   'and',
#   'punch',
#   'me',
#   'about',
#   ',',
#   'I',
#   'have',
#   'the',
#   'satisfaction',
#   'of',
#   'knowing',
#   'that',
#   'it',
#   'is',
#   'all',
#   'right',
#   ';',
#   'that',
#   'everybody',
#   'else',
#   'is',
#   'one',
#   'way',
#   'or',
#   'other',
#   'served',
#   'in',
#   'much',
#   'the',
#   'same',
#   'way',
#   '--',
#   'either',
#   'in',
#   'a',
#   'physical',
#   'or',
#   'metaphysical',
#   'point',
#   'of',
#   'view',
#   ',',
#   'that',
#   'is',
#   ';',
#   'and',
#   'so',
#   'the',
#   'universal',
#   'thump',
#   'is',
#   'passed',
#   'round',
#   ',',
#   'and',
#   'all',
#   'hands',
#   'should',
#   'rub',
#   'each',
#   'other',
#   "'",
#   's',
#   'shoulder',
#   '-',
#   'blades',
#   ',',
#   'and',
#   'be',
#   'content',
#   '.'],
#  ['Again',
#   ',',
#   'I',
#   'always',
#   'go',
#   'to',
#   'sea',
#   'as',
#   'a',
#   'sailor',
#   ',',
#   'because',
#   'they',
#   'make',
#   'a',
#   'point',
#   'of',
#   'paying',
#   'me',
#   'for',
#   'my',
#   'trouble',
#   ',',
#   'whereas',
#   'they',
#   'never',
#   'pay',
#   'passengers',
#   'a',
#   'single',
#   'penny',
#   'that',
#   'I',
#   'ever',
#   'heard',
#   'of',
#   '.'],
#  ['On',
#   'the',
#   'contrary',
#   ',',
#   'passengers',
#   'themselves',
#   'must',
#   'pay',
#   '.'],
#  ['And',
#   'there',
#   'is',
#   'all',
#   'the',
#   'difference',
#   'in',
#   'the',
#   'world',
#   'between',
#   'paying',
#   'and',
#   'being',
#   'paid',
#   '.'],
#  ['The',
#   'act',
#   'of',
#   'paying',
#   'is',
#   'perhaps',
#   'the',
#   'most',
#   'uncomfortable',
#   'infliction',
#   'that',
#   'the',
#   'two',
#   'orchard',
#   'thieves',
#   'entailed',
#   'upon',
#   'us',
#   '.'],
#  ['But',
#   'BEING',
#   'PAID',
#   ',',
#   '--',
#   'what',
#   'will',
#   'compare',
#   'with',
#   'it',
#   '?'],
#  ['The',
#   'urbane',
#   'activity',
#   'with',
#   'which',
#   'a',
#   'man',
#   'receives',
#   'money',
#   'is',
#   'really',
#   'marvellous',
#   ',',
#   'considering',
#   'that',
#   'we',
#   'so',
#   'earnestly',
#   'believe',
#   'money',
#   'to',
#   'be',
#   'the',
#   'root',
#   'of',
#   'all',
#   'earthly',
#   'ills',
#   ',',
#   'and',
#   'that',
#   'on',
#   'no',
#   'account',
#   'can',
#   'a',
#   'monied',
#   'man',
#   'enter',
#   'heaven',
#   '.'],
#  ['Ah', '!'],
#  ['how', 'cheerfully', 'we', 'consign', 'ourselves', 'to', 'perdition', '!'],
#  ['Finally',
#   ',',
#   'I',
#   'always',
#   'go',
#   'to',
#   'sea',
#   'as',
#   'a',
#   'sailor',
#   ',',
#   'because',
#   'of',
#   'the',
#   'wholesome',
#   'exercise',
#   'and',
#   'pure',
#   'air',
#   'of',
#   'the',
#   'fore',
#   '-',
#   'castle',
#   'deck',
#   '.'],
#  ['For',
#   'as',
#   'in',
#   'this',
#   'world',
#   ',',
#   'head',
#   'winds',
#   'are',
#   'far',
#   'more',
#   'prevalent',
#   'than',
#   'winds',
#   'from',
#   'astern',
#   '(',
#   'that',
#   'is',
#   ',',
#   'if',
#   'you',
#   'never',
#   'violate',
#   'the',
#   'Pythagorean',
#   'maxim',
#   ')',
#   ',',
#   'so',
#   'for',
#   'the',
#   'most',
#   'part',
#   'the',
#   'Commodore',
#   'on',
#   'the',
#   'quarter',
#   '-',
#   'deck',
#   'gets',
#   'his',
#   'atmosphere',
#   'at',
#   'second',
#   'hand',
#   'from',
#   'the',
#   'sailors',
#   'on',
#   'the',
#   'forecastle',
#   '.'],
#  ['He',
#   'thinks',
#   'he',
#   'breathes',
#   'it',
#   'first',
#   ';',
#   'but',
#   'not',
#   'so',
#   '.'],
#  ['In',
#   'much',
#   'the',
#   'same',
#   'way',
#   'do',
#   'the',
#   'commonalty',
#   'lead',
#   'their',
#   'leaders',
#   'in',
#   'many',
#   'other',
#   'things',
#   ',',
#   'at',
#   'the',
#   'same',
#   'time',
#   'that',
#   'the',
#   'leaders',
#   'little',
#   'suspect',
#   'it',
#   '.'],
#  ['But',
#   'wherefore',
#   'it',
#   'was',
#   'that',
#   'after',
#   'having',
#   'repeatedly',
#   'smelt',
#   'the',
#   'sea',
#   'as',
#   'a',
#   'merchant',
#   'sailor',
#   ',',
#   'I',
#   'should',
#   'now',
#   'take',
#   'it',
#   'into',
#   'my',
#   'head',
#   'to',
#   'go',
#   'on',
#   'a',
#   'whaling',
#   'voyage',
#   ';',
#   'this',
#   'the',
#   'invisible',
#   'police',
#   'officer',
#   'of',
#   'the',
#   'Fates',
#   ',',
#   'who',
#   'has',
#   'the',
#   'constant',
#   'surveillance',
#   'of',
#   'me',
#   ',',
#   'and',
#   'secretly',
#   'dogs',
#   'me',
#   ',',
#   'and',
#   'influences',
#   'me',
#   'in',
#   'some',
#   'unaccountable',
#   'way',
#   '--',
#   'he',
#   'can',
#   'better',
#   'answer',
#   'than',
#   'any',
#   'one',
#   'else',
#   '.'],
#  ['And',
#   ',',
#   'doubtless',
#   ',',
#   'my',
#   'going',
#   'on',
#   'this',
#   'whaling',
#   'voyage',
#   ',',
#   'formed',
#   'part',
#   'of',
#   'the',
#   'grand',
#   'programme',
#   'of',
#   'Providence',
#   'that',
#   'was',
#   'drawn',
#   'up',
#   'a',
#   'long',
#   'time',
#   'ago',
#   '.'],
#  ['It',
#   'came',
#   'in',
#   'as',
#   'a',
#   'sort',
#   'of',
#   'brief',
#   'interlude',
#   'and',
#   'solo',
#   'between',
#   'more',
#   'extensive',
#   'performances',
#   '.'],
#  ['I',
#   'take',
#   'it',
#   'that',
#   'this',
#   'part',
#   'of',
#   'the',
#   'bill',
#   'must',
#   'have',
#   'run',
#   'something',
#   'like',
#   'this',
#   ':'],
#  ['"',
#   'GRAND',
#   'CONTESTED',
#   'ELECTION',
#   'FOR',
#   'THE',
#   'PRESIDENCY',
#   'OF',
#   'THE',
#   'UNITED',
#   'STATES',
#   '.'],
#  ['"', 'WHALING', 'VOYAGE', 'BY', 'ONE', 'ISHMAEL', '.'],
#  ['"', 'BLOODY', 'BATTLE', 'IN', 'AFFGHANISTAN', '.', '"'],
#  ['Though',
#   'I',
#   'can',
#   'not',
#   'tell',
#   'why',
#   'it',
#   'was',
#   'exactly',
#   'that',
#   'those',
#   'stage',
#   'managers',
#   ',',
#   'the',
#   'Fates',
#   ',',
#   'put',
#   'me',
#   'down',
#   'for',
#   'this',
#   'shabby',
#   'part',
#   'of',
#   'a',
#   'whaling',
#   'voyage',
#   ',',
#   'when',
#   'others',
#   'were',
#   'set',
#   'down',
#   'for',
#   'magnificent',
#   'parts',
#   'in',
#   'high',
#   'tragedies',
#   ',',
#   'and',
#   'short',
#   'and',
#   'easy',
#   'parts',
#   'in',
#   'genteel',
#   'comedies',
#   ',',
#   'and',
#   'jolly',
#   'parts',
#   'in',
#   'farces',
#   '--',
#   'though',
#   'I',
#   'can',
#   'not',
#   'tell',
#   'why',
#   'this',
#   'was',
#   'exactly',
#   ';',
#   'yet',
#   ',',
#   'now',
#   'that',
#   'I',
#   'recall',
#   'all',
#   'the',
#   'circumstances',
#   ',',
#   'I',
#   'think',
#   'I',
#   'can',
#   'see',
#   'a',
#   'little',
#   'into',
#   'the',
#   'springs',
#   'and',
#   'motives',
#   'which',
#   'being',
#   'cunningly',
#   'presented',
#   'to',
#   'me',
#   'under',
#   'various',
#   'disguises',
#   ',',
#   'induced',
#   'me',
#   'to',
#   'set',
#   'about',
#   'performing',
#   'the',
#   'part',
#   'I',
#   'did',
#   ',',
#   'besides',
#   'cajoling',
#   'me',
#   'into',
#   'the',
#   'delusion',
#   'that',
#   'it',
#   'was',
#   'a',
#   'choice',
#   'resulting',
#   'from',
#   'my',
#   'own',
#   'unbiased',
#   'freewill',
#   'and',
#   'discriminating',
#   'judgment',
#   '.'],
#  ['Chief',
#   'among',
#   'these',
#   'motives',
#   'was',
#   'the',
#   'overwhelming',
#   'idea',
#   'of',
#   'the',
#   'great',
#   'whale',
#   'himself',
#   '.'],
#  ['Such',
#   'a',
#   'portentous',
#   'and',
#   'mysterious',
#   'monster',
#   'roused',
#   'all',
#   'my',
#   'curiosity',
#   '.'],
#  ['Then',
#   'the',
#   'wild',
#   'and',
#   'distant',
#   'seas',
#   'where',
#   'he',
#   'rolled',
#   'his',
#   'island',
#   'bulk',
#   ';',
#   'the',
#   'undeliverable',
#   ',',
#   'nameless',
#   'perils',
#   'of',
#   'the',
#   'whale',
#   ';',
#   'these',
#   ',',
#   'with',
#   'all',
#   'the',
#   'attending',
#   'marvels',
#   'of',
#   'a',
#   'thousand',
#   'Patagonian',
#   'sights',
#   'and',
#   'sounds',
#   ',',
#   'helped',
#   'to',
#   'sway',
#   'me',
#   'to',
#   'my',
#   'wish',
#   '.'],
#  ['With',
#   'other',
#   'men',
#   ',',
#   'perhaps',
#   ',',
#   'such',
#   'things',
#   'would',
#   'not',
#   'have',
#   'been',
#   'inducements',
#   ';',
#   'but',
#   'as',
#   'for',
#   'me',
#   ',',
#   'I',
#   'am',
#   'tormented',
#   'with',
#   'an',
#   'everlasting',
#   'itch',
#   'for',
#   'things',
#   'remote',
#   '.']]

# %% [markdown]
# ### Exercise
#
# Collect counts over the tokens. What is the most frequent token?

# %%
# your code here
from collections import Counter

c = Counter([token for sentence in tokens for token in sentence])
# c.most_common(1)
c.most_common(10)
# Out:
# [(',', 157),
#  ('the', 111),
#  ('.', 78),
#  ('of', 75),
#  ('a', 67),
#  ('and', 61),
#  ('to', 49),
#  ('in', 43),
#  ('I', 41),
#  ('is', 32)]

# %% [markdown]
# ## Lemmatization
# We want to get the dictionary form of each word, to reduce variation.

# %%
lemmas = [token.lemma_ for sentence in documents[:100] for token in nlp(sentence)]
lemmas
# Out:
# ['looming',
#  '.',
#  'call',
#  '-PRON-',
#  'ishmael',
#  '.',
#  'some',
#  'year',
#  'ago',
#  '--',
#  'never',
#  'mind',
#  'how',
#  'long',
#  'precisely',
#  '--',
#  'have',
#  'little',
#  'or',
#  'no',
#  'money',
#  'in',
#  '-PRON-',
#  'purse',
#  ',',
#  'and',
#  'nothing',
#  'particular',
#  'to',
#  'interest',
#  '-PRON-',
#  'on',
#  'shore',
#  ',',
#  '-PRON-',
#  'think',
#  '-PRON-',
#  'would',
#  'sail',
#  'about',
#  'a',
#  'little',
#  'and',
#  'see',
#  'the',
#  'watery',
#  'part',
#  'of',
#  'the',
#  'world',
#  '.',
#  '-PRON-',
#  'be',
#  'a',
#  'way',
#  '-PRON-',
#  'have',
#  'of',
#  'drive',
#  'off',
#  'the',
#  'spleen',
#  'and',
#  'regulate',
#  'the',
#  'circulation',
#  '.',
#  'whenever',
#  '-PRON-',
#  'find',
#  '-PRON-',
#  'grow',
#  'grim',
#  'about',
#  'the',
#  'mouth',
#  ';',
#  'whenever',
#  '-PRON-',
#  'be',
#  'a',
#  'damp',
#  ',',
#  'drizzly',
#  'november',
#  'in',
#  '-PRON-',
#  'soul',
#  ';',
#  'whenever',
#  '-PRON-',
#  'find',
#  '-PRON-',
#  'involuntarily',
#  'pause',
#  'before',
#  'coffin',
#  'warehouse',
#  ',',
#  'and',
#  'bring',
#  'up',
#  'the',
#  'rear',
#  'of',
#  'every',
#  'funeral',
#  '-PRON-',
#  'meet',
#  ';',
#  'and',
#  'especially',
#  'whenever',
#  '-PRON-',
#  'hypos',
#  'get',
#  'such',
#  'an',
#  'upper',
#  'hand',
#  'of',
#  '-PRON-',
#  ',',
#  'that',
#  '-PRON-',
#  'require',
#  'a',
#  'strong',
#  'moral',
#  'principle',
#  'to',
#  'prevent',
#  '-PRON-',
#  'from',
#  'deliberately',
#  'step',
#  'into',
#  'the',
#  'street',
#  ',',
#  'and',
#  'methodically',
#  'knock',
#  'people',
#  "'",
#  's',
#  'hat',
#  'off',
#  '--',
#  'then',
#  ',',
#  '-PRON-',
#  'account',
#  '-PRON-',
#  'high',
#  'time',
#  'to',
#  'get',
#  'to',
#  'sea',
#  'as',
#  'soon',
#  'as',
#  '-PRON-',
#  'can',
#  '.',
#  'this',
#  'be',
#  '-PRON-',
#  'substitute',
#  'for',
#  'pistol',
#  'and',
#  'ball',
#  '.',
#  'with',
#  'a',
#  'philosophical',
#  'flourish',
#  'cato',
#  'throw',
#  '-PRON-',
#  'upon',
#  '-PRON-',
#  'sword',
#  ';',
#  '-PRON-',
#  'quietly',
#  'take',
#  'to',
#  'the',
#  'ship',
#  '.',
#  'there',
#  'be',
#  'nothing',
#  'surprising',
#  'in',
#  'this',
#  '.',
#  'if',
#  '-PRON-',
#  'but',
#  'know',
#  '-PRON-',
#  ',',
#  'almost',
#  'all',
#  'man',
#  'in',
#  '-PRON-',
#  'degree',
#  ',',
#  'some',
#  'time',
#  'or',
#  'other',
#  ',',
#  'cherish',
#  'very',
#  'nearly',
#  'the',
#  'same',
#  'feeling',
#  'towards',
#  'the',
#  'ocean',
#  'with',
#  '-PRON-',
#  '.',
#  'there',
#  'now',
#  'be',
#  '-PRON-',
#  'insular',
#  'city',
#  'of',
#  'the',
#  'manhattoes',
#  ',',
#  'belt',
#  'round',
#  'by',
#  'wharf',
#  'as',
#  'indian',
#  'isle',
#  'by',
#  'coral',
#  'reef',
#  '--',
#  'commerce',
#  'surround',
#  '-PRON-',
#  'with',
#  '-PRON-',
#  'surf',
#  '.',
#  'right',
#  'and',
#  'leave',
#  ',',
#  'the',
#  'street',
#  'take',
#  '-PRON-',
#  'waterward',
#  '.',
#  '-PRON-',
#  'extreme',
#  'downtown',
#  'be',
#  'the',
#  'battery',
#  ',',
#  'where',
#  'that',
#  'noble',
#  'mole',
#  'be',
#  'wash',
#  'by',
#  'wave',
#  ',',
#  'and',
#  'cool',
#  'by',
#  'breeze',
#  ',',
#  'which',
#  'a',
#  'few',
#  'hour',
#  'previous',
#  'be',
#  'out',
#  'of',
#  'sight',
#  'of',
#  'land',
#  '.',
#  'look',
#  'at',
#  'the',
#  'crowd',
#  'of',
#  'water',
#  '-',
#  'gazer',
#  'there',
#  '.',
#  'circumambulate',
#  'the',
#  'city',
#  'of',
#  'a',
#  'dreamy',
#  'sabbath',
#  'afternoon',
#  '.',
#  'go',
#  'from',
#  'corlears',
#  'hook',
#  'to',
#  'coenties',
#  'slip',
#  ',',
#  'and',
#  'from',
#  'thence',
#  ',',
#  'by',
#  'whitehall',
#  ',',
#  'northward',
#  '.',
#  'what',
#  'do',
#  '-PRON-',
#  'see',
#  '?',
#  '--',
#  'post',
#  'like',
#  'silent',
#  'sentinel',
#  'all',
#  'around',
#  'the',
#  'town',
#  ',',
#  'stand',
#  'thousand',
#  'upon',
#  'thousand',
#  'of',
#  'mortal',
#  'man',
#  'fix',
#  'in',
#  'ocean',
#  'reverie',
#  '.',
#  'some',
#  'lean',
#  'against',
#  'the',
#  'spile',
#  ';',
#  'some',
#  'seat',
#  'upon',
#  'the',
#  'pier',
#  '-',
#  'head',
#  ';',
#  'some',
#  'look',
#  'over',
#  'the',
#  'bulwark',
#  'of',
#  'ship',
#  'from',
#  'china',
#  ';',
#  'some',
#  'high',
#  'aloft',
#  'in',
#  'the',
#  'rigging',
#  ',',
#  'as',
#  'if',
#  'strive',
#  'to',
#  'get',
#  'a',
#  'still',
#  'good',
#  'seaward',
#  'peep',
#  '.',
#  'but',
#  'these',
#  'be',
#  'all',
#  'landsman',
#  ';',
#  'of',
#  'week',
#  'day',
#  'pen',
#  'up',
#  'in',
#  'lath',
#  'and',
#  'plaster',
#  '--',
#  'tie',
#  'to',
#  'counter',
#  ',',
#  'nail',
#  'to',
#  'bench',
#  ',',
#  'clinch',
#  'to',
#  'desk',
#  '.',
#  'how',
#  'then',
#  'be',
#  'this',
#  '?',
#  'be',
#  'the',
#  'green',
#  'field',
#  'go',
#  '?',
#  'what',
#  'do',
#  '-PRON-',
#  'here',
#  '?',
#  'but',
#  'look',
#  '!',
#  'here',
#  'come',
#  'more',
#  'crowd',
#  ',',
#  'pace',
#  'straight',
#  'for',
#  'the',
#  'water',
#  ',',
#  'and',
#  'seemingly',
#  'bind',
#  'for',
#  'a',
#  'dive',
#  '.',
#  'strange',
#  '!',
#  'nothing',
#  'will',
#  'content',
#  '-PRON-',
#  'but',
#  'the',
#  'extreme',
#  'limit',
#  'of',
#  'the',
#  'land',
#  ';',
#  'loitering',
#  'under',
#  'the',
#  'shady',
#  'lee',
#  'of',
#  'yonder',
#  'warehouse',
#  'will',
#  'not',
#  'suffice',
#  '.',
#  'no',
#  '.',
#  '-PRON-',
#  'must',
#  'get',
#  'just',
#  'as',
#  'nigh',
#  'the',
#  'water',
#  'as',
#  '-PRON-',
#  'possibly',
#  'can',
#  'without',
#  'fall',
#  'in',
#  '.',
#  'and',
#  'there',
#  '-PRON-',
#  'stand',
#  '--',
#  'mile',
#  'of',
#  '-PRON-',
#  '--',
#  'league',
#  '.',
#  'inlander',
#  'all',
#  ',',
#  '-PRON-',
#  'come',
#  'from',
#  'lane',
#  'and',
#  'alley',
#  ',',
#  'street',
#  'and',
#  'avenue',
#  '--',
#  'north',
#  ',',
#  'east',
#  ',',
#  'south',
#  ',',
#  'and',
#  'west',
#  '.',
#  'yet',
#  'here',
#  '-PRON-',
#  'all',
#  'unite',
#  '.',
#  'tell',
#  '-PRON-',
#  ',',
#  'do',
#  'the',
#  'magnetic',
#  'virtue',
#  'of',
#  'the',
#  'needle',
#  'of',
#  'the',
#  'compass',
#  'of',
#  'all',
#  'those',
#  'ship',
#  'attract',
#  '-PRON-',
#  'thither',
#  '?',
#  'once',
#  'more',
#  '.',
#  'say',
#  '-PRON-',
#  'be',
#  'in',
#  'the',
#  'country',
#  ';',
#  'in',
#  'some',
#  'high',
#  'land',
#  'of',
#  'lake',
#  '.',
#  'take',
#  'almost',
#  'any',
#  'path',
#  '-PRON-',
#  'please',
#  ',',
#  'and',
#  'ten',
#  'to',
#  'one',
#  '-PRON-',
#  'carry',
#  '-PRON-',
#  'down',
#  'in',
#  'a',
#  'dale',
#  ',',
#  'and',
#  'leave',
#  '-PRON-',
#  'there',
#  'by',
#  'a',
#  'pool',
#  'in',
#  'the',
#  'stream',
#  '.',
#  'there',
#  'be',
#  'magic',
#  'in',
#  '-PRON-',
#  '.',
#  'let',
#  'the',
#  'most',
#  'absent',
#  '-',
#  'minded',
#  'of',
#  'man',
#  'be',
#  'plunge',
#  'in',
#  '-PRON-',
#  'deep',
#  'reverie',
#  '--',
#  'stand',
#  'that',
#  'man',
#  'on',
#  '-PRON-',
#  'leg',
#  ',',
#  'set',
#  '-PRON-',
#  'foot',
#  'a',
#  '-',
#  'going',
#  ',',
#  'and',
#  '-PRON-',
#  'will',
#  'infallibly',
#  'lead',
#  '-PRON-',
#  'to',
#  'water',
#  ',',
#  'if',
#  'water',
#  'there',
#  'be',
#  'in',
#  'all',
#  'that',
#  'region',
#  '.',
#  'should',
#  '-PRON-',
#  'ever',
#  'be',
#  'athirst',
#  'in',
#  'the',
#  'great',
#  'american',
#  'desert',
#  ',',
#  'try',
#  'this',
#  'experiment',
#  ',',
#  'if',
#  '-PRON-',
#  'caravan',
#  'happen',
#  'to',
#  'be',
#  'supply',
#  'with',
#  'a',
#  'metaphysical',
#  'professor',
#  '.',
#  'yes',
#  ',',
#  'as',
#  'every',
#  'one',
#  'know',
#  ',',
#  'meditation',
#  'and',
#  'water',
#  'be',
#  'wed',
#  'for',
#  'ever',
#  '.',
#  'but',
#  'here',
#  'be',
#  'an',
#  'artist',
#  '.',
#  '-PRON-',
#  'desire',
#  'to',
#  'paint',
#  '-PRON-',
#  'the',
#  'dreamiest',
#  ',',
#  'shady',
#  ',',
#  'quiet',
#  ',',
#  'most',
#  'enchanting',
#  'bit',
#  'of',
#  'romantic',
#  'landscape',
#  'in',
#  'all',
#  'the',
#  'valley',
#  'of',
#  'the',
#  'saco',
#  '.',
#  'what',
#  'be',
#  'the',
#  'chief',
#  'element',
#  '-PRON-',
#  'employ',
#  '?',
#  'there',
#  'stand',
#  '-PRON-',
#  'tree',
#  ',',
#  'each',
#  'with',
#  'a',
#  'hollow',
#  'trunk',
#  ',',
#  'as',
#  'if',
#  'a',
#  'hermit',
#  'and',
#  'a',
#  'crucifix',
#  'be',
#  'within',
#  ';',
#  'and',
#  'here',
#  'sleep',
#  '-PRON-',
#  'meadow',
#  ',',
#  'and',
#  'there',
#  'sleep',
#  '-PRON-',
#  'cattle',
#  ';',
#  'and',
#  'up',
#  'from',
#  'yonder',
#  'cottage',
#  'go',
#  'a',
#  'sleepy',
#  'smoke',
#  '.',
#  'deep',
#  'into',
#  'distant',
#  'woodland',
#  'wind',
#  'a',
#  'mazy',
#  'way',
#  ',',
#  'reach',
#  'to',
#  'overlap',
#  'spur',
#  'of',
#  'mountain',
#  'bath',
#  'in',
#  '-PRON-',
#  'hill',
#  '-',
#  'side',
#  'blue',
#  '.',
#  'but',
#  'though',
#  'the',
#  'picture',
#  'lie',
#  'thus',
#  'trance',
#  ',',
#  'and',
#  'though',
#  'this',
#  'pine',
#  '-',
#  'tree',
#  'shake',
#  'down',
#  '-PRON-',
#  'sigh',
#  'like',
#  'leaf',
#  'upon',
#  'this',
#  'shepherd',
#  "'",
#  's',
#  'head',
#  ',',
#  'yet',
#  'all',
#  'be',
#  'vain',
#  ',',
#  'unless',
#  'the',
#  'shepherd',
#  "'",
#  's',
#  'eye',
#  'be',
#  'fix',
#  'upon',
#  'the',
#  'magic',
#  'stream',
#  'before',
#  '-PRON-',
#  '.',
#  'go',
#  'visit',
#  'the',
#  'prairies',
#  'in',
#  'june',
#  ',',
#  'when',
#  'for',
#  'score',
#  'on',
#  'score',
#  'of',
#  'mile',
#  '-PRON-',
#  'wade',
#  'knee',
#  '-',
#  'deep',
#  'among',
#  'tiger',
#  '-',
#  'lily',
#  '--',
#  'what',
#  'be',
#  'the',
#  'one',
#  'charm',
#  'want',
#  '?',
#  '--',
#  'water',
#  '--',
#  'there',
#  'be',
#  'not',
#  'a',
#  'drop',
#  'of',
#  'water',
#  'there',
#  '!',
#  'be',
#  'niagara',
#  'but',
#  'a',
#  'cataract',
#  'of',
#  'sand',
#  ',',
#  'would',
#  '-PRON-',
#  'travel',
#  '-PRON-',
#  'thousand',
#  'mile',
#  'to',
#  'see',
#  '-PRON-',
#  '?',
#  'why',
#  'do',
#  'the',
#  'poor',
#  'poet',
#  'of',
#  'tennessee',
#  ',',
#  'upon',
#  'suddenly',
#  'receive',
#  'two',
#  'handful',
#  'of',
#  'silver',
#  ',',
#  'deliberate',
#  'whether',
#  'to',
#  'buy',
#  '-PRON-',
#  'a',
#  'coat',
#  ',',
#  'which',
#  '-PRON-',
#  'sadly',
#  'need',
#  ',',
#  'or',
#  'invest',
#  '-PRON-',
#  'money',
#  'in',
#  'a',
#  'pedestrian',
#  'trip',
#  'to',
#  'rockaway',
#  'beach',
#  '?',
#  'why',
#  'be',
#  'almost',
#  'every',
#  'robust',
#  'healthy',
#  'boy',
#  'with',
#  'a',
#  'robust',
#  'healthy',
#  'soul',
#  'in',
#  '-PRON-',
#  ',',
#  'at',
#  'some',
#  'time',
#  'or',
#  'other',
#  'crazy',
#  'to',
#  'go',
#  'to',
#  'sea',
#  '?',
#  'why',
#  ...]

# %% [markdown]
# ### Exercise
# Right now, the lemmas of all pronouns are collapsed into `-PRON-`. Change the code to preserve the original word (as lower case).

# %%
# your code here
lemmas_with_pron = [token.lemma_ if token.lemma_ != '-PRON-' else token.lower_ for sentence in documents[:10] for token in nlp(sentence)]
lemmas_with_pron
# Out:
# ['looming',
#  '.',
#  'call',
#  'me',
#  'ishmael',
#  '.',
#  'some',
#  'year',
#  'ago',
#  '--',
#  'never',
#  'mind',
#  'how',
#  'long',
#  'precisely',
#  '--',
#  'have',
#  'little',
#  'or',
#  'no',
#  'money',
#  'in',
#  'my',
#  'purse',
#  ',',
#  'and',
#  'nothing',
#  'particular',
#  'to',
#  'interest',
#  'me',
#  'on',
#  'shore',
#  ',',
#  'i',
#  'think',
#  'i',
#  'would',
#  'sail',
#  'about',
#  'a',
#  'little',
#  'and',
#  'see',
#  'the',
#  'watery',
#  'part',
#  'of',
#  'the',
#  'world',
#  '.',
#  'it',
#  'be',
#  'a',
#  'way',
#  'i',
#  'have',
#  'of',
#  'drive',
#  'off',
#  'the',
#  'spleen',
#  'and',
#  'regulate',
#  'the',
#  'circulation',
#  '.',
#  'whenever',
#  'i',
#  'find',
#  'myself',
#  'grow',
#  'grim',
#  'about',
#  'the',
#  'mouth',
#  ';',
#  'whenever',
#  'it',
#  'be',
#  'a',
#  'damp',
#  ',',
#  'drizzly',
#  'november',
#  'in',
#  'my',
#  'soul',
#  ';',
#  'whenever',
#  'i',
#  'find',
#  'myself',
#  'involuntarily',
#  'pause',
#  'before',
#  'coffin',
#  'warehouse',
#  ',',
#  'and',
#  'bring',
#  'up',
#  'the',
#  'rear',
#  'of',
#  'every',
#  'funeral',
#  'i',
#  'meet',
#  ';',
#  'and',
#  'especially',
#  'whenever',
#  'my',
#  'hypos',
#  'get',
#  'such',
#  'an',
#  'upper',
#  'hand',
#  'of',
#  'me',
#  ',',
#  'that',
#  'it',
#  'require',
#  'a',
#  'strong',
#  'moral',
#  'principle',
#  'to',
#  'prevent',
#  'me',
#  'from',
#  'deliberately',
#  'step',
#  'into',
#  'the',
#  'street',
#  ',',
#  'and',
#  'methodically',
#  'knock',
#  'people',
#  "'",
#  's',
#  'hat',
#  'off',
#  '--',
#  'then',
#  ',',
#  'i',
#  'account',
#  'it',
#  'high',
#  'time',
#  'to',
#  'get',
#  'to',
#  'sea',
#  'as',
#  'soon',
#  'as',
#  'i',
#  'can',
#  '.',
#  'this',
#  'be',
#  'my',
#  'substitute',
#  'for',
#  'pistol',
#  'and',
#  'ball',
#  '.',
#  'with',
#  'a',
#  'philosophical',
#  'flourish',
#  'cato',
#  'throw',
#  'himself',
#  'upon',
#  'his',
#  'sword',
#  ';',
#  'i',
#  'quietly',
#  'take',
#  'to',
#  'the',
#  'ship',
#  '.',
#  'there',
#  'be',
#  'nothing',
#  'surprising',
#  'in',
#  'this',
#  '.',
#  'if',
#  'they',
#  'but',
#  'know',
#  'it',
#  ',',
#  'almost',
#  'all',
#  'man',
#  'in',
#  'their',
#  'degree',
#  ',',
#  'some',
#  'time',
#  'or',
#  'other',
#  ',',
#  'cherish',
#  'very',
#  'nearly',
#  'the',
#  'same',
#  'feeling',
#  'towards',
#  'the',
#  'ocean',
#  'with',
#  'me',
#  '.',
#  'there',
#  'now',
#  'be',
#  'your',
#  'insular',
#  'city',
#  'of',
#  'the',
#  'manhattoes',
#  ',',
#  'belt',
#  'round',
#  'by',
#  'wharf',
#  'as',
#  'indian',
#  'isle',
#  'by',
#  'coral',
#  'reef',
#  '--',
#  'commerce',
#  'surround',
#  'it',
#  'with',
#  'her',
#  'surf',
#  '.']

# %% [markdown]
# ## Stemming
# A more aggressive way of removing variation is *stemming*.

# %%
from nltk import SnowballStemmer

stemmer = SnowballStemmer('english')
stems = [[stemmer.stem(token) for token in sentence] for sentence in tokens]
stems
# Out:
# [['loom', '.'],
#  ['call', 'me', 'ishmael', '.'],
#  ['some',
#   'year',
#   'ago',
#   '--',
#   'never',
#   'mind',
#   'how',
#   'long',
#   'precis',
#   '--',
#   'have',
#   'littl',
#   'or',
#   'no',
#   'money',
#   'in',
#   'my',
#   'purs',
#   ',',
#   'and',
#   'noth',
#   'particular',
#   'to',
#   'interest',
#   'me',
#   'on',
#   'shore',
#   ',',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'sail',
#   'about',
#   'a',
#   'littl',
#   'and',
#   'see',
#   'the',
#   'wateri',
#   'part',
#   'of',
#   'the',
#   'world',
#   '.'],
#  ['it',
#   'is',
#   'a',
#   'way',
#   'i',
#   'have',
#   'of',
#   'drive',
#   'off',
#   'the',
#   'spleen',
#   'and',
#   'regul',
#   'the',
#   'circul',
#   '.'],
#  ['whenev',
#   'i',
#   'find',
#   'myself',
#   'grow',
#   'grim',
#   'about',
#   'the',
#   'mouth',
#   ';',
#   'whenev',
#   'it',
#   'is',
#   'a',
#   'damp',
#   ',',
#   'drizzli',
#   'novemb',
#   'in',
#   'my',
#   'soul',
#   ';',
#   'whenev',
#   'i',
#   'find',
#   'myself',
#   'involuntarili',
#   'paus',
#   'befor',
#   'coffin',
#   'warehous',
#   ',',
#   'and',
#   'bring',
#   'up',
#   'the',
#   'rear',
#   'of',
#   'everi',
#   'funer',
#   'i',
#   'meet',
#   ';',
#   'and',
#   'especi',
#   'whenev',
#   'my',
#   'hypo',
#   'get',
#   'such',
#   'an',
#   'upper',
#   'hand',
#   'of',
#   'me',
#   ',',
#   'that',
#   'it',
#   'requir',
#   'a',
#   'strong',
#   'moral',
#   'principl',
#   'to',
#   'prevent',
#   'me',
#   'from',
#   'deliber',
#   'step',
#   'into',
#   'the',
#   'street',
#   ',',
#   'and',
#   'method',
#   'knock',
#   'peopl',
#   "'",
#   's',
#   'hat',
#   'off',
#   '--',
#   'then',
#   ',',
#   'i',
#   'account',
#   'it',
#   'high',
#   'time',
#   'to',
#   'get',
#   'to',
#   'sea',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'can',
#   '.'],
#  ['this', 'is', 'my', 'substitut', 'for', 'pistol', 'and', 'ball', '.'],
#  ['with',
#   'a',
#   'philosoph',
#   'flourish',
#   'cato',
#   'throw',
#   'himself',
#   'upon',
#   'his',
#   'sword',
#   ';',
#   'i',
#   'quiet',
#   'take',
#   'to',
#   'the',
#   'ship',
#   '.'],
#  ['there', 'is', 'noth', 'surpris', 'in', 'this', '.'],
#  ['if',
#   'they',
#   'but',
#   'knew',
#   'it',
#   ',',
#   'almost',
#   'all',
#   'men',
#   'in',
#   'their',
#   'degre',
#   ',',
#   'some',
#   'time',
#   'or',
#   'other',
#   ',',
#   'cherish',
#   'veri',
#   'near',
#   'the',
#   'same',
#   'feel',
#   'toward',
#   'the',
#   'ocean',
#   'with',
#   'me',
#   '.'],
#  ['there',
#   'now',
#   'is',
#   'your',
#   'insular',
#   'citi',
#   'of',
#   'the',
#   'manhatto',
#   ',',
#   'belt',
#   'round',
#   'by',
#   'wharv',
#   'as',
#   'indian',
#   'isl',
#   'by',
#   'coral',
#   'reef',
#   '--',
#   'commerc',
#   'surround',
#   'it',
#   'with',
#   'her',
#   'surf',
#   '.'],
#  ['right',
#   'and',
#   'left',
#   ',',
#   'the',
#   'street',
#   'take',
#   'you',
#   'waterward',
#   '.'],
#  ['it',
#   'extrem',
#   'downtown',
#   'is',
#   'the',
#   'batteri',
#   ',',
#   'where',
#   'that',
#   'nobl',
#   'mole',
#   'is',
#   'wash',
#   'by',
#   'wave',
#   ',',
#   'and',
#   'cool',
#   'by',
#   'breez',
#   ',',
#   'which',
#   'a',
#   'few',
#   'hour',
#   'previous',
#   'were',
#   'out',
#   'of',
#   'sight',
#   'of',
#   'land',
#   '.'],
#  ['look', 'at', 'the', 'crowd', 'of', 'water', '-', 'gazer', 'there', '.'],
#  ['circumambul',
#   'the',
#   'citi',
#   'of',
#   'a',
#   'dreami',
#   'sabbath',
#   'afternoon',
#   '.'],
#  ['go',
#   'from',
#   'corlear',
#   'hook',
#   'to',
#   'coenti',
#   'slip',
#   ',',
#   'and',
#   'from',
#   'thenc',
#   ',',
#   'by',
#   'whitehal',
#   ',',
#   'northward',
#   '.'],
#  ['what',
#   'do',
#   'you',
#   'see',
#   '?',
#   '--',
#   'post',
#   'like',
#   'silent',
#   'sentinel',
#   'all',
#   'around',
#   'the',
#   'town',
#   ',',
#   'stand',
#   'thousand',
#   'upon',
#   'thousand',
#   'of',
#   'mortal',
#   'men',
#   'fix',
#   'in',
#   'ocean',
#   'reveri',
#   '.'],
#  ['some',
#   'lean',
#   'against',
#   'the',
#   'spile',
#   ';',
#   'some',
#   'seat',
#   'upon',
#   'the',
#   'pier',
#   '-',
#   'head',
#   ';',
#   'some',
#   'look',
#   'over',
#   'the',
#   'bulwark',
#   'of',
#   'ship',
#   'from',
#   'china',
#   ';',
#   'some',
#   'high',
#   'aloft',
#   'in',
#   'the',
#   'rig',
#   ',',
#   'as',
#   'if',
#   'strive',
#   'to',
#   'get',
#   'a',
#   'still',
#   'better',
#   'seaward',
#   'peep',
#   '.'],
#  ['but',
#   'these',
#   'are',
#   'all',
#   'landsmen',
#   ';',
#   'of',
#   'week',
#   'day',
#   'pent',
#   'up',
#   'in',
#   'lath',
#   'and',
#   'plaster',
#   '--',
#   'tie',
#   'to',
#   'counter',
#   ',',
#   'nail',
#   'to',
#   'bench',
#   ',',
#   'clinch',
#   'to',
#   'desk',
#   '.'],
#  ['how', 'then', 'is', 'this', '?'],
#  ['are', 'the', 'green', 'field', 'gone', '?'],
#  ['what', 'do', 'they', 'here', '?'],
#  ['but', 'look', '!'],
#  ['here',
#   'come',
#   'more',
#   'crowd',
#   ',',
#   'pace',
#   'straight',
#   'for',
#   'the',
#   'water',
#   ',',
#   'and',
#   'seem',
#   'bound',
#   'for',
#   'a',
#   'dive',
#   '.'],
#  ['strang', '!'],
#  ['noth',
#   'will',
#   'content',
#   'them',
#   'but',
#   'the',
#   'extremest',
#   'limit',
#   'of',
#   'the',
#   'land',
#   ';',
#   'loiter',
#   'under',
#   'the',
#   'shadi',
#   'lee',
#   'of',
#   'yonder',
#   'warehous',
#   'will',
#   'not',
#   'suffic',
#   '.'],
#  ['no', '.'],
#  ['they',
#   'must',
#   'get',
#   'just',
#   'as',
#   'nigh',
#   'the',
#   'water',
#   'as',
#   'they',
#   'possibl',
#   'can',
#   'without',
#   'fall',
#   'in',
#   '.'],
#  ['and',
#   'there',
#   'they',
#   'stand',
#   '--',
#   'mile',
#   'of',
#   'them',
#   '--',
#   'leagu',
#   '.'],
#  ['inland',
#   'all',
#   ',',
#   'they',
#   'come',
#   'from',
#   'lane',
#   'and',
#   'alley',
#   ',',
#   'street',
#   'and',
#   'avenu',
#   '--',
#   'north',
#   ',',
#   'east',
#   ',',
#   'south',
#   ',',
#   'and',
#   'west',
#   '.'],
#  ['yet', 'here', 'they', 'all', 'unit', '.'],
#  ['tell',
#   'me',
#   ',',
#   'doe',
#   'the',
#   'magnet',
#   'virtu',
#   'of',
#   'the',
#   'needl',
#   'of',
#   'the',
#   'compass',
#   'of',
#   'all',
#   'those',
#   'ship',
#   'attract',
#   'them',
#   'thither',
#   '?'],
#  ['onc', 'more', '.'],
#  ['say',
#   'you',
#   'are',
#   'in',
#   'the',
#   'countri',
#   ';',
#   'in',
#   'some',
#   'high',
#   'land',
#   'of',
#   'lake',
#   '.'],
#  ['take',
#   'almost',
#   'ani',
#   'path',
#   'you',
#   'pleas',
#   ',',
#   'and',
#   'ten',
#   'to',
#   'one',
#   'it',
#   'carri',
#   'you',
#   'down',
#   'in',
#   'a',
#   'dale',
#   ',',
#   'and',
#   'leav',
#   'you',
#   'there',
#   'by',
#   'a',
#   'pool',
#   'in',
#   'the',
#   'stream',
#   '.'],
#  ['there', 'is', 'magic', 'in', 'it', '.'],
#  ['let',
#   'the',
#   'most',
#   'absent',
#   '-',
#   'mind',
#   'of',
#   'men',
#   'be',
#   'plung',
#   'in',
#   'his',
#   'deepest',
#   'reveri',
#   '--',
#   'stand',
#   'that',
#   'man',
#   'on',
#   'his',
#   'leg',
#   ',',
#   'set',
#   'his',
#   'feet',
#   'a',
#   '-',
#   'go',
#   ',',
#   'and',
#   'he',
#   'will',
#   'infal',
#   'lead',
#   'you',
#   'to',
#   'water',
#   ',',
#   'if',
#   'water',
#   'there',
#   'be',
#   'in',
#   'all',
#   'that',
#   'region',
#   '.'],
#  ['should',
#   'you',
#   'ever',
#   'be',
#   'athirst',
#   'in',
#   'the',
#   'great',
#   'american',
#   'desert',
#   ',',
#   'tri',
#   'this',
#   'experi',
#   ',',
#   'if',
#   'your',
#   'caravan',
#   'happen',
#   'to',
#   'be',
#   'suppli',
#   'with',
#   'a',
#   'metaphys',
#   'professor',
#   '.'],
#  ['yes',
#   ',',
#   'as',
#   'everi',
#   'one',
#   'know',
#   ',',
#   'medit',
#   'and',
#   'water',
#   'are',
#   'wed',
#   'for',
#   'ever',
#   '.'],
#  ['but', 'here', 'is', 'an', 'artist', '.'],
#  ['he',
#   'desir',
#   'to',
#   'paint',
#   'you',
#   'the',
#   'dreamiest',
#   ',',
#   'shadiest',
#   ',',
#   'quietest',
#   ',',
#   'most',
#   'enchant',
#   'bit',
#   'of',
#   'romant',
#   'landscap',
#   'in',
#   'all',
#   'the',
#   'valley',
#   'of',
#   'the',
#   'saco',
#   '.'],
#  ['what', 'is', 'the', 'chief', 'element', 'he', 'employ', '?'],
#  ['there',
#   'stand',
#   'his',
#   'tree',
#   ',',
#   'each',
#   'with',
#   'a',
#   'hollow',
#   'trunk',
#   ',',
#   'as',
#   'if',
#   'a',
#   'hermit',
#   'and',
#   'a',
#   'crucifix',
#   'were',
#   'within',
#   ';',
#   'and',
#   'here',
#   'sleep',
#   'his',
#   'meadow',
#   ',',
#   'and',
#   'there',
#   'sleep',
#   'his',
#   'cattl',
#   ';',
#   'and',
#   'up',
#   'from',
#   'yonder',
#   'cottag',
#   'goe',
#   'a',
#   'sleepi',
#   'smoke',
#   '.'],
#  ['deep',
#   'into',
#   'distant',
#   'woodland',
#   'wind',
#   'a',
#   'mazi',
#   'way',
#   ',',
#   'reach',
#   'to',
#   'overlap',
#   'spur',
#   'of',
#   'mountain',
#   'bath',
#   'in',
#   'their',
#   'hill',
#   '-',
#   'side',
#   'blue',
#   '.'],
#  ['but',
#   'though',
#   'the',
#   'pictur',
#   'lie',
#   'thus',
#   'tranc',
#   ',',
#   'and',
#   'though',
#   'this',
#   'pine',
#   '-',
#   'tree',
#   'shake',
#   'down',
#   'it',
#   'sigh',
#   'like',
#   'leav',
#   'upon',
#   'this',
#   'shepherd',
#   "'",
#   's',
#   'head',
#   ',',
#   'yet',
#   'all',
#   'were',
#   'vain',
#   ',',
#   'unless',
#   'the',
#   'shepherd',
#   "'",
#   's',
#   'eye',
#   'were',
#   'fix',
#   'upon',
#   'the',
#   'magic',
#   'stream',
#   'befor',
#   'him',
#   '.'],
#  ['go',
#   'visit',
#   'the',
#   'prairi',
#   'in',
#   'june',
#   ',',
#   'when',
#   'for',
#   'score',
#   'on',
#   'score',
#   'of',
#   'mile',
#   'you',
#   'wade',
#   'knee',
#   '-',
#   'deep',
#   'among',
#   'tiger',
#   '-',
#   'lili',
#   '--',
#   'what',
#   'is',
#   'the',
#   'one',
#   'charm',
#   'want',
#   '?',
#   '--',
#   'water',
#   '--',
#   'there',
#   'is',
#   'not',
#   'a',
#   'drop',
#   'of',
#   'water',
#   'there',
#   '!'],
#  ['were',
#   'niagara',
#   'but',
#   'a',
#   'cataract',
#   'of',
#   'sand',
#   ',',
#   'would',
#   'you',
#   'travel',
#   'your',
#   'thousand',
#   'mile',
#   'to',
#   'see',
#   'it',
#   '?'],
#  ['whi',
#   'did',
#   'the',
#   'poor',
#   'poet',
#   'of',
#   'tennesse',
#   ',',
#   'upon',
#   'sudden',
#   'receiv',
#   'two',
#   'hand',
#   'of',
#   'silver',
#   ',',
#   'deliber',
#   'whether',
#   'to',
#   'buy',
#   'him',
#   'a',
#   'coat',
#   ',',
#   'which',
#   'he',
#   'sad',
#   'need',
#   ',',
#   'or',
#   'invest',
#   'his',
#   'money',
#   'in',
#   'a',
#   'pedestrian',
#   'trip',
#   'to',
#   'rockaway',
#   'beach',
#   '?'],
#  ['whi',
#   'is',
#   'almost',
#   'everi',
#   'robust',
#   'healthi',
#   'boy',
#   'with',
#   'a',
#   'robust',
#   'healthi',
#   'soul',
#   'in',
#   'him',
#   ',',
#   'at',
#   'some',
#   'time',
#   'or',
#   'other',
#   'crazi',
#   'to',
#   'go',
#   'to',
#   'sea',
#   '?'],
#  ['whi',
#   'upon',
#   'your',
#   'first',
#   'voyag',
#   'as',
#   'a',
#   'passeng',
#   ',',
#   'did',
#   'you',
#   'yourself',
#   'feel',
#   'such',
#   'a',
#   'mystic',
#   'vibrat',
#   ',',
#   'when',
#   'first',
#   'told',
#   'that',
#   'you',
#   'and',
#   'your',
#   'ship',
#   'were',
#   'now',
#   'out',
#   'of',
#   'sight',
#   'of',
#   'land',
#   '?'],
#  ['whi', 'did', 'the', 'old', 'persian', 'hold', 'the', 'sea', 'holi', '?'],
#  ['whi',
#   'did',
#   'the',
#   'greek',
#   'give',
#   'it',
#   'a',
#   'separ',
#   'deiti',
#   ',',
#   'and',
#   'own',
#   'brother',
#   'of',
#   'jove',
#   '?'],
#  ['sure', 'all', 'this', 'is', 'not', 'without', 'mean', '.'],
#  ['and',
#   'still',
#   'deeper',
#   'the',
#   'mean',
#   'of',
#   'that',
#   'stori',
#   'of',
#   'narcissus',
#   ',',
#   'who',
#   'becaus',
#   'he',
#   'could',
#   'not',
#   'grasp',
#   'the',
#   'torment',
#   ',',
#   'mild',
#   'imag',
#   'he',
#   'saw',
#   'in',
#   'the',
#   'fountain',
#   ',',
#   'plung',
#   'into',
#   'it',
#   'and',
#   'was',
#   'drown',
#   '.'],
#  ['but',
#   'that',
#   'same',
#   'imag',
#   ',',
#   'we',
#   'ourselv',
#   'see',
#   'in',
#   'all',
#   'river',
#   'and',
#   'ocean',
#   '.'],
#  ['it',
#   'is',
#   'the',
#   'imag',
#   'of',
#   'the',
#   'ungrasp',
#   'phantom',
#   'of',
#   'life',
#   ';',
#   'and',
#   'this',
#   'is',
#   'the',
#   'key',
#   'to',
#   'it',
#   'all',
#   '.'],
#  ['now',
#   ',',
#   'when',
#   'i',
#   'say',
#   'that',
#   'i',
#   'am',
#   'in',
#   'the',
#   'habit',
#   'of',
#   'go',
#   'to',
#   'sea',
#   'whenev',
#   'i',
#   'begin',
#   'to',
#   'grow',
#   'hazi',
#   'about',
#   'the',
#   'eye',
#   ',',
#   'and',
#   'begin',
#   'to',
#   'be',
#   'over',
#   'conscious',
#   'of',
#   'my',
#   'lung',
#   ',',
#   'i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'have',
#   'it',
#   'infer',
#   'that',
#   'i',
#   'ever',
#   'go',
#   'to',
#   'sea',
#   'as',
#   'a',
#   'passeng',
#   '.'],
#  ['for',
#   'to',
#   'go',
#   'as',
#   'a',
#   'passeng',
#   'you',
#   'must',
#   'need',
#   'have',
#   'a',
#   'purs',
#   ',',
#   'and',
#   'a',
#   'purs',
#   'is',
#   'but',
#   'a',
#   'rag',
#   'unless',
#   'you',
#   'have',
#   'someth',
#   'in',
#   'it',
#   '.'],
#  ['besid',
#   ',',
#   'passeng',
#   'get',
#   'sea',
#   '-',
#   'sick',
#   '--',
#   'grow',
#   'quarrelsom',
#   '--',
#   'don',
#   "'",
#   't',
#   'sleep',
#   'of',
#   'night',
#   '--',
#   'do',
#   'not',
#   'enjoy',
#   'themselv',
#   'much',
#   ',',
#   'as',
#   'a',
#   'general',
#   'thing',
#   ';',
#   '--',
#   'no',
#   ',',
#   'i',
#   'never',
#   'go',
#   'as',
#   'a',
#   'passeng',
#   ';',
#   'nor',
#   ',',
#   'though',
#   'i',
#   'am',
#   'someth',
#   'of',
#   'a',
#   'salt',
#   ',',
#   'do',
#   'i',
#   'ever',
#   'go',
#   'to',
#   'sea',
#   'as',
#   'a',
#   'commodor',
#   ',',
#   'or',
#   'a',
#   'captain',
#   ',',
#   'or',
#   'a',
#   'cook',
#   '.'],
#  ['i',
#   'abandon',
#   'the',
#   'glori',
#   'and',
#   'distinct',
#   'of',
#   'such',
#   'offic',
#   'to',
#   'those',
#   'who',
#   'like',
#   'them',
#   '.'],
#  ['for',
#   'my',
#   'part',
#   ',',
#   'i',
#   'abomin',
#   'all',
#   'honour',
#   'respect',
#   'toil',
#   ',',
#   'trial',
#   ',',
#   'and',
#   'tribul',
#   'of',
#   'everi',
#   'kind',
#   'whatsoev',
#   '.'],
#  ['it',
#   'is',
#   'quit',
#   'as',
#   'much',
#   'as',
#   'i',
#   'can',
#   'do',
#   'to',
#   'take',
#   'care',
#   'of',
#   'myself',
#   ',',
#   'without',
#   'take',
#   'care',
#   'of',
#   'ship',
#   ',',
#   'barqu',
#   ',',
#   'brig',
#   ',',
#   'schooner',
#   ',',
#   'and',
#   'what',
#   'not',
#   '.'],
#  ['and',
#   'as',
#   'for',
#   'go',
#   'as',
#   'cook',
#   ',',
#   '--',
#   'though',
#   'i',
#   'confess',
#   'there',
#   'is',
#   'consider',
#   'glori',
#   'in',
#   'that',
#   ',',
#   'a',
#   'cook',
#   'be',
#   'a',
#   'sort',
#   'of',
#   'offic',
#   'on',
#   'ship',
#   '-',
#   'board',
#   '--',
#   'yet',
#   ',',
#   'somehow',
#   ',',
#   'i',
#   'never',
#   'fanci',
#   'broil',
#   'fowl',
#   ';',
#   '--',
#   'though',
#   'onc',
#   'broil',
#   ',',
#   'judici',
#   'butter',
#   ',',
#   'and',
#   'judgmat',
#   'salt',
#   'and',
#   'pepper',
#   ',',
#   'there',
#   'is',
#   'no',
#   'one',
#   'who',
#   'will',
#   'speak',
#   'more',
#   'respect',
#   ',',
#   'not',
#   'to',
#   'say',
#   'reverenti',
#   ',',
#   'of',
#   'a',
#   'broil',
#   'fowl',
#   'than',
#   'i',
#   'will',
#   '.'],
#  ['it',
#   'is',
#   'out',
#   'of',
#   'the',
#   'idolatr',
#   'dote',
#   'of',
#   'the',
#   'old',
#   'egyptian',
#   'upon',
#   'broil',
#   'ibi',
#   'and',
#   'roast',
#   'river',
#   'hors',
#   ',',
#   'that',
#   'you',
#   'see',
#   'the',
#   'mummi',
#   'of',
#   'those',
#   'creatur',
#   'in',
#   'their',
#   'huge',
#   'bake',
#   '-',
#   'hous',
#   'the',
#   'pyramid',
#   '.'],
#  ['no',
#   ',',
#   'when',
#   'i',
#   'go',
#   'to',
#   'sea',
#   ',',
#   'i',
#   'go',
#   'as',
#   'a',
#   'simpl',
#   'sailor',
#   ',',
#   'right',
#   'befor',
#   'the',
#   'mast',
#   ',',
#   'plumb',
#   'down',
#   'into',
#   'the',
#   'forecastl',
#   ',',
#   'aloft',
#   'there',
#   'to',
#   'the',
#   'royal',
#   'mast',
#   '-',
#   'head',
#   '.'],
#  ['true',
#   ',',
#   'they',
#   'rather',
#   'order',
#   'me',
#   'about',
#   'some',
#   ',',
#   'and',
#   'make',
#   'me',
#   'jump',
#   'from',
#   'spar',
#   'to',
#   'spar',
#   ',',
#   'like',
#   'a',
#   'grasshopp',
#   'in',
#   'a',
#   'may',
#   'meadow',
#   '.'],
#  ['and',
#   'at',
#   'first',
#   ',',
#   'this',
#   'sort',
#   'of',
#   'thing',
#   'is',
#   'unpleas',
#   'enough',
#   '.'],
#  ['it',
#   'touch',
#   'one',
#   "'",
#   's',
#   'sens',
#   'of',
#   'honour',
#   ',',
#   'particular',
#   'if',
#   'you',
#   'come',
#   'of',
#   'an',
#   'old',
#   'establish',
#   'famili',
#   'in',
#   'the',
#   'land',
#   ',',
#   'the',
#   'van',
#   'renssela',
#   ',',
#   'or',
#   'randolph',
#   ',',
#   'or',
#   'hardicanut',
#   '.'],
#  ['and',
#   'more',
#   'than',
#   'all',
#   ',',
#   'if',
#   'just',
#   'previous',
#   'to',
#   'put',
#   'your',
#   'hand',
#   'into',
#   'the',
#   'tar',
#   '-',
#   'pot',
#   ',',
#   'you',
#   'have',
#   'been',
#   'lord',
#   'it',
#   'as',
#   'a',
#   'countri',
#   'schoolmast',
#   ',',
#   'make',
#   'the',
#   'tallest',
#   'boy',
#   'stand',
#   'in',
#   'awe',
#   'of',
#   'you',
#   '.'],
#  ['the',
#   'transit',
#   'is',
#   'a',
#   'keen',
#   'one',
#   ',',
#   'i',
#   'assur',
#   'you',
#   ',',
#   'from',
#   'a',
#   'schoolmast',
#   'to',
#   'a',
#   'sailor',
#   ',',
#   'and',
#   'requir',
#   'a',
#   'strong',
#   'decoct',
#   'of',
#   'seneca',
#   'and',
#   'the',
#   'stoic',
#   'to',
#   'enabl',
#   'you',
#   'to',
#   'grin',
#   'and',
#   'bear',
#   'it',
#   '.'],
#  ['but', 'even', 'this', 'wear', 'off', 'in', 'time', '.'],
#  ['what',
#   'of',
#   'it',
#   ',',
#   'if',
#   'some',
#   'old',
#   'hunk',
#   'of',
#   'a',
#   'sea',
#   '-',
#   'captain',
#   'order',
#   'me',
#   'to',
#   'get',
#   'a',
#   'broom',
#   'and',
#   'sweep',
#   'down',
#   'the',
#   'deck',
#   '?'],
#  ['what',
#   'doe',
#   'that',
#   'indign',
#   'amount',
#   'to',
#   ',',
#   'weigh',
#   ',',
#   'i',
#   'mean',
#   ',',
#   'in',
#   'the',
#   'scale',
#   'of',
#   'the',
#   'new',
#   'testament',
#   '?'],
#  ['do',
#   'you',
#   'think',
#   'the',
#   'archangel',
#   'gabriel',
#   'think',
#   'anyth',
#   'the',
#   'less',
#   'of',
#   'me',
#   ',',
#   'becaus',
#   'i',
#   'prompt',
#   'and',
#   'respect',
#   'obey',
#   'that',
#   'old',
#   'hunk',
#   'in',
#   'that',
#   'particular',
#   'instanc',
#   '?'],
#  ['who', 'ain', "'", 't', 'a', 'slave', '?'],
#  ['tell', 'me', 'that', '.'],
#  ['well',
#   ',',
#   'then',
#   ',',
#   'howev',
#   'the',
#   'old',
#   'sea',
#   '-',
#   'captain',
#   'may',
#   'order',
#   'me',
#   'about',
#   '--',
#   'howev',
#   'they',
#   'may',
#   'thump',
#   'and',
#   'punch',
#   'me',
#   'about',
#   ',',
#   'i',
#   'have',
#   'the',
#   'satisfact',
#   'of',
#   'know',
#   'that',
#   'it',
#   'is',
#   'all',
#   'right',
#   ';',
#   'that',
#   'everybodi',
#   'els',
#   'is',
#   'one',
#   'way',
#   'or',
#   'other',
#   'serv',
#   'in',
#   'much',
#   'the',
#   'same',
#   'way',
#   '--',
#   'either',
#   'in',
#   'a',
#   'physic',
#   'or',
#   'metaphys',
#   'point',
#   'of',
#   'view',
#   ',',
#   'that',
#   'is',
#   ';',
#   'and',
#   'so',
#   'the',
#   'univers',
#   'thump',
#   'is',
#   'pass',
#   'round',
#   ',',
#   'and',
#   'all',
#   'hand',
#   'should',
#   'rub',
#   'each',
#   'other',
#   "'",
#   's',
#   'shoulder',
#   '-',
#   'blade',
#   ',',
#   'and',
#   'be',
#   'content',
#   '.'],
#  ['again',
#   ',',
#   'i',
#   'alway',
#   'go',
#   'to',
#   'sea',
#   'as',
#   'a',
#   'sailor',
#   ',',
#   'becaus',
#   'they',
#   'make',
#   'a',
#   'point',
#   'of',
#   'pay',
#   'me',
#   'for',
#   'my',
#   'troubl',
#   ',',
#   'wherea',
#   'they',
#   'never',
#   'pay',
#   'passeng',
#   'a',
#   'singl',
#   'penni',
#   'that',
#   'i',
#   'ever',
#   'heard',
#   'of',
#   '.'],
#  ['on', 'the', 'contrari', ',', 'passeng', 'themselv', 'must', 'pay', '.'],
#  ['and',
#   'there',
#   'is',
#   'all',
#   'the',
#   'differ',
#   'in',
#   'the',
#   'world',
#   'between',
#   'pay',
#   'and',
#   'be',
#   'paid',
#   '.'],
#  ['the',
#   'act',
#   'of',
#   'pay',
#   'is',
#   'perhap',
#   'the',
#   'most',
#   'uncomfort',
#   'inflict',
#   'that',
#   'the',
#   'two',
#   'orchard',
#   'thiev',
#   'entail',
#   'upon',
#   'us',
#   '.'],
#  ['but', 'be', 'paid', ',', '--', 'what', 'will', 'compar', 'with', 'it', '?'],
#  ['the',
#   'urban',
#   'activ',
#   'with',
#   'which',
#   'a',
#   'man',
#   'receiv',
#   'money',
#   'is',
#   'realli',
#   'marvel',
#   ',',
#   'consid',
#   'that',
#   'we',
#   'so',
#   'earnest',
#   'believ',
#   'money',
#   'to',
#   'be',
#   'the',
#   'root',
#   'of',
#   'all',
#   'earth',
#   'ill',
#   ',',
#   'and',
#   'that',
#   'on',
#   'no',
#   'account',
#   'can',
#   'a',
#   'moni',
#   'man',
#   'enter',
#   'heaven',
#   '.'],
#  ['ah', '!'],
#  ['how', 'cheer', 'we', 'consign', 'ourselv', 'to', 'perdit', '!'],
#  ['final',
#   ',',
#   'i',
#   'alway',
#   'go',
#   'to',
#   'sea',
#   'as',
#   'a',
#   'sailor',
#   ',',
#   'becaus',
#   'of',
#   'the',
#   'wholesom',
#   'exercis',
#   'and',
#   'pure',
#   'air',
#   'of',
#   'the',
#   'fore',
#   '-',
#   'castl',
#   'deck',
#   '.'],
#  ['for',
#   'as',
#   'in',
#   'this',
#   'world',
#   ',',
#   'head',
#   'wind',
#   'are',
#   'far',
#   'more',
#   'preval',
#   'than',
#   'wind',
#   'from',
#   'astern',
#   '(',
#   'that',
#   'is',
#   ',',
#   'if',
#   'you',
#   'never',
#   'violat',
#   'the',
#   'pythagorean',
#   'maxim',
#   ')',
#   ',',
#   'so',
#   'for',
#   'the',
#   'most',
#   'part',
#   'the',
#   'commodor',
#   'on',
#   'the',
#   'quarter',
#   '-',
#   'deck',
#   'get',
#   'his',
#   'atmospher',
#   'at',
#   'second',
#   'hand',
#   'from',
#   'the',
#   'sailor',
#   'on',
#   'the',
#   'forecastl',
#   '.'],
#  ['he', 'think', 'he', 'breath', 'it', 'first', ';', 'but', 'not', 'so', '.'],
#  ['in',
#   'much',
#   'the',
#   'same',
#   'way',
#   'do',
#   'the',
#   'commonalti',
#   'lead',
#   'their',
#   'leader',
#   'in',
#   'mani',
#   'other',
#   'thing',
#   ',',
#   'at',
#   'the',
#   'same',
#   'time',
#   'that',
#   'the',
#   'leader',
#   'littl',
#   'suspect',
#   'it',
#   '.'],
#  ['but',
#   'wherefor',
#   'it',
#   'was',
#   'that',
#   'after',
#   'have',
#   'repeat',
#   'smelt',
#   'the',
#   'sea',
#   'as',
#   'a',
#   'merchant',
#   'sailor',
#   ',',
#   'i',
#   'should',
#   'now',
#   'take',
#   'it',
#   'into',
#   'my',
#   'head',
#   'to',
#   'go',
#   'on',
#   'a',
#   'whale',
#   'voyag',
#   ';',
#   'this',
#   'the',
#   'invis',
#   'polic',
#   'offic',
#   'of',
#   'the',
#   'fate',
#   ',',
#   'who',
#   'has',
#   'the',
#   'constant',
#   'surveil',
#   'of',
#   'me',
#   ',',
#   'and',
#   'secret',
#   'dog',
#   'me',
#   ',',
#   'and',
#   'influenc',
#   'me',
#   'in',
#   'some',
#   'unaccount',
#   'way',
#   '--',
#   'he',
#   'can',
#   'better',
#   'answer',
#   'than',
#   'ani',
#   'one',
#   'els',
#   '.'],
#  ['and',
#   ',',
#   'doubtless',
#   ',',
#   'my',
#   'go',
#   'on',
#   'this',
#   'whale',
#   'voyag',
#   ',',
#   'form',
#   'part',
#   'of',
#   'the',
#   'grand',
#   'programm',
#   'of',
#   'provid',
#   'that',
#   'was',
#   'drawn',
#   'up',
#   'a',
#   'long',
#   'time',
#   'ago',
#   '.'],
#  ['it',
#   'came',
#   'in',
#   'as',
#   'a',
#   'sort',
#   'of',
#   'brief',
#   'interlud',
#   'and',
#   'solo',
#   'between',
#   'more',
#   'extens',
#   'perform',
#   '.'],
#  ['i',
#   'take',
#   'it',
#   'that',
#   'this',
#   'part',
#   'of',
#   'the',
#   'bill',
#   'must',
#   'have',
#   'run',
#   'someth',
#   'like',
#   'this',
#   ':'],
#  ['"',
#   'grand',
#   'contest',
#   'elect',
#   'for',
#   'the',
#   'presid',
#   'of',
#   'the',
#   'unit',
#   'state',
#   '.'],
#  ['"', 'whale', 'voyag', 'by', 'one', 'ishmael', '.'],
#  ['"', 'bloodi', 'battl', 'in', 'affghanistan', '.', '"'],
#  ['though',
#   'i',
#   'can',
#   'not',
#   'tell',
#   'whi',
#   'it',
#   'was',
#   'exact',
#   'that',
#   'those',
#   'stage',
#   'manag',
#   ',',
#   'the',
#   'fate',
#   ',',
#   'put',
#   'me',
#   'down',
#   'for',
#   'this',
#   'shabbi',
#   'part',
#   'of',
#   'a',
#   'whale',
#   'voyag',
#   ',',
#   'when',
#   'other',
#   'were',
#   'set',
#   'down',
#   'for',
#   'magnific',
#   'part',
#   'in',
#   'high',
#   'tragedi',
#   ',',
#   'and',
#   'short',
#   'and',
#   'easi',
#   'part',
#   'in',
#   'genteel',
#   'comedi',
#   ',',
#   'and',
#   'jolli',
#   'part',
#   'in',
#   'farc',
#   '--',
#   'though',
#   'i',
#   'can',
#   'not',
#   'tell',
#   'whi',
#   'this',
#   'was',
#   'exact',
#   ';',
#   'yet',
#   ',',
#   'now',
#   'that',
#   'i',
#   'recal',
#   'all',
#   'the',
#   'circumst',
#   ',',
#   'i',
#   'think',
#   'i',
#   'can',
#   'see',
#   'a',
#   'littl',
#   'into',
#   'the',
#   'spring',
#   'and',
#   'motiv',
#   'which',
#   'be',
#   'cun',
#   'present',
#   'to',
#   'me',
#   'under',
#   'various',
#   'disguis',
#   ',',
#   'induc',
#   'me',
#   'to',
#   'set',
#   'about',
#   'perform',
#   'the',
#   'part',
#   'i',
#   'did',
#   ',',
#   'besid',
#   'cajol',
#   'me',
#   'into',
#   'the',
#   'delus',
#   'that',
#   'it',
#   'was',
#   'a',
#   'choic',
#   'result',
#   'from',
#   'my',
#   'own',
#   'unbias',
#   'freewil',
#   'and',
#   'discrimin',
#   'judgment',
#   '.'],
#  ['chief',
#   'among',
#   'these',
#   'motiv',
#   'was',
#   'the',
#   'overwhelm',
#   'idea',
#   'of',
#   'the',
#   'great',
#   'whale',
#   'himself',
#   '.'],
#  ['such',
#   'a',
#   'portent',
#   'and',
#   'mysteri',
#   'monster',
#   'rous',
#   'all',
#   'my',
#   'curios',
#   '.'],
#  ['then',
#   'the',
#   'wild',
#   'and',
#   'distant',
#   'sea',
#   'where',
#   'he',
#   'roll',
#   'his',
#   'island',
#   'bulk',
#   ';',
#   'the',
#   'undeliver',
#   ',',
#   'nameless',
#   'peril',
#   'of',
#   'the',
#   'whale',
#   ';',
#   'these',
#   ',',
#   'with',
#   'all',
#   'the',
#   'attend',
#   'marvel',
#   'of',
#   'a',
#   'thousand',
#   'patagonian',
#   'sight',
#   'and',
#   'sound',
#   ',',
#   'help',
#   'to',
#   'sway',
#   'me',
#   'to',
#   'my',
#   'wish',
#   '.'],
#  ['with',
#   'other',
#   'men',
#   ',',
#   'perhap',
#   ',',
#   'such',
#   'thing',
#   'would',
#   'not',
#   'have',
#   'been',
#   'induc',
#   ';',
#   'but',
#   'as',
#   'for',
#   'me',
#   ',',
#   'i',
#   'am',
#   'torment',
#   'with',
#   'an',
#   'everlast',
#   'itch',
#   'for',
#   'thing',
#   'remot',
#   '.']]

# %% [markdown]
# ### Exercise
#
# Keep track of the most frequent word for each stem in `tokens`. Hint: use a nested `defaultdict`.
#
# - How many word forms does the stem `hand` have?
# - What is the most common word form for the stems `respect` and `whale`? What happened there?

# %%
# your code here
from collections import defaultdict
stem_origins = defaultdict(lambda: defaultdict(int))

for sentence in tokens:
    for token in sentence:
        stem = stemmer.stem(token)
        stem_origins[stem][token.lower()] += 1
stem_origins['whale']
# Out:
# defaultdict(int, {'whaling': 4, 'whale': 2})

# %% [markdown]
# ## Parts of speech
# We can extract the part of speech for every word with the `pos_` atttribute.

# %%
pos = [[token.pos_ for token in nlp(sentence)] for sentence in documents[:100]]
pos
# Out:
# [['NOUN', 'PUNCT'],
#  ['VERB', 'PRON', 'PROPN', 'PUNCT'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'PUNCT',
#   'VERB',
#   'ADJ',
#   'CCONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CCONJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADP',
#   'VERB',
#   'PART',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['ADV',
#   'PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'PROPN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'PART',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PART',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'PART',
#   'PART',
#   'NOUN',
#   'PART',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'PART',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADP',
#   'PRON',
#   'VERB',
#   'PUNCT'],
#  ['DET', 'VERB', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'CCONJ', 'NOUN', 'PUNCT'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'PROPN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['ADV', 'VERB', 'NOUN', 'ADJ', 'ADP', 'DET', 'PUNCT'],
#  ['ADP',
#   'PRON',
#   'CCONJ',
#   'VERB',
#   'PRON',
#   'PUNCT',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'ADV',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT'],
#  ['ADV',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PROPN',
#   'PUNCT',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  ['INTJ',
#   'CCONJ',
#   'VERB',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'PUNCT'],
#  ['ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADV',
#   'PUNCT'],
#  ['VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'PROPN', 'NOUN', 'PUNCT'],
#  ['VERB',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'ADP',
#   'PROPN',
#   'VERB',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'ADV',
#   'PUNCT'],
#  ['NOUN',
#   'VERB',
#   'PRON',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['DET',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'ADP',
#   'VERB',
#   'PART',
#   'VERB',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'DET',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PART',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['ADV', 'ADV', 'VERB', 'DET', 'PUNCT'],
#  ['VERB', 'DET', 'ADJ', 'NOUN', 'VERB', 'PUNCT'],
#  ['NOUN', 'VERB', 'PRON', 'ADV', 'PUNCT'],
#  ['CCONJ', 'VERB', 'PUNCT'],
#  ['ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['ADJ', 'PUNCT'],
#  ['NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   'CCONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PUNCT'],
#  ['INTJ', 'PUNCT'],
#  ['PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADP',
#   'VERB',
#   'ADV',
#   'PUNCT'],
#  ['CCONJ',
#   'ADV',
#   'PRON',
#   'VERB',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN',
#   'DET',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ', 'ADV', 'PRON', 'DET', 'VERB', 'PUNCT'],
#  ['VERB',
#   'PRON',
#   'PUNCT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'PUNCT'],
#  ['ADV', 'ADV', 'PUNCT'],
#  ['VERB',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'PUNCT',
#   'CCONJ',
#   'NUM',
#   'ADP',
#   'NUM',
#   'PRON',
#   'VERB',
#   'PRON',
#   'PART',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['ADV', 'VERB', 'NOUN', 'ADP', 'PRON', 'PUNCT'],
#  ['VERB',
#   'DET',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PART',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  ['INTJ',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PUNCT',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADV',
#   'PUNCT'],
#  ['CCONJ', 'ADV', 'VERB', 'DET', 'NOUN', 'PUNCT'],
#  ['PRON',
#   'VERB',
#   'PART',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'PUNCT',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PROPN',
#   'PUNCT'],
#  ['NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'PRON', 'VERB', 'PUNCT'],
#  ['ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  ['ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'PART',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PART',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'DET',
#   'VERB',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT'],
#  ['VERB',
#   'VERB',
#   'DET',
#   'PROPN',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'PUNCT'],
#  ['VERB',
#   'PROPN',
#   'CCONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'PART',
#   'VERB',
#   'PRON',
#   'PUNCT'],
#  ['ADV',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'ADP',
#   'ADV',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'ADP',
#   'PART',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'PRON',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PART',
#   'VERB',
#   'PROPN',
#   'PUNCT'],
#  ['ADV',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'ADJ',
#   'PART',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['ADV',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADP',
#   'PRON',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['ADV', 'VERB', 'DET', 'ADJ', 'PROPN', 'VERB', 'DET', 'NOUN', 'ADJ', 'PUNCT'],
#  ['ADV',
#   'VERB',
#   'DET',
#   'PROPN',
#   'VERB',
#   'PRON',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PUNCT'],
#  ['ADV', 'ADJ', 'DET', 'VERB', 'ADV', 'ADP', 'VERB', 'PUNCT'],
#  ['CCONJ',
#   'ADV',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'PRON',
#   'CCONJ',
#   'VERB',
#   'VERB',
#   'PUNCT'],
#  ['CCONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'DET',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'DET',
#   'PUNCT'],
#  ['ADV',
#   'PUNCT',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'VERB',
#   'PART',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'PART',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PART',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['ADP',
#   'PART',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'CCONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT'],
#  ['ADV',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PRON',
#   'ADV',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'INTJ',
#   'PUNCT',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PROPN',
#   'PUNCT',
#   'CCONJ',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'DET',
#   'PROPN',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT'],
#  ['ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PART',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'ADV',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'ADP',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'PRON',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'CCONJ',
#   'VERB',
#   'PUNCT',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'PART',
#   'VERB',
#   'ADV',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'PROPN',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['INTJ',
#   'PUNCT',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'PART',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'PUNCT'],
#  ['ADJ',
#   'PUNCT',
#   'PRON',
#   'ADV',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PROPN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'ADV',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'NUM',
#   'PUNCT',
#   'PART',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   'CCONJ',
#   'PROPN',
#   'PUNCT',
#   'CCONJ',
#   'PROPN',
#   'PUNCT'],
#  ['CCONJ',
#   'ADJ',
#   'ADP',
#   'DET',
#   'PUNCT',
#   'ADP',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'PRON',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'CCONJ',
#   'DET',
#   'PROPN',
#   'PART',
#   'VERB',
#   'PRON',
#   'PART',
#   'VERB',
#   'CCONJ',
#   'VERB',
#   'PRON',
#   'PUNCT'],
#  ['CCONJ', 'ADV', 'DET', 'VERB', 'PART', 'ADP', 'NOUN', 'PUNCT'],
#  ['NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PART',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'PART',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PUNCT',
#   'VERB',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PROPN',
#   'PROPN',
#   'PUNCT'],
#  ['VERB',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PROPN',
#   'VERB',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'ADV',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN', 'VERB', 'PUNCT', 'NOUN', 'DET', 'NOUN', 'PUNCT'],
#  ['VERB', 'PRON', 'DET', 'PUNCT'],
#  ['INTJ',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADP',
#   'PUNCT',
#   'ADV',
#   'PRON',
#   'VERB',
#   'VERB',
#   'CCONJ',
#   'VERB',
#   'PRON',
#   'ADP',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'ADV',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'PUNCT',
#   'CCONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'PUNCT',
#   'PART',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADJ',
#   'PUNCT'],
#  ['ADV',
#   'PUNCT',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADP',
#   'PUNCT'],
#  ['ADP', 'DET', 'NOUN', 'PUNCT', 'NOUN', 'PRON', 'VERB', 'VERB', 'PUNCT'],
#  ['CCONJ',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'CCONJ',
#   'VERB',
#   'VERB',
#   'PUNCT'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRON',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'PROPN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'PRON',
#   'PUNCT'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'PART',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PROPN',
#   'PUNCT'],
#  ['INTJ', 'PUNCT'],
#  ['ADV', 'ADV', 'PRON', 'VERB', 'PRON', 'ADP', 'NOUN', 'PUNCT'],
#  ['ADV',
#   'PUNCT',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  ['ADP',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'PUNCT',
#   'ADV',
#   'ADV',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'ADV',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'PROPN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'ADV',
#   'PUNCT'],
#  ['ADP',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'PRON',
#   'PUNCT'],
#  ['CCONJ',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADP',
#   'ADP',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PART',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PROPN',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'PRON',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PUNCT'],
#  ['CCONJ',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'PART',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'PART',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PUNCT'],
#  ['PUNCT',
#   'PROPN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PROPN',
#   'ADP',
#   'DET',
#   'PROPN',
#   'PROPN',
#   'PUNCT'],
#  ['PUNCT', 'PROPN', 'NOUN', 'ADP', 'NUM', 'NOUN', 'PUNCT'],
#  ['PUNCT', 'PROPN', 'NOUN', 'ADP', 'PROPN', 'PUNCT', 'PUNCT'],
#  ['ADP',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'PROPN',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'PART',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PART',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADV',
#   'DET',
#   'VERB',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'PART',
#   'VERB',
#   'PART',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'PUNCT',
#   'ADP',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'PUNCT'],
#  ['PROPN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'PUNCT'],
#  ['ADJ',
#   'DET',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  ['ADV',
#   'DET',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'PUNCT',
#   'ADP',
#   'ADJ',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'PART',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  ['ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'ADP',
#   'PRON',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT']]

# %% [markdown]
# ### Exercise
# Print out the words in the first 10 sentences, but remove all words that are not nouns, verbs, adjectives, adverbs, or proper names.

# %%
# your code here
content_words = [[token.lemma_ for token in nlp(sentence) if token.pos_ in {'NOUN', 'VERB', 'ADJ', 'ADV', 'PROPN'}] for sentence in documents[:10]]
content_words
# Out:
# [['looming'],
#  ['call', 'ishmael'],
#  ['year',
#   'ago',
#   'never',
#   'mind',
#   'how',
#   'long',
#   'precisely',
#   'have',
#   'little',
#   'money',
#   '-PRON-',
#   'purse',
#   'nothing',
#   'particular',
#   'interest',
#   'shore',
#   'think',
#   'would',
#   'sail',
#   'little',
#   'see',
#   'watery',
#   'part',
#   'world'],
#  ['be', 'way', 'have', 'drive', 'spleen', 'regulate', 'circulation'],
#  ['whenever',
#   'find',
#   'grow',
#   'grim',
#   'mouth',
#   'whenever',
#   'be',
#   'damp',
#   'drizzly',
#   'november',
#   '-PRON-',
#   'soul',
#   'whenever',
#   'find',
#   'involuntarily',
#   'pause',
#   'coffin',
#   'warehouse',
#   'bring',
#   'rear',
#   'funeral',
#   'meet',
#   'especially',
#   'whenever',
#   '-PRON-',
#   'hypos',
#   'get',
#   'such',
#   'upper',
#   'hand',
#   'require',
#   'strong',
#   'moral',
#   'principle',
#   'prevent',
#   'deliberately',
#   'step',
#   'street',
#   'methodically',
#   'knock',
#   'people',
#   'hat',
#   'then',
#   'account',
#   'high',
#   'time',
#   'get',
#   'sea',
#   'as',
#   'soon',
#   'can'],
#  ['be', '-PRON-', 'substitute', 'pistol', 'ball'],
#  ['philosophical',
#   'flourish',
#   'cato',
#   'throw',
#   '-PRON-',
#   'sword',
#   'quietly',
#   'take',
#   'ship'],
#  ['there', 'be', 'nothing', 'surprising'],
#  ['know',
#   'almost',
#   'man',
#   '-PRON-',
#   'degree',
#   'time',
#   'other',
#   'cherish',
#   'very',
#   'nearly',
#   'same',
#   'feeling',
#   'ocean'],
#  ['there',
#   'now',
#   'be',
#   '-PRON-',
#   'insular',
#   'city',
#   'manhattoes',
#   'belt',
#   'round',
#   'wharf',
#   'indian',
#   'isle',
#   'coral',
#   'reef',
#   'commerce',
#   'surround',
#   '-PRON-',
#   'surf']]

# %% [markdown]
# ## Named Entities
# For each noun phrase, we can infer the semantic type of it.

# %%
entities = [[(entity.text, entity.label_) 
             for entity in nlp(sentence).ents]
            for sentence in documents[:50]]
entities
# nlp('John gave a book to Mary and Celia in Cardiff').ents
# Out:
# [[],
#  [],
#  [('Some years ago', 'DATE')],
#  [],
#  [('November', 'DATE')],
#  [],
#  [],
#  [],
#  [],
#  [('Indian', 'NORP')],
#  [],
#  [('a few hours', 'TIME')],
#  [],
#  [('Circumambulate', 'ORG'), ('Sabbath', 'ORG'), ('afternoon', 'TIME')],
#  [('Coenties Slip', 'PERSON')],
#  [('thousands upon thousands', 'CARDINAL')],
#  [('China', 'GPE')],
#  [('week days', 'DATE')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('ten to one', 'CARDINAL')],
#  [],
#  [],
#  [('American', 'NORP')],
#  [],
#  [],
#  [('Saco', 'PERSON')],
#  [],
#  [],
#  [],
#  [],
#  [('Prairies', 'ORG'), ('June', 'DATE')],
#  [('Niagara', 'PERSON')],
#  [('Tennessee', 'GPE'), ('two', 'CARDINAL'), ('Rockaway Beach', 'GPE')],
#  [],
#  [('first', 'ORDINAL')],
#  [('Persians', 'NORP')]]

# %% [markdown]
# ### Exercise
# Who are the 5 most frequently named people in the first 500 sentence?

# %%
# your code here
top_5_entities = [entity.text 
                  for sentence in documents[:500]
                  for entity in nlp(sentence).ents
                  if entity.label_ == 'PERSON'
]

Counter(top_5_entities).most_common(5)
# Out:
# [('Queequeg', 12),
#  ('Sal', 3),
#  ('Peter Coffin', 2),
#  ('Spouter', 2),
#  ('Jonah', 2)]

# %% [markdown]
# ### Exercise
#
# Use the text below to extract all entities.
# - Create tuples of `(lemma, NER type)`
# - Collect counts over the tuples
# - Look at the 10 most frequent tuples: how many of them are wrong? Why? Discuss with a neighbor.

# %%
text = """
Seville.
Summers in the flamboyant Andalucían capital often nudge 40C, but spring is a delight, with the parks in bloom and the scent of orange blossom and jasmine in the air. And in Semana Santa (Holy Week, 14-20 April) the streets come alive with floats and processions. There is also the raucous annual Feria de Abril – a week-long fiesta of parades, flamenco and partying long into the night (4-11 May; expect higher hotel prices if you visit then).
Seville is a romantic and energetic place, with sights aplenty, from the Unesco-listed cathedral – the largest Gothic cathedral in the world – to the beautiful Alcázar royal palace. But days here are best spent simply wandering the medieval streets of Santa Cruz and along the river to La Real Maestranza, Spain’s most spectacular bullring.
Seville is the birthplace of tapas and perfect for a foodie break – join a tapas tour (try devoursevillefoodtours.com), or stop at the countless bars for a glass of sherry with local jamón ibérico (check out Bar Las Teresas in Santa Cruz or historic Casa Morales in Constitución). Great food markets include the Feria, the oldest, and the wooden, futuristic-looking Metropol Parasol.
Nightlife is, unsurprisingly, late and lively. For flamenco, try one of the peñas, or flamenco social clubs – Torres Macarena on C/Torrijano, perhaps – with bars open across town until the early hours.
Book it: In an atmospheric 18th-century house, the Hospes Casa del Rey de Baeza is a lovely place to stay in lively Santa Cruz. Doubles from £133 room only, hospes.com
Trieste.
By April, temperatures are on the rise in Trieste and in the late 20s by May. It is far less touristy than the likes of Florence or Rome, and spring sees the city’s lovely restaurants and bars populated almost exclusively by locals.
A city with a proud coffee-drinking culture – Illy has its headquarters here – Trieste has many venerable cafes, including the dazzling mirror-walled Caffè degli Specchi on the Piazza Unità d’Italia – said to be Europe’s biggest seaside piazza – and the elegant Caffè San Marco, which has a good bookshop. James Joyce was a regular when he lived here between 1904-1915. You can learn all about him at the excellent museum, which also has a free, downloadable themed walk on its website (museojoycetrieste.it).
Above Trieste is a vast limestone plateau known as the carso (or karst). Travel up to Villa Opicina on the edge of the region by bus.
There are several trattorie, but for a real treat catch a cab to one of the 30 or so osmize – farm restaurants that sell their wines, cured meats, cheese, honey, fruit and veg; traditionally, they were open eight, 16 or 24 days per year (“osmi” means “eighth” in Slovene) but this now varies – check the app at osmize.com for details.
Book it: Stay at the palatial, seafront Savoia Excelsior Palace, Jan Morris’s pad in her book Trieste and the Meaning of Nowhere. Doubles from £127 room only, starhotelscollezione.com
Belgrade.
As Belgrade shrugs off the snow, cafe tables start colonising the pavements again. Not that Serbia’s capital hibernates during the winter, but spring brings a freshness worth savouring before summer’s 40C heat kicks in.
You feel it especially in Kalemegdan, the huge park and fortress hugging the confluence of the Danube and Sava rivers. Down below are wide riverside paths that offer superb cycling all the way to the attractive suburb of Zemun. Follow the Sava southwards to reach the river island of Ada Ciganlija – open all year round for walks and bike rides and usually warm enough in May for a swim.
Although barely a month goes by without a festival, the pace picks up during spring. The Belgrade Dance Festival attracts dance companies from around the world. Classical guitar gets its own spotlight during the Guitar Art Festivalfrom 12-17 March, and from 26-28 April you can join the Orthodox Easter festivities. The landmark Mikser House in Savamala may have closed, but its Mikser festival still celebrates the best in Balkan design (24-26 May).
With the long-awaited reopening of the National Museum of Serbia and the Museum of Contemporary Art, Belgrade has some cultural heavyweights to add to its dizzyingly varied restaurant scene. Head to the Dorćol district for cheap cocktails in Blaznavac’s psychedelic garden before a Balkan-Mediterranean dinner in cosy Tezga (Strahinjića Bana 82, on Facebook).
Book it: Set in a handsome 1929 villa in Dorćol, Smokvica has six stylish rooms as well as a restaurant with a courtyard garden. Doubles from €70 room only, smokvica.rs
Montpellier.
Montpellier combines easy elegance and a vibrant cultural scene with a youthful buzz – its university, founded in the 13th century, counts radical satirist Rabelais among its alumni and some 60,000 students live here.
The medieval centre is a maze made for wandering, with 16 leafy squares – in spring, all green and abuzz with alfresco cafe life. The vast, pedestrianised Place de la Comédie connects the old town with the striking new Antigone district, replete with modern, neoclassical-style buildings.
For a fine-art foray, head to Musée Fabre – one of the biggest in France – or nearby photography museum Pavillon Populaire. Montpellier boasts the oldest botanical garden in France, too, dating from 1593 and particularly beautiful in April and May. Independent boutiques, opera houses, markets laden with Languedoc produce (look for oysters and asparagus) and great dining options add to the appeal. Le Petit Jardin is a bistro and lovely garden restaurant near the old cathedral.
Beyond the city, discover vineyards like Mas de Daumas Gassac or hike up Pic St-Loup in the Cévennes foothills for views over the coast. The beach and charming seaside town of Palavas-les-Flots is just 10km away – a tram ride or easy cycle (rent bicycles from Ville et Vélo).
Book it: Hotel Le Guilhem is a 16th-century building in the historic centre with cathedral views from its terrace (where breakfast is served, weather permitting). Doubles from £83 room only, leguilhem.com
Berlin.
After a long, cold winter, Berliners waste no time in celebrating the return of the sun, with beer gardens and flea markets reopening all over the city. Try picturesque Cafe Am Neuen Seefor lakeside pizza and beer in the Tiergarten, and hang out with the hipsters along the canal at Berlin’s coolest flohmarkt, surrounded by cherry blossom trees, a charming place to browse and have a couple of beers.
For the best blossom, though, head to one of the trails along the line of the wall, the Mauerweg, near S-bahn Bornholmer Strasse, or Lichterfelde Süd, where the trees were gifted by the Japanese to celebrate German reunification in 1989.
Berlin is set for two big anniversaries this year: it’s 100 years since the Bauhaus was founded and 30 years since the wall came down, so check out events including exhibitions and dances themed around the former (see visitberlin.de for more information) or get a feel for the creative chaos of post-wall Berlin at the multimedia Nineties Berlin exhibition.
Boat tours along the river and canals are superb in spring but, generally, cycling is the best way to get around (many hotels and hostels have their own). And if urban life gets a bit much, do as the Berliners do and head out to one of the many city lakes, such as Schlachtensee or Wannsee, directly accessible by U and S-bahn.
Book it: Boutique Hotel Oderberger in a trendy, central location has doubles from £113, hotel-oderberger.berlin, or try indoor caravanning at Hüttenpalast, doubles from £61 room only, huettenpalast.de
"""

# your code here

# %% [markdown]
# ## Parsing
# For each word, we can extract the word it is grammatically related to, plus the type of the relation.

# %%
[[(c.text, c.head.text, c.dep_) for c in nlp(sentence)] 
 for sentence in documents[:100]]
# Out:
# [[('Loomings', 'Loomings', 'ROOT'), ('.', 'Loomings', 'punct')],
#  [('Call', 'Call', 'ROOT'),
#   ('me', 'Call', 'dobj'),
#   ('Ishmael', 'Call', 'oprd'),
#   ('.', 'Call', 'punct')],
#  [('Some', 'years', 'det'),
#   ('years', 'ago', 'npadvmod'),
#   ('ago', 'mind', 'advmod'),
#   ('--', 'mind', 'punct'),
#   ('never', 'mind', 'neg'),
#   ('mind', 'thought', 'ccomp'),
#   ('how', 'long', 'advmod'),
#   ('long', 'precisely', 'advmod'),
#   ('precisely', 'mind', 'advmod'),
#   ('--', 'mind', 'punct'),
#   ('having', 'mind', 'advcl'),
#   ('little', 'money', 'amod'),
#   ('or', 'little', 'cc'),
#   ('no', 'little', 'conj'),
#   ('money', 'having', 'dobj'),
#   ('in', 'having', 'prep'),
#   ('my', 'purse', 'poss'),
#   ('purse', 'in', 'pobj'),
#   (',', 'having', 'punct'),
#   ('and', 'having', 'cc'),
#   ('nothing', 'having', 'conj'),
#   ('particular', 'nothing', 'amod'),
#   ('to', 'interest', 'aux'),
#   ('interest', 'nothing', 'relcl'),
#   ('me', 'interest', 'dobj'),
#   ('on', 'interest', 'prep'),
#   ('shore', 'on', 'pobj'),
#   (',', 'thought', 'punct'),
#   ('I', 'thought', 'nsubj'),
#   ('thought', 'thought', 'ROOT'),
#   ('I', 'sail', 'nsubj'),
#   ('would', 'sail', 'aux'),
#   ('sail', 'thought', 'ccomp'),
#   ('about', 'little', 'advmod'),
#   ('a', 'little', 'det'),
#   ('little', 'sail', 'dobj'),
#   ('and', 'sail', 'cc'),
#   ('see', 'sail', 'conj'),
#   ('the', 'part', 'det'),
#   ('watery', 'part', 'amod'),
#   ('part', 'see', 'dobj'),
#   ('of', 'part', 'prep'),
#   ('the', 'world', 'det'),
#   ('world', 'of', 'pobj'),
#   ('.', 'thought', 'punct')],
#  [('It', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('a', 'way', 'det'),
#   ('way', 'is', 'attr'),
#   ('I', 'have', 'nsubj'),
#   ('have', 'way', 'relcl'),
#   ('of', 'way', 'prep'),
#   ('driving', 'of', 'pcomp'),
#   ('off', 'driving', 'prt'),
#   ('the', 'spleen', 'det'),
#   ('spleen', 'driving', 'dobj'),
#   ('and', 'driving', 'cc'),
#   ('regulating', 'driving', 'conj'),
#   ('the', 'circulation', 'det'),
#   ('circulation', 'regulating', 'dobj'),
#   ('.', 'is', 'punct')],
#  [('Whenever', 'find', 'advmod'),
#   ('I', 'find', 'nsubj'),
#   ('find', 'drizzly', 'advcl'),
#   ('myself', 'growing', 'nsubj'),
#   ('growing', 'find', 'ccomp'),
#   ('grim', 'growing', 'advmod'),
#   ('about', 'grim', 'prep'),
#   ('the', 'mouth', 'det'),
#   ('mouth', 'about', 'pobj'),
#   (';', 'drizzly', 'punct'),
#   ('whenever', 'is', 'advmod'),
#   ('it', 'is', 'nsubj'),
#   ('is', 'drizzly', 'advcl'),
#   ('a', 'damp', 'det'),
#   ('damp', 'is', 'attr'),
#   (',', 'drizzly', 'punct'),
#   ('drizzly', 'account', 'ccomp'),
#   ('November', 'drizzly', 'npadvmod'),
#   ('in', 'drizzly', 'prep'),
#   ('my', 'soul', 'poss'),
#   ('soul', 'in', 'pobj'),
#   (';', 'account', 'punct'),
#   ('whenever', 'find', 'advmod'),
#   ('I', 'find', 'nsubj'),
#   ('find', 'account', 'advcl'),
#   ('myself', 'pausing', 'nsubj'),
#   ('involuntarily', 'pausing', 'advmod'),
#   ('pausing', 'find', 'ccomp'),
#   ('before', 'pausing', 'prep'),
#   ('coffin', 'warehouses', 'compound'),
#   ('warehouses', 'before', 'pobj'),
#   (',', 'pausing', 'punct'),
#   ('and', 'pausing', 'cc'),
#   ('bringing', 'pausing', 'conj'),
#   ('up', 'bringing', 'prt'),
#   ('the', 'rear', 'det'),
#   ('rear', 'bringing', 'dobj'),
#   ('of', 'rear', 'prep'),
#   ('every', 'funeral', 'det'),
#   ('funeral', 'of', 'pobj'),
#   ('I', 'meet', 'nsubj'),
#   ('meet', 'funeral', 'relcl'),
#   (';', 'find', 'punct'),
#   ('and', 'find', 'cc'),
#   ('especially', 'whenever', 'advmod'),
#   ('whenever', 'get', 'advmod'),
#   ('my', 'hypos', 'poss'),
#   ('hypos', 'get', 'nsubj'),
#   ('get', 'requires', 'advcl'),
#   ('such', 'hand', 'predet'),
#   ('an', 'hand', 'det'),
#   ('upper', 'hand', 'amod'),
#   ('hand', 'get', 'dobj'),
#   ('of', 'hand', 'prep'),
#   ('me', 'of', 'pobj'),
#   (',', 'requires', 'punct'),
#   ('that', 'requires', 'mark'),
#   ('it', 'requires', 'nsubj'),
#   ('requires', 'find', 'conj'),
#   ('a', 'principle', 'det'),
#   ('strong', 'principle', 'amod'),
#   ('moral', 'principle', 'amod'),
#   ('principle', 'requires', 'dobj'),
#   ('to', 'prevent', 'aux'),
#   ('prevent', 'requires', 'xcomp'),
#   ('me', 'prevent', 'dobj'),
#   ('from', 'prevent', 'prep'),
#   ('deliberately', 'stepping', 'advmod'),
#   ('stepping', 'from', 'pcomp'),
#   ('into', 'stepping', 'prep'),
#   ('the', 'street', 'det'),
#   ('street', 'into', 'pobj'),
#   (',', 'requires', 'punct'),
#   ('and', 'requires', 'cc'),
#   ('methodically', 'knocking', 'advmod'),
#   ('knocking', 'requires', 'conj'),
#   ('people', 'hats', 'poss'),
#   ("'", 'people', 'case'),
#   ('s', 'people', 'case'),
#   ('hats', 'knocking', 'dobj'),
#   ('off', 'hats', 'prt'),
#   ('--', 'account', 'punct'),
#   ('then', 'account', 'advmod'),
#   (',', 'account', 'punct'),
#   ('I', 'account', 'nsubj'),
#   ('account', 'account', 'ROOT'),
#   ('it', 'account', 'dobj'),
#   ('high', 'time', 'amod'),
#   ('time', 'account', 'npadvmod'),
#   ('to', 'get', 'aux'),
#   ('get', 'time', 'relcl'),
#   ('to', 'get', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('as', 'soon', 'advmod'),
#   ('soon', 'get', 'advmod'),
#   ('as', 'can', 'mark'),
#   ('I', 'can', 'nsubj'),
#   ('can', 'soon', 'advcl'),
#   ('.', 'account', 'punct')],
#  [('This', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('my', 'substitute', 'poss'),
#   ('substitute', 'is', 'attr'),
#   ('for', 'substitute', 'prep'),
#   ('pistol', 'for', 'pobj'),
#   ('and', 'pistol', 'cc'),
#   ('ball', 'pistol', 'conj'),
#   ('.', 'is', 'punct')],
#  [('With', 'throws', 'prep'),
#   ('a', 'flourish', 'det'),
#   ('philosophical', 'flourish', 'amod'),
#   ('flourish', 'With', 'pobj'),
#   ('Cato', 'throws', 'nsubj'),
#   ('throws', 'take', 'ccomp'),
#   ('himself', 'throws', 'dobj'),
#   ('upon', 'throws', 'prep'),
#   ('his', 'sword', 'poss'),
#   ('sword', 'upon', 'pobj'),
#   (';', 'take', 'punct'),
#   ('I', 'take', 'nsubj'),
#   ('quietly', 'take', 'advmod'),
#   ('take', 'take', 'ROOT'),
#   ('to', 'take', 'prep'),
#   ('the', 'ship', 'det'),
#   ('ship', 'to', 'pobj'),
#   ('.', 'take', 'punct')],
#  [('There', 'is', 'expl'),
#   ('is', 'is', 'ROOT'),
#   ('nothing', 'is', 'attr'),
#   ('surprising', 'nothing', 'amod'),
#   ('in', 'nothing', 'prep'),
#   ('this', 'in', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('If', 'knew', 'mark'),
#   ('they', 'knew', 'nsubj'),
#   ('but', 'they', 'cc'),
#   ('knew', 'cherish', 'advcl'),
#   ('it', 'knew', 'dobj'),
#   (',', 'cherish', 'punct'),
#   ('almost', 'all', 'advmod'),
#   ('all', 'men', 'nummod'),
#   ('men', 'cherish', 'nsubj'),
#   ('in', 'men', 'prep'),
#   ('their', 'degree', 'poss'),
#   ('degree', 'in', 'pobj'),
#   (',', 'men', 'punct'),
#   ('some', 'time', 'det'),
#   ('time', 'men', 'conj'),
#   ('or', 'time', 'cc'),
#   ('other', 'time', 'conj'),
#   (',', 'cherish', 'punct'),
#   ('cherish', 'cherish', 'ROOT'),
#   ('very', 'nearly', 'advmod'),
#   ('nearly', 'feelings', 'advmod'),
#   ('the', 'feelings', 'det'),
#   ('same', 'feelings', 'amod'),
#   ('feelings', 'cherish', 'dobj'),
#   ('towards', 'feelings', 'prep'),
#   ('the', 'ocean', 'det'),
#   ('ocean', 'towards', 'pobj'),
#   ('with', 'feelings', 'prep'),
#   ('me', 'with', 'pobj'),
#   ('.', 'cherish', 'punct')],
#  [('There', 'is', 'expl'),
#   ('now', 'is', 'advmod'),
#   ('is', 'is', 'ROOT'),
#   ('your', 'city', 'poss'),
#   ('insular', 'city', 'amod'),
#   ('city', 'is', 'attr'),
#   ('of', 'city', 'prep'),
#   ('the', 'Manhattoes', 'det'),
#   ('Manhattoes', 'of', 'pobj'),
#   (',', 'is', 'punct'),
#   ('belted', 'is', 'conj'),
#   ('round', 'belted', 'advmod'),
#   ('by', 'belted', 'agent'),
#   ('wharves', 'by', 'pobj'),
#   ('as', 'belted', 'prep'),
#   ('Indian', 'isles', 'amod'),
#   ('isles', 'as', 'pobj'),
#   ('by', 'isles', 'prep'),
#   ('coral', 'reefs', 'amod'),
#   ('reefs', 'by', 'pobj'),
#   ('--', 'belted', 'punct'),
#   ('commerce', 'surrounds', 'nsubj'),
#   ('surrounds', 'belted', 'conj'),
#   ('it', 'surrounds', 'dobj'),
#   ('with', 'surrounds', 'prep'),
#   ('her', 'surf', 'poss'),
#   ('surf', 'with', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('Right', 'take', 'intj'),
#   ('and', 'Right', 'cc'),
#   ('left', 'Right', 'conj'),
#   (',', 'take', 'punct'),
#   ('the', 'streets', 'det'),
#   ('streets', 'take', 'nsubj'),
#   ('take', 'take', 'ROOT'),
#   ('you', 'take', 'dobj'),
#   ('waterward', 'take', 'oprd'),
#   ('.', 'take', 'punct')],
#  [('Its', 'downtown', 'poss'),
#   ('extreme', 'downtown', 'amod'),
#   ('downtown', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('the', 'battery', 'det'),
#   ('battery', 'is', 'attr'),
#   (',', 'battery', 'punct'),
#   ('where', 'washed', 'advmod'),
#   ('that', 'mole', 'det'),
#   ('noble', 'mole', 'amod'),
#   ('mole', 'washed', 'nsubjpass'),
#   ('is', 'washed', 'auxpass'),
#   ('washed', 'battery', 'relcl'),
#   ('by', 'washed', 'agent'),
#   ('waves', 'by', 'pobj'),
#   (',', 'washed', 'punct'),
#   ('and', 'washed', 'cc'),
#   ('cooled', 'washed', 'conj'),
#   ('by', 'cooled', 'agent'),
#   ('breezes', 'by', 'pobj'),
#   (',', 'breezes', 'punct'),
#   ('which', 'previous', 'nsubj'),
#   ('a', 'few', 'quantmod'),
#   ('few', 'hours', 'amod'),
#   ('hours', 'previous', 'npadvmod'),
#   ('previous', 'breezes', 'relcl'),
#   ('were', 'is', 'advcl'),
#   ('out', 'were', 'prep'),
#   ('of', 'out', 'prep'),
#   ('sight', 'of', 'pobj'),
#   ('of', 'sight', 'prep'),
#   ('land', 'of', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('Look', 'Look', 'ROOT'),
#   ('at', 'Look', 'prep'),
#   ('the', 'crowds', 'det'),
#   ('crowds', 'at', 'pobj'),
#   ('of', 'crowds', 'prep'),
#   ('water', 'gazers', 'compound'),
#   ('-', 'gazers', 'punct'),
#   ('gazers', 'of', 'pobj'),
#   ('there', 'gazers', 'advmod'),
#   ('.', 'Look', 'punct')],
#  [('Circumambulate', 'Circumambulate', 'ROOT'),
#   ('the', 'city', 'det'),
#   ('city', 'Circumambulate', 'dobj'),
#   ('of', 'city', 'prep'),
#   ('a', 'dreamy', 'det'),
#   ('dreamy', 'of', 'pobj'),
#   ('Sabbath', 'afternoon', 'compound'),
#   ('afternoon', 'Circumambulate', 'npadvmod'),
#   ('.', 'Circumambulate', 'punct')],
#  [('Go', 'Go', 'ROOT'),
#   ('from', 'Go', 'prep'),
#   ('Corlears', 'Hook', 'compound'),
#   ('Hook', 'from', 'pobj'),
#   ('to', 'Go', 'prep'),
#   ('Coenties', 'Slip', 'compound'),
#   ('Slip', 'to', 'pobj'),
#   (',', 'Go', 'punct'),
#   ('and', 'Go', 'cc'),
#   ('from', 'Go', 'conj'),
#   ('thence', 'from', 'pobj'),
#   (',', 'from', 'punct'),
#   ('by', 'from', 'conj'),
#   ('Whitehall', 'by', 'pobj'),
#   (',', 'Whitehall', 'punct'),
#   ('northward', 'Whitehall', 'amod'),
#   ('.', 'Go', 'punct')],
#  [('What', 'see', 'dobj'),
#   ('do', 'see', 'aux'),
#   ('you', 'see', 'nsubj'),
#   ('see', 'see', 'ROOT'),
#   ('?', 'see', 'punct'),
#   ('--', 'stand', 'punct'),
#   ('Posted', 'stand', 'advcl'),
#   ('like', 'Posted', 'prep'),
#   ('silent', 'sentinels', 'amod'),
#   ('sentinels', 'like', 'pobj'),
#   ('all', 'around', 'advmod'),
#   ('around', 'sentinels', 'prep'),
#   ('the', 'town', 'det'),
#   ('town', 'around', 'pobj'),
#   (',', 'stand', 'punct'),
#   ('stand', 'stand', 'ROOT'),
#   ('thousands', 'stand', 'npadvmod'),
#   ('upon', 'stand', 'prep'),
#   ('thousands', 'upon', 'pobj'),
#   ('of', 'thousands', 'prep'),
#   ('mortal', 'men', 'amod'),
#   ('men', 'of', 'pobj'),
#   ('fixed', 'men', 'acl'),
#   ('in', 'fixed', 'prep'),
#   ('ocean', 'reveries', 'compound'),
#   ('reveries', 'in', 'pobj'),
#   ('.', 'stand', 'punct')],
#  [('Some', 'high', 'dep'),
#   ('leaning', 'Some', 'acl'),
#   ('against', 'leaning', 'prep'),
#   ('the', 'spiles', 'det'),
#   ('spiles', 'against', 'pobj'),
#   (';', 'high', 'punct'),
#   ('some', 'high', 'dep'),
#   ('seated', 'some', 'acl'),
#   ('upon', 'seated', 'prep'),
#   ('the', 'heads', 'det'),
#   ('pier', 'heads', 'compound'),
#   ('-', 'heads', 'punct'),
#   ('heads', 'upon', 'pobj'),
#   (';', 'high', 'punct'),
#   ('some', 'high', 'dep'),
#   ('looking', 'some', 'acl'),
#   ('over', 'looking', 'prep'),
#   ('the', 'bulwarks', 'det'),
#   ('bulwarks', 'over', 'pobj'),
#   ('of', 'bulwarks', 'prep'),
#   ('ships', 'of', 'pobj'),
#   ('from', 'ships', 'prep'),
#   ('China', 'from', 'pobj'),
#   (';', 'high', 'punct'),
#   ('some', 'high', 'nsubj'),
#   ('high', 'high', 'ROOT'),
#   ('aloft', 'high', 'advmod'),
#   ('in', 'aloft', 'prep'),
#   ('the', 'rigging', 'det'),
#   ('rigging', 'in', 'pobj'),
#   (',', 'high', 'punct'),
#   ('as', 'striving', 'mark'),
#   ('if', 'striving', 'mark'),
#   ('striving', 'high', 'advcl'),
#   ('to', 'get', 'aux'),
#   ('get', 'striving', 'xcomp'),
#   ('a', 'peep', 'det'),
#   ('still', 'better', 'advmod'),
#   ('better', 'peep', 'amod'),
#   ('seaward', 'peep', 'amod'),
#   ('peep', 'get', 'dobj'),
#   ('.', 'high', 'punct')],
#  [('But', 'are', 'cc'),
#   ('these', 'are', 'nsubj'),
#   ('are', 'tied', 'ccomp'),
#   ('all', 'are', 'dep'),
#   ('landsmen', 'are', 'attr'),
#   (';', 'are', 'punct'),
#   ('of', 'tied', 'prep'),
#   ('week', 'days', 'compound'),
#   ('days', 'of', 'pobj'),
#   ('pent', 'of', 'pobj'),
#   ('up', 'pent', 'prt'),
#   ('in', 'pent', 'prep'),
#   ('lath', 'in', 'pobj'),
#   ('and', 'lath', 'cc'),
#   ('plaster', 'lath', 'conj'),
#   ('--', 'pent', 'punct'),
#   ('tied', 'tied', 'ROOT'),
#   ('to', 'tied', 'prep'),
#   ('counters', 'to', 'pobj'),
#   (',', 'tied', 'punct'),
#   ('nailed', 'tied', 'conj'),
#   ('to', 'nailed', 'prep'),
#   ('benches', 'to', 'pobj'),
#   (',', 'nailed', 'punct'),
#   ('clinched', 'nailed', 'conj'),
#   ('to', 'clinched', 'prep'),
#   ('desks', 'to', 'pobj'),
#   ('.', 'tied', 'punct')],
#  [('How', 'is', 'advmod'),
#   ('then', 'is', 'advmod'),
#   ('is', 'is', 'ROOT'),
#   ('this', 'is', 'nsubj'),
#   ('?', 'is', 'punct')],
#  [('Are', 'gone', 'auxpass'),
#   ('the', 'fields', 'det'),
#   ('green', 'fields', 'amod'),
#   ('fields', 'gone', 'nsubj'),
#   ('gone', 'gone', 'ROOT'),
#   ('?', 'gone', 'punct')],
#  [('What', 'do', 'nsubj'),
#   ('do', 'do', 'ROOT'),
#   ('they', 'do', 'nsubj'),
#   ('here', 'do', 'advmod'),
#   ('?', 'do', 'punct')],
#  [('But', 'look', 'cc'), ('look', 'look', 'ROOT'), ('!', 'look', 'punct')],
#  [('here', 'come', 'advmod'),
#   ('come', 'come', 'ROOT'),
#   ('more', 'crowds', 'amod'),
#   ('crowds', 'come', 'nsubj'),
#   (',', 'come', 'punct'),
#   ('pacing', 'come', 'advcl'),
#   ('straight', 'pacing', 'advmod'),
#   ('for', 'pacing', 'prep'),
#   ('the', 'water', 'det'),
#   ('water', 'for', 'pobj'),
#   (',', 'pacing', 'punct'),
#   ('and', 'pacing', 'cc'),
#   ('seemingly', 'bound', 'advmod'),
#   ('bound', 'pacing', 'conj'),
#   ('for', 'bound', 'prep'),
#   ('a', 'dive', 'det'),
#   ('dive', 'for', 'pobj'),
#   ('.', 'come', 'punct')],
#  [('Strange', 'Strange', 'ROOT'), ('!', 'Strange', 'punct')],
#  [('Nothing', 'content', 'nsubj'),
#   ('will', 'content', 'aux'),
#   ('content', 'content', 'ROOT'),
#   ('them', 'content', 'dobj'),
#   ('but', 'content', 'cc'),
#   ('the', 'limit', 'det'),
#   ('extremest', 'limit', 'compound'),
#   ('limit', 'suffice', 'nsubj'),
#   ('of', 'limit', 'prep'),
#   ('the', 'land', 'det'),
#   ('land', 'of', 'pobj'),
#   (';', 'limit', 'punct'),
#   ('loitering', 'suffice', 'csubj'),
#   ('under', 'loitering', 'prep'),
#   ('the', 'lee', 'det'),
#   ('shady', 'lee', 'amod'),
#   ('lee', 'under', 'pobj'),
#   ('of', 'lee', 'prep'),
#   ('yonder', 'warehouses', 'compound'),
#   ('warehouses', 'of', 'pobj'),
#   ('will', 'suffice', 'aux'),
#   ('not', 'suffice', 'neg'),
#   ('suffice', 'content', 'conj'),
#   ('.', 'suffice', 'punct')],
#  [('No', 'No', 'ROOT'), ('.', 'No', 'punct')],
#  [('They', 'get', 'nsubj'),
#   ('must', 'get', 'aux'),
#   ('get', 'get', 'ROOT'),
#   ('just', 'nigh', 'advmod'),
#   ('as', 'nigh', 'advmod'),
#   ('nigh', 'water', 'amod'),
#   ('the', 'water', 'det'),
#   ('water', 'get', 'dobj'),
#   ('as', 'can', 'mark'),
#   ('they', 'can', 'nsubj'),
#   ('possibly', 'can', 'advmod'),
#   ('can', 'get', 'advcl'),
#   ('without', 'can', 'prep'),
#   ('falling', 'without', 'pcomp'),
#   ('in', 'falling', 'prt'),
#   ('.', 'get', 'punct')],
#  [('And', 'stand', 'cc'),
#   ('there', 'stand', 'advmod'),
#   ('they', 'stand', 'nsubj'),
#   ('stand', 'leagues', 'ccomp'),
#   ('--', 'stand', 'punct'),
#   ('miles', 'stand', 'npadvmod'),
#   ('of', 'miles', 'prep'),
#   ('them', 'of', 'pobj'),
#   ('--', 'stand', 'punct'),
#   ('leagues', 'leagues', 'ROOT'),
#   ('.', 'leagues', 'punct')],
#  [('Inlanders', 'come', 'npadvmod'),
#   ('all', 'Inlanders', 'appos'),
#   (',', 'come', 'punct'),
#   ('they', 'come', 'nsubj'),
#   ('come', 'come', 'ROOT'),
#   ('from', 'come', 'prep'),
#   ('lanes', 'from', 'pobj'),
#   ('and', 'lanes', 'cc'),
#   ('alleys', 'lanes', 'conj'),
#   (',', 'lanes', 'punct'),
#   ('streets', 'lanes', 'conj'),
#   ('and', 'streets', 'cc'),
#   ('avenues', 'streets', 'conj'),
#   ('--', 'lanes', 'punct'),
#   ('north', 'lanes', 'appos'),
#   (',', 'north', 'punct'),
#   ('east', 'north', 'conj'),
#   (',', 'east', 'punct'),
#   ('south', 'east', 'conj'),
#   (',', 'south', 'punct'),
#   ('and', 'south', 'cc'),
#   ('west', 'south', 'conj'),
#   ('.', 'come', 'punct')],
#  [('Yet', 'unite', 'advmod'),
#   ('here', 'unite', 'advmod'),
#   ('they', 'unite', 'nsubj'),
#   ('all', 'they', 'appos'),
#   ('unite', 'unite', 'ROOT'),
#   ('.', 'unite', 'punct')],
#  [('Tell', 'Tell', 'ROOT'),
#   ('me', 'Tell', 'dobj'),
#   (',', 'Tell', 'punct'),
#   ('does', 'attract', 'aux'),
#   ('the', 'virtue', 'det'),
#   ('magnetic', 'virtue', 'amod'),
#   ('virtue', 'attract', 'nsubj'),
#   ('of', 'virtue', 'prep'),
#   ('the', 'needles', 'det'),
#   ('needles', 'of', 'pobj'),
#   ('of', 'needles', 'prep'),
#   ('the', 'compasses', 'det'),
#   ('compasses', 'of', 'pobj'),
#   ('of', 'compasses', 'prep'),
#   ('all', 'ships', 'predet'),
#   ('those', 'ships', 'det'),
#   ('ships', 'of', 'pobj'),
#   ('attract', 'Tell', 'ccomp'),
#   ('them', 'attract', 'dobj'),
#   ('thither', 'attract', 'advmod'),
#   ('?', 'Tell', 'punct')],
#  [('Once', 'more', 'advmod'),
#   ('more', 'more', 'ROOT'),
#   ('.', 'more', 'punct')],
#  [('Say', 'Say', 'ROOT'),
#   ('you', 'are', 'nsubj'),
#   ('are', 'Say', 'ccomp'),
#   ('in', 'are', 'prep'),
#   ('the', 'country', 'det'),
#   ('country', 'in', 'pobj'),
#   (';', 'Say', 'punct'),
#   ('in', 'Say', 'prep'),
#   ('some', 'land', 'det'),
#   ('high', 'land', 'amod'),
#   ('land', 'in', 'pobj'),
#   ('of', 'land', 'prep'),
#   ('lakes', 'of', 'pobj'),
#   ('.', 'Say', 'punct')],
#  [('Take', 'Take', 'ROOT'),
#   ('almost', 'any', 'advmod'),
#   ('any', 'path', 'det'),
#   ('path', 'Take', 'dobj'),
#   ('you', 'please', 'nsubj'),
#   ('please', 'Take', 'parataxis'),
#   (',', 'Take', 'punct'),
#   ('and', 'Take', 'cc'),
#   ('ten', 'Take', 'conj'),
#   ('to', 'ten', 'prep'),
#   ('one', 'to', 'pobj'),
#   ('it', 'carries', 'nsubj'),
#   ('carries', 'Take', 'conj'),
#   ('you', 'carries', 'dobj'),
#   ('down', 'carries', 'prt'),
#   ('in', 'carries', 'prep'),
#   ('a', 'dale', 'det'),
#   ('dale', 'in', 'pobj'),
#   (',', 'carries', 'punct'),
#   ('and', 'carries', 'cc'),
#   ('leaves', 'carries', 'conj'),
#   ('you', 'leaves', 'dobj'),
#   ('there', 'leaves', 'advmod'),
#   ('by', 'leaves', 'prep'),
#   ('a', 'pool', 'det'),
#   ('pool', 'by', 'pobj'),
#   ('in', 'pool', 'prep'),
#   ('the', 'stream', 'det'),
#   ('stream', 'in', 'pobj'),
#   ('.', 'Take', 'punct')],
#  [('There', 'is', 'expl'),
#   ('is', 'is', 'ROOT'),
#   ('magic', 'is', 'attr'),
#   ('in', 'is', 'prep'),
#   ('it', 'in', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('Let', 'Let', 'ROOT'),
#   ('the', 'minded', 'det'),
#   ('most', 'minded', 'amod'),
#   ('absent', 'minded', 'amod'),
#   ('-', 'minded', 'punct'),
#   ('minded', 'plunged', 'nsubjpass'),
#   ('of', 'minded', 'prep'),
#   ('men', 'of', 'pobj'),
#   ('be', 'plunged', 'auxpass'),
#   ('plunged', 'Let', 'ccomp'),
#   ('in', 'plunged', 'prep'),
#   ('his', 'reveries', 'poss'),
#   ('deepest', 'reveries', 'amod'),
#   ('reveries', 'in', 'pobj'),
#   ('--', 'plunged', 'punct'),
#   ('stand', 'Let', 'ccomp'),
#   ('that', 'man', 'det'),
#   ('man', 'set', 'nsubj'),
#   ('on', 'man', 'prep'),
#   ('his', 'legs', 'poss'),
#   ('legs', 'on', 'pobj'),
#   (',', 'set', 'punct'),
#   ('set', 'stand', 'ccomp'),
#   ('his', 'feet', 'poss'),
#   ('feet', 'set', 'dobj'),
#   ('a', 'going', 'det'),
#   ('-', 'going', 'punct'),
#   ('going', 'set', 'dobj'),
#   (',', 'set', 'punct'),
#   ('and', 'set', 'cc'),
#   ('he', 'lead', 'nsubj'),
#   ('will', 'lead', 'aux'),
#   ('infallibly', 'lead', 'advmod'),
#   ('lead', 'set', 'conj'),
#   ('you', 'lead', 'dobj'),
#   ('to', 'lead', 'prep'),
#   ('water', 'to', 'pobj'),
#   (',', 'lead', 'punct'),
#   ('if', 'be', 'mark'),
#   ('water', 'be', 'nsubj'),
#   ('there', 'be', 'expl'),
#   ('be', 'lead', 'advcl'),
#   ('in', 'be', 'prep'),
#   ('all', 'region', 'predet'),
#   ('that', 'region', 'det'),
#   ('region', 'in', 'pobj'),
#   ('.', 'lead', 'punct')],
#  [('Should', 'be', 'aux'),
#   ('you', 'be', 'nsubj'),
#   ('ever', 'be', 'advmod'),
#   ('be', 'try', 'advcl'),
#   ('athirst', 'be', 'acomp'),
#   ('in', 'be', 'prep'),
#   ('the', 'desert', 'det'),
#   ('great', 'desert', 'amod'),
#   ('American', 'desert', 'amod'),
#   ('desert', 'in', 'pobj'),
#   (',', 'be', 'punct'),
#   ('try', 'try', 'ROOT'),
#   ('this', 'experiment', 'det'),
#   ('experiment', 'try', 'dobj'),
#   (',', 'try', 'punct'),
#   ('if', 'happen', 'mark'),
#   ('your', 'caravan', 'poss'),
#   ('caravan', 'happen', 'nsubj'),
#   ('happen', 'try', 'advcl'),
#   ('to', 'supplied', 'aux'),
#   ('be', 'supplied', 'auxpass'),
#   ('supplied', 'happen', 'xcomp'),
#   ('with', 'supplied', 'prep'),
#   ('a', 'professor', 'det'),
#   ('metaphysical', 'professor', 'amod'),
#   ('professor', 'with', 'pobj'),
#   ('.', 'try', 'punct')],
#  [('Yes', 'wedded', 'intj'),
#   (',', 'wedded', 'punct'),
#   ('as', 'knows', 'mark'),
#   ('every', 'one', 'det'),
#   ('one', 'knows', 'nsubj'),
#   ('knows', 'wedded', 'advcl'),
#   (',', 'wedded', 'punct'),
#   ('meditation', 'wedded', 'nsubjpass'),
#   ('and', 'meditation', 'cc'),
#   ('water', 'meditation', 'conj'),
#   ('are', 'wedded', 'auxpass'),
#   ('wedded', 'wedded', 'ROOT'),
#   ('for', 'wedded', 'prep'),
#   ('ever', 'for', 'pcomp'),
#   ('.', 'wedded', 'punct')],
#  [('But', 'is', 'cc'),
#   ('here', 'is', 'advmod'),
#   ('is', 'is', 'ROOT'),
#   ('an', 'artist', 'det'),
#   ('artist', 'is', 'attr'),
#   ('.', 'is', 'punct')],
#  [('He', 'desires', 'nsubj'),
#   ('desires', 'desires', 'ROOT'),
#   ('to', 'paint', 'aux'),
#   ('paint', 'desires', 'xcomp'),
#   ('you', 'paint', 'dative'),
#   ('the', 'bit', 'det'),
#   ('dreamiest', 'bit', 'amod'),
#   (',', 'bit', 'punct'),
#   ('shadiest', 'bit', 'amod'),
#   (',', 'shadiest', 'punct'),
#   ('quietest', 'shadiest', 'conj'),
#   (',', 'bit', 'punct'),
#   ('most', 'enchanting', 'advmod'),
#   ('enchanting', 'bit', 'amod'),
#   ('bit', 'paint', 'dobj'),
#   ('of', 'bit', 'prep'),
#   ('romantic', 'landscape', 'amod'),
#   ('landscape', 'of', 'pobj'),
#   ('in', 'bit', 'prep'),
#   ('all', 'valley', 'predet'),
#   ('the', 'valley', 'det'),
#   ('valley', 'in', 'pobj'),
#   ('of', 'valley', 'prep'),
#   ('the', 'Saco', 'det'),
#   ('Saco', 'of', 'pobj'),
#   ('.', 'desires', 'punct')],
#  [('What', 'is', 'attr'),
#   ('is', 'is', 'ROOT'),
#   ('the', 'element', 'det'),
#   ('chief', 'element', 'amod'),
#   ('element', 'is', 'nsubj'),
#   ('he', 'employs', 'nsubj'),
#   ('employs', 'element', 'relcl'),
#   ('?', 'is', 'punct')],
#  [('There', 'stand', 'expl'),
#   ('stand', 'stand', 'ROOT'),
#   ('his', 'trees', 'poss'),
#   ('trees', 'stand', 'dobj'),
#   (',', 'stand', 'punct'),
#   ('each', 'stand', 'npadvmod'),
#   ('with', 'each', 'prep'),
#   ('a', 'trunk', 'det'),
#   ('hollow', 'trunk', 'amod'),
#   ('trunk', 'with', 'pobj'),
#   (',', 'stand', 'punct'),
#   ('as', 'were', 'mark'),
#   ('if', 'were', 'mark'),
#   ('a', 'hermit', 'det'),
#   ('hermit', 'were', 'nsubj'),
#   ('and', 'hermit', 'cc'),
#   ('a', 'crucifix', 'det'),
#   ('crucifix', 'hermit', 'conj'),
#   ('were', 'stand', 'advcl'),
#   ('within', 'were', 'advmod'),
#   (';', 'stand', 'punct'),
#   ('and', 'stand', 'cc'),
#   ('here', 'sleeps', 'advmod'),
#   ('sleeps', 'stand', 'conj'),
#   ('his', 'meadow', 'poss'),
#   ('meadow', 'sleeps', 'dobj'),
#   (',', 'sleeps', 'punct'),
#   ('and', 'sleeps', 'cc'),
#   ('there', 'sleep', 'expl'),
#   ('sleep', 'sleeps', 'conj'),
#   ('his', 'cattle', 'poss'),
#   ('cattle', 'sleep', 'dobj'),
#   (';', 'sleep', 'punct'),
#   ('and', 'sleep', 'cc'),
#   ('up', 'goes', 'prep'),
#   ('from', 'up', 'prep'),
#   ('yonder', 'cottage', 'compound'),
#   ('cottage', 'from', 'pobj'),
#   ('goes', 'sleep', 'conj'),
#   ('a', 'smoke', 'det'),
#   ('sleepy', 'smoke', 'amod'),
#   ('smoke', 'goes', 'dobj'),
#   ('.', 'sleeps', 'punct')],
#  [('Deep', 'winds', 'advmod'),
#   ('into', 'Deep', 'prep'),
#   ('distant', 'woodlands', 'amod'),
#   ('woodlands', 'into', 'pobj'),
#   ('winds', 'winds', 'ROOT'),
#   ('a', 'way', 'det'),
#   ('mazy', 'way', 'amod'),
#   ('way', 'winds', 'npadvmod'),
#   (',', 'winds', 'punct'),
#   ('reaching', 'winds', 'advcl'),
#   ('to', 'reaching', 'prep'),
#   ('overlapping', 'spurs', 'amod'),
#   ('spurs', 'to', 'pobj'),
#   ('of', 'spurs', 'prep'),
#   ('mountains', 'of', 'pobj'),
#   ('bathed', 'spurs', 'acl'),
#   ('in', 'bathed', 'prep'),
#   ('their', 'blue', 'poss'),
#   ('hill', 'side', 'compound'),
#   ('-', 'side', 'punct'),
#   ('side', 'blue', 'compound'),
#   ('blue', 'in', 'pobj'),
#   ('.', 'winds', 'punct')],
#  [('But', 'tranced', 'cc'),
#   ('though', 'lies', 'mark'),
#   ('the', 'picture', 'det'),
#   ('picture', 'lies', 'nsubj'),
#   ('lies', 'tranced', 'advcl'),
#   ('thus', 'tranced', 'advmod'),
#   ('tranced', 'tranced', 'ROOT'),
#   (',', 'tranced', 'punct'),
#   ('and', 'tranced', 'cc'),
#   ('though', 'shakes', 'mark'),
#   ('this', 'tree', 'det'),
#   ('pine', 'tree', 'compound'),
#   ('-', 'tree', 'punct'),
#   ('tree', 'shakes', 'nsubj'),
#   ('shakes', 'tranced', 'conj'),
#   ('down', 'shakes', 'prt'),
#   ('its', 'sighs', 'poss'),
#   ('sighs', 'shakes', 'dobj'),
#   ('like', 'shakes', 'prep'),
#   ('leaves', 'like', 'pobj'),
#   ('upon', 'leaves', 'prep'),
#   ('this', 'shepherd', 'det'),
#   ('shepherd', 'head', 'poss'),
#   ("'", 'shepherd', 'punct'),
#   ('s', 'shepherd', 'case'),
#   ('head', 'upon', 'pobj'),
#   (',', 'shakes', 'punct'),
#   ('yet', 'shakes', 'cc'),
#   ('all', 'were', 'nsubj'),
#   ('were', 'shakes', 'conj'),
#   ('vain', 'were', 'acomp'),
#   (',', 'were', 'punct'),
#   ('unless', 'fixed', 'mark'),
#   ('the', 'shepherd', 'det'),
#   ('shepherd', 'eye', 'poss'),
#   ("'", 'shepherd', 'punct'),
#   ('s', 'shepherd', 'case'),
#   ('eye', 'fixed', 'nsubjpass'),
#   ('were', 'fixed', 'auxpass'),
#   ('fixed', 'were', 'advcl'),
#   ('upon', 'fixed', 'prep'),
#   ('the', 'stream', 'det'),
#   ('magic', 'stream', 'amod'),
#   ('stream', 'upon', 'pobj'),
#   ('before', 'stream', 'prep'),
#   ('him', 'before', 'pobj'),
#   ('.', 'tranced', 'punct')],
#  [('Go', 'Go', 'ROOT'),
#   ('visit', 'Go', 'advcl'),
#   ('the', 'Prairies', 'det'),
#   ('Prairies', 'visit', 'dobj'),
#   ('in', 'visit', 'prep'),
#   ('June', 'in', 'pobj'),
#   (',', 'June', 'punct'),
#   ('when', 'for', 'advmod'),
#   ('for', 'Go', 'advcl'),
#   ('scores', 'for', 'pobj'),
#   ('on', 'scores', 'prep'),
#   ('scores', 'on', 'pobj'),
#   ('of', 'scores', 'prep'),
#   ('miles', 'of', 'pobj'),
#   ('you', 'wade', 'nsubj'),
#   ('wade', 'wade', 'ROOT'),
#   ('knee', 'deep', 'npadvmod'),
#   ('-', 'deep', 'punct'),
#   ('deep', 'wade', 'advmod'),
#   ('among', 'deep', 'prep'),
#   ('Tiger', 'lilies', 'compound'),
#   ('-', 'lilies', 'punct'),
#   ('lilies', 'among', 'pobj'),
#   ('--', 'is', 'punct'),
#   ('what', 'is', 'attr'),
#   ('is', 'wade', 'parataxis'),
#   ('the', 'wanting', 'det'),
#   ('one', 'wanting', 'nummod'),
#   ('charm', 'wanting', 'compound'),
#   ('wanting', 'is', 'nsubj'),
#   ('?', 'is', 'punct'),
#   ('--', 'is', 'punct'),
#   ('Water', 'is', 'dep'),
#   ('--', 'is', 'punct'),
#   ('there', 'is', 'expl'),
#   ('is', 'is', 'ROOT'),
#   ('not', 'is', 'neg'),
#   ('a', 'drop', 'det'),
#   ('drop', 'is', 'attr'),
#   ('of', 'drop', 'prep'),
#   ('water', 'of', 'pobj'),
#   ('there', 'drop', 'advmod'),
#   ('!', 'is', 'punct')],
#  [('Were', 'travel', 'advcl'),
#   ('Niagara', 'Were', 'nsubj'),
#   ('but', 'Niagara', 'cc'),
#   ('a', 'cataract', 'det'),
#   ('cataract', 'Niagara', 'conj'),
#   ('of', 'cataract', 'prep'),
#   ('sand', 'of', 'pobj'),
#   (',', 'travel', 'punct'),
#   ('would', 'travel', 'aux'),
#   ('you', 'travel', 'nsubj'),
#   ('travel', 'travel', 'ROOT'),
#   ('your', 'miles', 'poss'),
#   ('thousand', 'miles', 'nummod'),
#   ('miles', 'travel', 'dobj'),
#   ('to', 'see', 'aux'),
#   ('see', 'travel', 'advcl'),
#   ('it', 'see', 'dobj'),
#   ('?', 'travel', 'punct')],
#  [('Why', 'deliberate', 'advmod'),
#   ('did', 'deliberate', 'aux'),
#   ('the', 'poet', 'det'),
#   ('poor', 'poet', 'amod'),
#   ('poet', 'deliberate', 'nsubj'),
#   ('of', 'poet', 'prep'),
#   ('Tennessee', 'of', 'pobj'),
#   (',', 'deliberate', 'punct'),
#   ('upon', 'deliberate', 'prep'),
#   ('suddenly', 'receiving', 'advmod'),
#   ('receiving', 'upon', 'pcomp'),
#   ('two', 'handfuls', 'nummod'),
#   ('handfuls', 'receiving', 'dobj'),
#   ('of', 'handfuls', 'prep'),
#   ('silver', 'of', 'pobj'),
#   (',', 'deliberate', 'punct'),
#   ('deliberate', 'deliberate', 'ROOT'),
#   ('whether', 'buy', 'mark'),
#   ('to', 'buy', 'aux'),
#   ('buy', 'deliberate', 'advcl'),
#   ('him', 'buy', 'dative'),
#   ('a', 'coat', 'det'),
#   ('coat', 'buy', 'dobj'),
#   (',', 'coat', 'punct'),
#   ('which', 'needed', 'dobj'),
#   ('he', 'needed', 'nsubj'),
#   ('sadly', 'needed', 'advmod'),
#   ('needed', 'coat', 'relcl'),
#   (',', 'needed', 'punct'),
#   ('or', 'needed', 'cc'),
#   ('invest', 'needed', 'conj'),
#   ('his', 'money', 'poss'),
#   ('money', 'invest', 'dobj'),
#   ('in', 'invest', 'prep'),
#   ('a', 'trip', 'det'),
#   ('pedestrian', 'trip', 'compound'),
#   ('trip', 'in', 'pobj'),
#   ('to', 'trip', 'prep'),
#   ('Rockaway', 'Beach', 'compound'),
#   ('Beach', 'to', 'pobj'),
#   ('?', 'deliberate', 'punct')],
#  [('Why', 'is', 'advmod'),
#   ('is', 'is', 'ROOT'),
#   ('almost', 'every', 'advmod'),
#   ('every', 'boy', 'nummod'),
#   ('robust', 'boy', 'amod'),
#   ('healthy', 'boy', 'amod'),
#   ('boy', 'is', 'attr'),
#   ('with', 'boy', 'prep'),
#   ('a', 'soul', 'det'),
#   ('robust', 'soul', 'amod'),
#   ('healthy', 'soul', 'amod'),
#   ('soul', 'with', 'pobj'),
#   ('in', 'soul', 'prep'),
#   ('him', 'in', 'pobj'),
#   (',', 'is', 'punct'),
#   ('at', 'is', 'prep'),
#   ('some', 'time', 'det'),
#   ('time', 'at', 'pobj'),
#   ('or', 'time', 'cc'),
#   ('other', 'time', 'conj'),
#   ('crazy', 'time', 'amod'),
#   ('to', 'go', 'aux'),
#   ('go', 'is', 'xcomp'),
#   ('to', 'go', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('?', 'is', 'punct')],
#  [('Why', 'feel', 'advmod'),
#   ('upon', 'feel', 'prep'),
#   ('your', 'voyage', 'poss'),
#   ('first', 'voyage', 'amod'),
#   ('voyage', 'upon', 'pobj'),
#   ('as', 'voyage', 'prep'),
#   ('a', 'passenger', 'det'),
#   ('passenger', 'as', 'pobj'),
#   (',', 'feel', 'punct'),
#   ('did', 'feel', 'aux'),
#   ('you', 'feel', 'nsubj'),
#   ('yourself', 'you', 'appos'),
#   ('feel', 'feel', 'ROOT'),
#   ('such', 'vibration', 'predet'),
#   ('a', 'vibration', 'det'),
#   ('mystical', 'vibration', 'amod'),
#   ('vibration', 'feel', 'dobj'),
#   (',', 'vibration', 'punct'),
#   ('when', 'told', 'advmod'),
#   ('first', 'told', 'advmod'),
#   ('told', 'vibration', 'relcl'),
#   ('that', 'were', 'mark'),
#   ('you', 'were', 'nsubj'),
#   ('and', 'you', 'cc'),
#   ('your', 'ship', 'poss'),
#   ('ship', 'you', 'conj'),
#   ('were', 'told', 'ccomp'),
#   ('now', 'were', 'advmod'),
#   ('out', 'were', 'prep'),
#   ('of', 'out', 'prep'),
#   ('sight', 'of', 'pobj'),
#   ('of', 'sight', 'prep'),
#   ('land', 'of', 'pobj'),
#   ('?', 'feel', 'punct')],
#  [('Why', 'hold', 'advmod'),
#   ('did', 'hold', 'aux'),
#   ('the', 'Persians', 'det'),
#   ('old', 'Persians', 'amod'),
#   ('Persians', 'hold', 'nsubj'),
#   ('hold', 'hold', 'ROOT'),
#   ('the', 'sea', 'det'),
#   ('sea', 'hold', 'dobj'),
#   ('holy', 'hold', 'ccomp'),
#   ('?', 'hold', 'punct')],
#  [('Why', 'give', 'advmod'),
#   ('did', 'give', 'aux'),
#   ('the', 'Greeks', 'det'),
#   ('Greeks', 'give', 'nsubj'),
#   ('give', 'give', 'ROOT'),
#   ('it', 'give', 'dative'),
#   ('a', 'deity', 'det'),
#   ('separate', 'deity', 'amod'),
#   ('deity', 'give', 'dobj'),
#   (',', 'give', 'punct'),
#   ('and', 'give', 'cc'),
#   ('own', 'give', 'conj'),
#   ('brother', 'own', 'dobj'),
#   ('of', 'brother', 'prep'),
#   ('Jove', 'of', 'pobj'),
#   ('?', 'give', 'punct')],
#  [('Surely', 'is', 'advmod'),
#   ('all', 'this', 'predet'),
#   ('this', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('not', 'is', 'neg'),
#   ('without', 'is', 'prep'),
#   ('meaning', 'without', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('And', 'deeper', 'cc'),
#   ('still', 'deeper', 'advmod'),
#   ('deeper', 'plunged', 'advmod'),
#   ('the', 'meaning', 'det'),
#   ('meaning', 'deeper', 'dobj'),
#   ('of', 'meaning', 'prep'),
#   ('that', 'story', 'det'),
#   ('story', 'of', 'pobj'),
#   ('of', 'story', 'prep'),
#   ('Narcissus', 'of', 'pobj'),
#   (',', 'story', 'punct'),
#   ('who', 'grasp', 'nsubj'),
#   ('because', 'grasp', 'mark'),
#   ('he', 'grasp', 'nsubj'),
#   ('could', 'grasp', 'aux'),
#   ('not', 'grasp', 'neg'),
#   ('grasp', 'story', 'relcl'),
#   ('the', 'tormenting', 'det'),
#   ('tormenting', 'grasp', 'dobj'),
#   (',', 'story', 'punct'),
#   ('mild', 'image', 'amod'),
#   ('image', 'story', 'appos'),
#   ('he', 'saw', 'nsubj'),
#   ('saw', 'image', 'relcl'),
#   ('in', 'saw', 'prep'),
#   ('the', 'fountain', 'det'),
#   ('fountain', 'in', 'pobj'),
#   (',', 'story', 'punct'),
#   ('plunged', 'plunged', 'ROOT'),
#   ('into', 'plunged', 'prep'),
#   ('it', 'into', 'pobj'),
#   ('and', 'plunged', 'cc'),
#   ('was', 'drowned', 'auxpass'),
#   ('drowned', 'plunged', 'conj'),
#   ('.', 'plunged', 'punct')],
#  [('But', 'see', 'cc'),
#   ('that', 'image', 'det'),
#   ('same', 'image', 'amod'),
#   ('image', 'see', 'npadvmod'),
#   (',', 'see', 'punct'),
#   ('we', 'see', 'nsubj'),
#   ('ourselves', 'we', 'appos'),
#   ('see', 'see', 'ROOT'),
#   ('in', 'see', 'prep'),
#   ('all', 'rivers', 'det'),
#   ('rivers', 'in', 'pobj'),
#   ('and', 'rivers', 'cc'),
#   ('oceans', 'rivers', 'conj'),
#   ('.', 'see', 'punct')],
#  [('It', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('the', 'image', 'det'),
#   ('image', 'is', 'attr'),
#   ('of', 'image', 'prep'),
#   ('the', 'phantom', 'det'),
#   ('ungraspable', 'phantom', 'amod'),
#   ('phantom', 'of', 'pobj'),
#   ('of', 'phantom', 'prep'),
#   ('life', 'of', 'pobj'),
#   (';', 'is', 'punct'),
#   ('and', 'is', 'cc'),
#   ('this', 'is', 'nsubj'),
#   ('is', 'is', 'conj'),
#   ('the', 'key', 'det'),
#   ('key', 'is', 'attr'),
#   ('to', 'key', 'prep'),
#   ('it', 'to', 'pobj'),
#   ('all', 'it', 'appos'),
#   ('.', 'is', 'punct')],
#  [('Now', 'mean', 'advmod'),
#   (',', 'mean', 'punct'),
#   ('when', 'say', 'advmod'),
#   ('I', 'say', 'nsubj'),
#   ('say', 'mean', 'advcl'),
#   ('that', 'am', 'mark'),
#   ('I', 'am', 'nsubj'),
#   ('am', 'say', 'ccomp'),
#   ('in', 'am', 'prep'),
#   ('the', 'habit', 'det'),
#   ('habit', 'in', 'pobj'),
#   ('of', 'habit', 'prep'),
#   ('going', 'of', 'pcomp'),
#   ('to', 'going', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('whenever', 'grow', 'advmod'),
#   ('I', 'begin', 'nsubj'),
#   ('begin', 'going', 'advcl'),
#   ('to', 'grow', 'aux'),
#   ('grow', 'begin', 'xcomp'),
#   ('hazy', 'grow', 'acomp'),
#   ('about', 'hazy', 'prep'),
#   ('the', 'eyes', 'det'),
#   ('eyes', 'about', 'pobj'),
#   (',', 'say', 'punct'),
#   ('and', 'say', 'cc'),
#   ('begin', 'say', 'conj'),
#   ('to', 'be', 'aux'),
#   ('be', 'begin', 'xcomp'),
#   ('over', 'conscious', 'advmod'),
#   ('conscious', 'be', 'acomp'),
#   ('of', 'conscious', 'prep'),
#   ('my', 'lungs', 'poss'),
#   ('lungs', 'of', 'pobj'),
#   (',', 'mean', 'punct'),
#   ('I', 'mean', 'nsubj'),
#   ('do', 'mean', 'aux'),
#   ('not', 'mean', 'neg'),
#   ('mean', 'mean', 'ROOT'),
#   ('to', 'have', 'aux'),
#   ('have', 'mean', 'xcomp'),
#   ('it', 'inferred', 'nsubj'),
#   ('inferred', 'have', 'ccomp'),
#   ('that', 'go', 'mark'),
#   ('I', 'go', 'nsubj'),
#   ('ever', 'go', 'advmod'),
#   ('go', 'inferred', 'ccomp'),
#   ('to', 'go', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('as', 'go', 'prep'),
#   ('a', 'passenger', 'det'),
#   ('passenger', 'as', 'pobj'),
#   ('.', 'mean', 'punct')],
#  [('For', 'have', 'prep'),
#   ('to', 'go', 'aux'),
#   ('go', 'For', 'pcomp'),
#   ('as', 'go', 'prep'),
#   ('a', 'passenger', 'det'),
#   ('passenger', 'as', 'pobj'),
#   ('you', 'needs', 'nsubj'),
#   ('must', 'needs', 'aux'),
#   ('needs', 'passenger', 'relcl'),
#   ('have', 'have', 'ROOT'),
#   ('a', 'purse', 'det'),
#   ('purse', 'have', 'dobj'),
#   (',', 'have', 'punct'),
#   ('and', 'have', 'cc'),
#   ('a', 'purse', 'det'),
#   ('purse', 'is', 'nsubj'),
#   ('is', 'have', 'conj'),
#   ('but', 'is', 'cc'),
#   ('a', 'rag', 'det'),
#   ('rag', 'is', 'conj'),
#   ('unless', 'have', 'mark'),
#   ('you', 'have', 'nsubj'),
#   ('have', 'is', 'advcl'),
#   ('something', 'have', 'dobj'),
#   ('in', 'something', 'prep'),
#   ('it', 'in', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('Besides', 'get', 'advmod'),
#   (',', 'get', 'punct'),
#   ('passengers', 'get', 'nsubj'),
#   ('get', 'go', 'ccomp'),
#   ('sea', 'sick', 'npadvmod'),
#   ('-', 'sick', 'punct'),
#   ('sick', 'quarrelsome', 'amod'),
#   ('--', 'quarrelsome', 'punct'),
#   ('grow', 'quarrelsome', 'amod'),
#   ('quarrelsome', 'get', 'dobj'),
#   ('--', 'quarrelsome', 'punct'),
#   ('don', 'sleep', 'poss'),
#   ("'", 'don', 'punct'),
#   ('t', 'sleep', 'compound'),
#   ('sleep', 'quarrelsome', 'appos'),
#   ('of', 'sleep', 'prep'),
#   ('nights', 'of', 'pobj'),
#   ('--', 'quarrelsome', 'punct'),
#   ('do', 'enjoy', 'aux'),
#   ('not', 'enjoy', 'neg'),
#   ('enjoy', 'get', 'conj'),
#   ('themselves', 'enjoy', 'dobj'),
#   ('much', 'enjoy', 'advmod'),
#   (',', 'enjoy', 'punct'),
#   ('as', 'enjoy', 'prep'),
#   ('a', 'thing', 'det'),
#   ('general', 'thing', 'amod'),
#   ('thing', 'as', 'pobj'),
#   (';', 'enjoy', 'punct'),
#   ('--', 'go', 'punct'),
#   ('no', 'go', 'intj'),
#   (',', 'go', 'punct'),
#   ('I', 'go', 'nsubj'),
#   ('never', 'go', 'neg'),
#   ('go', 'get', 'conj'),
#   ('as', 'go', 'prep'),
#   ('a', 'passenger', 'det'),
#   ('passenger', 'as', 'pobj'),
#   (';', 'go', 'punct'),
#   ('nor', 'go', 'cc'),
#   (',', 'go', 'punct'),
#   ('though', 'am', 'mark'),
#   ('I', 'am', 'nsubj'),
#   ('am', 'get', 'advcl'),
#   ('something', 'am', 'attr'),
#   ('of', 'something', 'prep'),
#   ('a', 'salt', 'det'),
#   ('salt', 'of', 'pobj'),
#   (',', 'go', 'punct'),
#   ('do', 'go', 'aux'),
#   ('I', 'go', 'nsubj'),
#   ('ever', 'go', 'advmod'),
#   ('go', 'go', 'ROOT'),
#   ('to', 'go', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('as', 'go', 'prep'),
#   ('a', 'Commodore', 'det'),
#   ('Commodore', 'as', 'pobj'),
#   (',', 'Commodore', 'punct'),
#   ('or', 'Commodore', 'cc'),
#   ('a', 'Captain', 'det'),
#   ('Captain', 'Commodore', 'conj'),
#   (',', 'Captain', 'punct'),
#   ('or', 'Captain', 'cc'),
#   ('a', 'Cook', 'det'),
#   ('Cook', 'Captain', 'conj'),
#   ('.', 'go', 'punct')],
#  [('I', 'abandon', 'nsubj'),
#   ('abandon', 'abandon', 'ROOT'),
#   ('the', 'glory', 'det'),
#   ('glory', 'abandon', 'dobj'),
#   ('and', 'glory', 'cc'),
#   ('distinction', 'glory', 'conj'),
#   ('of', 'glory', 'prep'),
#   ('such', 'offices', 'amod'),
#   ('offices', 'of', 'pobj'),
#   ('to', 'abandon', 'dative'),
#   ('those', 'to', 'pobj'),
#   ('who', 'like', 'nsubj'),
#   ('like', 'those', 'relcl'),
#   ('them', 'like', 'dobj'),
#   ('.', 'abandon', 'punct')],
#  [('For', 'abominate', 'prep'),
#   ('my', 'part', 'poss'),
#   ('part', 'For', 'pobj'),
#   (',', 'abominate', 'punct'),
#   ('I', 'abominate', 'nsubj'),
#   ('abominate', 'abominate', 'ROOT'),
#   ('all', 'toils', 'det'),
#   ('honourable', 'toils', 'amod'),
#   ('respectable', 'toils', 'amod'),
#   ('toils', 'abominate', 'dobj'),
#   (',', 'toils', 'punct'),
#   ('trials', 'toils', 'conj'),
#   (',', 'trials', 'punct'),
#   ('and', 'trials', 'cc'),
#   ('tribulations', 'trials', 'conj'),
#   ('of', 'toils', 'prep'),
#   ('every', 'kind', 'det'),
#   ('kind', 'of', 'pobj'),
#   ('whatsoever', 'kind', 'advmod'),
#   ('.', 'abominate', 'punct')],
#  [('It', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('quite', 'much', 'advmod'),
#   ('as', 'much', 'advmod'),
#   ('much', 'is', 'acomp'),
#   ('as', 'do', 'mark'),
#   ('I', 'do', 'nsubj'),
#   ('can', 'do', 'aux'),
#   ('do', 'much', 'advcl'),
#   ('to', 'take', 'aux'),
#   ('take', 'do', 'advcl'),
#   ('care', 'take', 'dobj'),
#   ('of', 'take', 'prep'),
#   ('myself', 'of', 'pobj'),
#   (',', 'take', 'punct'),
#   ('without', 'take', 'prep'),
#   ('taking', 'without', 'pcomp'),
#   ('care', 'taking', 'dobj'),
#   ('of', 'taking', 'prep'),
#   ('ships', 'of', 'pobj'),
#   (',', 'ships', 'punct'),
#   ('barques', 'ships', 'conj'),
#   (',', 'barques', 'punct'),
#   ('brigs', 'barques', 'conj'),
#   (',', 'brigs', 'punct'),
#   ('schooners', 'brigs', 'conj'),
#   (',', 'schooners', 'punct'),
#   ('and', 'schooners', 'cc'),
#   ('what', 'schooners', 'conj'),
#   ('not', 'what', 'neg'),
#   ('.', 'is', 'punct')],
#  [('And', 'fancied', 'cc'),
#   ('as', 'fancied', 'prep'),
#   ('for', 'as', 'prep'),
#   ('going', 'for', 'pcomp'),
#   ('as', 'cook', 'mark'),
#   ('cook', 'going', 'dobj'),
#   (',', 'fancied', 'punct'),
#   ('--', 'fancied', 'punct'),
#   ('though', 'confess', 'mark'),
#   ('I', 'confess', 'nsubj'),
#   ('confess', 'fancied', 'advcl'),
#   ('there', 'is', 'expl'),
#   ('is', 'confess', 'ccomp'),
#   ('considerable', 'glory', 'amod'),
#   ('glory', 'is', 'attr'),
#   ('in', 'is', 'prep'),
#   ('that', 'in', 'pobj'),
#   (',', 'fancied', 'punct'),
#   ('a', 'cook', 'det'),
#   ('cook', 'being', 'nsubj'),
#   ('being', 'fancied', 'ccomp'),
#   ('a', 'sort', 'det'),
#   ('sort', 'being', 'attr'),
#   ('of', 'sort', 'prep'),
#   ('officer', 'of', 'pobj'),
#   ('on', 'sort', 'prep'),
#   ('ship', 'board', 'compound'),
#   ('-', 'board', 'punct'),
#   ('board', 'on', 'pobj'),
#   ('--', 'fancied', 'punct'),
#   ('yet', 'fancied', 'advmod'),
#   (',', 'fancied', 'punct'),
#   ('somehow', 'fancied', 'advmod'),
#   (',', 'fancied', 'punct'),
#   ('I', 'fancied', 'nsubj'),
#   ('never', 'fancied', 'neg'),
#   ('fancied', 'is', 'advcl'),
#   ('broiling', 'fowls', 'compound'),
#   ('fowls', 'fancied', 'dobj'),
#   (';', 'fancied', 'punct'),
#   ('--', 'fancied', 'punct'),
#   ('though', 'broiled', 'mark'),
#   ('once', 'broiled', 'advmod'),
#   ('broiled', 'buttered', 'advcl'),
#   (',', 'buttered', 'punct'),
#   ('judiciously', 'buttered', 'advmod'),
#   ('buttered', 'fancied', 'conj'),
#   (',', 'buttered', 'punct'),
#   ('and', 'buttered', 'cc'),
#   ('judgmatically', 'salted', 'advmod'),
#   ('salted', 'buttered', 'conj'),
#   ('and', 'salted', 'cc'),
#   ('peppered', 'salted', 'conj'),
#   (',', 'is', 'punct'),
#   ('there', 'is', 'expl'),
#   ('is', 'is', 'ROOT'),
#   ('no', 'one', 'det'),
#   ('one', 'is', 'attr'),
#   ('who', 'speak', 'nsubj'),
#   ('will', 'speak', 'aux'),
#   ('speak', 'one', 'relcl'),
#   ('more', 'respectfully', 'advmod'),
#   ('respectfully', 'speak', 'advmod'),
#   (',', 'speak', 'punct'),
#   ('not', 'say', 'neg'),
#   ('to', 'say', 'aux'),
#   ('say', 'speak', 'advcl'),
#   ('reverentially', 'say', 'advmod'),
#   (',', 'say', 'punct'),
#   ('of', 'say', 'prep'),
#   ('a', 'fowl', 'det'),
#   ('broiled', 'fowl', 'amod'),
#   ('fowl', 'of', 'pobj'),
#   ('than', 'will', 'mark'),
#   ('I', 'will', 'nsubj'),
#   ('will', 'say', 'advcl'),
#   ('.', 'is', 'punct')],
#  [('It', 'is', 'nsubj'),
#   ('is', 'is', 'ROOT'),
#   ('out', 'is', 'prep'),
#   ('of', 'out', 'prep'),
#   ('the', 'dotings', 'det'),
#   ('idolatrous', 'dotings', 'amod'),
#   ('dotings', 'of', 'pobj'),
#   ('of', 'dotings', 'prep'),
#   ('the', 'Egyptians', 'det'),
#   ('old', 'Egyptians', 'amod'),
#   ('Egyptians', 'of', 'pobj'),
#   ('upon', 'dotings', 'prep'),
#   ('broiled', 'ibis', 'amod'),
#   ('ibis', 'horse', 'amod'),
#   ('and', 'ibis', 'cc'),
#   ('roasted', 'ibis', 'conj'),
#   ('river', 'horse', 'compound'),
#   ('horse', 'upon', 'pobj'),
#   (',', 'is', 'punct'),
#   ('that', 'see', 'mark'),
#   ('you', 'see', 'nsubj'),
#   ('see', 'is', 'ccomp'),
#   ('the', 'mummies', 'det'),
#   ('mummies', 'see', 'dobj'),
#   ('of', 'mummies', 'prep'),
#   ('those', 'creatures', 'det'),
#   ('creatures', 'of', 'pobj'),
#   ('in', 'mummies', 'prep'),
#   ('their', 'houses', 'poss'),
#   ('huge', 'houses', 'amod'),
#   ('bake', 'houses', 'compound'),
#   ('-', 'houses', 'punct'),
#   ('houses', 'in', 'pobj'),
#   ('the', 'pyramids', 'det'),
#   ('pyramids', 'in', 'pobj'),
#   ('.', 'is', 'punct')],
#  [('No', 'go', 'intj'),
#   (',', 'go', 'punct'),
#   ('when', 'go', 'advmod'),
#   ('I', 'go', 'nsubj'),
#   ('go', 'go', 'advcl'),
#   ('to', 'go', 'prep'),
#   ('sea', 'to', 'pobj'),
#   (',', 'go', 'punct'),
#   ('I', 'go', 'nsubj'),
#   ('go', 'go', 'ROOT'),
#   ('as', 'go', 'prep'),
#   ('a', 'sailor', 'det'),
#   ('simple', 'sailor', 'amod'),
#   ('sailor', 'as', 'pobj'),
#   (',', 'go', 'punct'),
#   ('right', 'before', 'advmod'),
#   ('before', 'go', 'prep'),
#   ('the', 'mast', 'det'),
#   ('mast', 'before', 'pobj'),
#   (',', 'plumb', 'punct'),
#   ('plumb', 'go', 'advcl'),
#   ('down', 'plumb', 'prt'),
#   ('into', 'plumb', 'prep'),
#   ('the', 'forecastle', 'det'),
#   ('forecastle', 'into', 'pobj'),
#   (',', 'plumb', 'punct'),
#   ('aloft', 'there', 'advmod'),
#   ('there', 'plumb', 'advmod'),
#   ('to', 'there', 'prep'),
#   ('the', 'head', 'det'),
#   ('royal', 'head', 'amod'),
#   ('mast', 'head', 'compound'),
#   ('-', 'head', 'punct'),
#   ('head', 'to', 'pobj'),
#   ('.', 'go', 'punct')],
#  [('True', 'order', 'intj'),
#   (',', 'order', 'punct'),
#   ('they', 'order', 'nsubj'),
#   ('rather', 'order', 'advmod'),
#   ('order', 'order', 'ROOT'),
#   ('me', 'order', 'dobj'),
#   ('about', 'order', 'prep'),
#   ('some', 'about', 'pobj'),
#   (',', 'order', 'punct'),
#   ('and', 'order', 'cc'),
#   ('make', 'order', 'conj'),
#   ('me', 'jump', 'nsubj'),
#   ('jump', 'make', 'ccomp'),
#   ('from', 'jump', 'prep'),
#   ('spar', 'from', 'pobj'),
#   ('to', 'jump', 'prep'),
#   ('spar', 'to', 'pobj'),
#   (',', 'jump', 'punct'),
#   ('like', 'jump', 'prep'),
#   ('a', 'grasshopper', 'det'),
#   ('grasshopper', 'like', 'pobj'),
#   ('in', 'grasshopper', 'prep'),
#   ('a', 'meadow', 'det'),
#   ('May', 'meadow', 'compound'),
#   ('meadow', 'in', 'pobj'),
#   ('.', 'order', 'punct')],
#  [('And', 'is', 'cc'),
#   ('at', 'is', 'prep'),
#   ('first', 'at', 'pcomp'),
#   (',', 'is', 'punct'),
#   ('this', 'sort', 'det'),
#   ('sort', 'is', 'nsubj'),
#   ('of', 'sort', 'prep'),
#   ('thing', 'of', 'pobj'),
#   ('is', 'is', 'ROOT'),
#   ('unpleasant', 'is', 'acomp'),
#   ('enough', 'unpleasant', 'advmod'),
#   ('.', 'is', 'punct')],
#  [('It', 'touches', 'nsubj'),
#   ('touches', 'touches', 'ROOT'),
#   ('one', 'sense', 'poss'),
#   ("'", 'one', 'punct'),
#   ('s', 'one', 'case'),
#   ('sense', 'touches', 'dobj'),
#   ('of', 'sense', 'prep'),
#   ('honour', 'of', 'pobj'),
#   (',', 'touches', 'punct'),
#   ('particularly', 'come', 'advmod'),
#   ('if', 'come', 'mark'),
#   ('you', 'come', 'nsubj'),
#   ('come', 'touches', 'advcl'),
#   ('of', 'come', 'prep'),
#   ('an', 'family', 'det'),
#   ('old', 'family', 'amod'),
#   ('established', 'family', 'amod'),
#   ('family', 'of', 'pobj'),
#   ('in', 'family', 'prep'),
#   ('the', 'land', 'det'),
#   ('land', 'in', 'pobj'),
#   (',', 'family', 'punct'),
#   ('the', 'Rensselaers', 'det'),
#   ('Van', 'Rensselaers', 'compound'),
#   ('Rensselaers', 'family', 'conj'),
#   (',', 'Rensselaers', 'punct'),
#   ('or', 'Rensselaers', 'cc'),
#   ('Randolphs', 'Rensselaers', 'conj'),
#   (',', 'Randolphs', 'punct'),
#   ('or', 'Randolphs', 'cc'),
#   ('Hardicanutes', 'Randolphs', 'conj'),
#   ('.', 'touches', 'punct')],
#  [('And', 'lording', 'cc'),
#   ('more', 'all', 'amod'),
#   ('than', 'all', 'quantmod'),
#   ('all', 'lording', 'advmod'),
#   (',', 'lording', 'punct'),
#   ('if', 'previous', 'mark'),
#   ('just', 'previous', 'advmod'),
#   ('previous', 'lording', 'advcl'),
#   ('to', 'previous', 'prep'),
#   ('putting', 'to', 'pcomp'),
#   ('your', 'hand', 'poss'),
#   ('hand', 'putting', 'dobj'),
#   ('into', 'putting', 'prep'),
#   ('the', 'pot', 'det'),
#   ('tar', 'pot', 'compound'),
#   ('-', 'pot', 'punct'),
#   ('pot', 'into', 'pobj'),
#   (',', 'lording', 'punct'),
#   ('you', 'lording', 'nsubj'),
#   ('have', 'lording', 'aux'),
#   ('been', 'lording', 'aux'),
#   ('lording', 'lording', 'ROOT'),
#   ('it', 'lording', 'dobj'),
#   ('as', 'lording', 'prep'),
#   ('a', 'schoolmaster', 'det'),
#   ('country', 'schoolmaster', 'compound'),
#   ('schoolmaster', 'as', 'pobj'),
#   (',', 'lording', 'punct'),
#   ('making', 'lording', 'advcl'),
#   ('the', 'boys', 'det'),
#   ('tallest', 'boys', 'amod'),
#   ('boys', 'stand', 'nsubj'),
#   ('stand', 'making', 'ccomp'),
#   ('in', 'stand', 'prep'),
#   ('awe', 'in', 'pobj'),
#   ('of', 'awe', 'prep'),
#   ('you', 'of', 'pobj'),
#   ('.', 'lording', 'punct')],
#  [('The', 'transition', 'det'),
#   ('transition', 'is', 'nsubj'),
#   ('is', 'assure', 'ccomp'),
#   ('a', 'one', 'det'),
#   ('keen', 'one', 'amod'),
#   ('one', 'is', 'attr'),
#   (',', 'assure', 'punct'),
#   ('I', 'assure', 'nsubj'),
#   ('assure', 'assure', 'ROOT'),
#   ('you', 'assure', 'dobj'),
#   (',', 'assure', 'punct'),
#   ('from', 'assure', 'prep'),
#   ('a', 'schoolmaster', 'det'),
#   ('schoolmaster', 'from', 'pobj'),
#   ('to', 'schoolmaster', 'prep'),
#   ('a', 'sailor', 'det'),
#   ('sailor', 'to', 'pobj'),
#   (',', 'assure', 'punct'),
#   ('and', 'assure', 'cc'),
#   ('requires', 'assure', 'conj'),
#   ('a', 'decoction', 'det'),
#   ('strong', 'decoction', 'amod'),
#   ('decoction', 'requires', 'dobj'),
#   ('of', 'decoction', 'prep'),
#   ('Seneca', 'of', 'pobj'),
#   ('and', 'Seneca', 'cc'),
#   ('the', 'Stoics', 'det'),
#   ('Stoics', 'Seneca', 'conj'),
#   ('to', 'enable', 'aux'),
#   ('enable', 'requires', 'advcl'),
#   ('you', 'enable', 'dobj'),
#   ('to', 'grin', 'aux'),
#   ('grin', 'enable', 'xcomp'),
#   ('and', 'grin', 'cc'),
#   ('bear', 'grin', 'conj'),
#   ('it', 'bear', 'dobj'),
#   ('.', 'assure', 'punct')],
#  [('But', 'wears', 'cc'),
#   ('even', 'wears', 'advmod'),
#   ('this', 'wears', 'nsubj'),
#   ('wears', 'wears', 'ROOT'),
#   ('off', 'wears', 'prt'),
#   ('in', 'wears', 'prep'),
#   ('time', 'in', 'pobj'),
#   ('.', 'wears', 'punct')],
#  [('What', 'What', 'ROOT'),
#   ('of', 'What', 'prep'),
#   ('it', 'of', 'pobj'),
#   (',', 'What', 'punct'),
#   ('if', 'get', 'mark'),
#   ('some', 'hunks', 'det'),
#   ('old', 'hunks', 'amod'),
# ...
#   ('that', 'believe', 'mark'),
#   ('we', 'believe', 'nsubj'),
#   ('so', 'earnestly', 'advmod'),
#   ('earnestly', 'believe', 'advmod'),
#   ('believe', 'considering', 'ccomp'),
#   ('money', 'be', 'nsubj'),
#   ('to', 'be', 'aux'),
#   ('be', 'believe', 'ccomp'),
#   ('the', 'root', 'det'),
#   ('root', 'be', 'attr'),
#   ('of', 'root', 'prep'),
#   ('all', 'ills', 'det'),
#   ('earthly', 'ills', 'amod'),
#   ('ills', 'of', 'pobj'),
#   (',', 'believe', 'punct'),
#   ('and', 'believe', 'cc'),
#   ('that', 'enter', 'mark'),
#   ('on', 'enter', 'prep'),
#   ('no', 'account', 'det'),
#   ('account', 'on', 'pobj'),
#   ('can', 'enter', 'aux'),
#   ('a', 'man', 'det'),
#   ('monied', 'man', 'amod'),
#   ('man', 'enter', 'nsubj'),
#   ('enter', 'believe', 'conj'),
#   ('heaven', 'enter', 'dobj'),
#   ('.', 'is', 'punct')],
#  [('Ah', 'Ah', 'ROOT'), ('!', 'Ah', 'punct')],
#  [('how', 'cheerfully', 'advmod'),
#   ('cheerfully', 'consign', 'advmod'),
#   ('we', 'consign', 'nsubj'),
#   ('consign', 'consign', 'ROOT'),
#   ('ourselves', 'consign', 'dobj'),
#   ('to', 'consign', 'prep'),
#   ('perdition', 'to', 'pobj'),
#   ('!', 'consign', 'punct')],
#  [('Finally', 'go', 'advmod'),
#   (',', 'go', 'punct'),
#   ('I', 'go', 'nsubj'),
#   ('always', 'go', 'advmod'),
#   ('go', 'go', 'ROOT'),
#   ('to', 'go', 'prep'),
#   ('sea', 'to', 'pobj'),
#   ('as', 'go', 'prep'),
#   ('a', 'sailor', 'det'),
#   ('sailor', 'as', 'pobj'),
#   (',', 'go', 'punct'),
#   ('because', 'go', 'prep'),
#   ('of', 'because', 'pcomp'),
#   ('the', 'exercise', 'det'),
#   ('wholesome', 'exercise', 'amod'),
#   ('exercise', 'because', 'pobj'),
#   ('and', 'exercise', 'cc'),
#   ('pure', 'air', 'amod'),
#   ('air', 'exercise', 'conj'),
#   ('of', 'exercise', 'prep'),
#   ('the', 'deck', 'det'),
#   ('fore', 'castle', 'compound'),
#   ('-', 'castle', 'punct'),
#   ('castle', 'deck', 'compound'),
#   ('deck', 'of', 'pobj'),
#   ('.', 'go', 'punct')],
#  [('For', 'are', 'prep'),
#   ('as', 'For', 'prep'),
#   ('in', 'as', 'prep'),
#   ('this', 'world', 'det'),
#   ('world', 'in', 'pobj'),
#   (',', 'are', 'punct'),
#   ('head', 'winds', 'compound'),
#   ('winds', 'are', 'nsubj'),
#   ('are', 'are', 'ROOT'),
#   ('far', 'more', 'advmod'),
#   ('more', 'prevalent', 'advmod'),
#   ('prevalent', 'are', 'acomp'),
#   ('than', 'prevalent', 'prep'),
#   ('winds', 'than', 'pobj'),
#   ('from', 'winds', 'prep'),
#   ('astern', 'from', 'pobj'),
#   ('(', 'gets', 'punct'),
#   ('that', 'is', 'advmod'),
#   ('is', 'gets', 'advmod'),
#   (',', 'gets', 'punct'),
#   ('if', 'violate', 'mark'),
#   ('you', 'violate', 'nsubj'),
#   ('never', 'violate', 'neg'),
#   ('violate', 'gets', 'advcl'),
#   ('the', 'maxim', 'det'),
#   ('Pythagorean', 'maxim', 'amod'),
#   ('maxim', 'violate', 'dobj'),
#   (')', 'violate', 'punct'),
#   (',', 'gets', 'punct'),
#   ('so', 'gets', 'advmod'),
#   ('for', 'gets', 'prep'),
#   ('the', 'part', 'det'),
#   ('most', 'part', 'amod'),
#   ('part', 'for', 'pobj'),
#   ('the', 'Commodore', 'det'),
#   ('Commodore', 'part', 'appos'),
#   ('on', 'part', 'prep'),
#   ('the', 'deck', 'det'),
#   ('quarter', 'deck', 'compound'),
#   ('-', 'deck', 'punct'),
#   ('deck', 'on', 'pobj'),
#   ('gets', 'are', 'parataxis'),
#   ('his', 'atmosphere', 'poss'),
#   ('atmosphere', 'gets', 'dobj'),
#   ('at', 'gets', 'prep'),
#   ('second', 'hand', 'amod'),
#   ('hand', 'at', 'pobj'),
#   ('from', 'gets', 'prep'),
#   ('the', 'sailors', 'det'),
#   ('sailors', 'from', 'pobj'),
#   ('on', 'sailors', 'prep'),
#   ('the', 'forecastle', 'det'),
#   ('forecastle', 'on', 'pobj'),
#   ('.', 'gets', 'punct')],
#  [('He', 'thinks', 'nsubj'),
#   ('thinks', 'thinks', 'ROOT'),
#   ('he', 'breathes', 'nsubj'),
#   ('breathes', 'thinks', 'ccomp'),
#   ('it', 'breathes', 'dobj'),
#   ('first', 'breathes', 'advmod'),
#   (';', 'thinks', 'punct'),
#   ('but', 'thinks', 'cc'),
#   ('not', 'so', 'neg'),
#   ('so', 'thinks', 'conj'),
#   ('.', 'thinks', 'punct')],
#  [('In', 'lead', 'prep'),
#   ('much', 'In', 'pobj'),
#   ('the', 'way', 'det'),
#   ('same', 'way', 'amod'),
#   ('way', 'In', 'pobj'),
#   ('do', 'lead', 'aux'),
#   ('the', 'commonalty', 'det'),
#   ('commonalty', 'lead', 'nsubj'),
#   ('lead', 'lead', 'ROOT'),
#   ('their', 'leaders', 'poss'),
#   ('leaders', 'lead', 'dobj'),
#   ('in', 'lead', 'prep'),
#   ('many', 'things', 'amod'),
#   ('other', 'things', 'amod'),
#   ('things', 'in', 'pobj'),
#   (',', 'lead', 'punct'),
#   ('at', 'lead', 'prep'),
#   ('the', 'time', 'det'),
#   ('same', 'time', 'amod'),
#   ('time', 'at', 'pobj'),
#   ('that', 'suspect', 'advmod'),
#   ('the', 'leaders', 'det'),
#   ('leaders', 'suspect', 'nsubj'),
#   ('little', 'suspect', 'amod'),
#   ('suspect', 'time', 'relcl'),
#   ('it', 'suspect', 'dobj'),
#   ('.', 'lead', 'punct')],
#  [('But', 'was', 'cc'),
#   ('wherefore', 'was', 'intj'),
#   ('it', 'was', 'nsubj'),
#   ('was', 'answer', 'ccomp'),
#   ('that', 'take', 'mark'),
#   ('after', 'take', 'prep'),
#   ('having', 'smelt', 'aux'),
#   ('repeatedly', 'smelt', 'advmod'),
#   ('smelt', 'after', 'pcomp'),
#   ('the', 'sea', 'det'),
#   ('sea', 'smelt', 'dobj'),
#   ('as', 'sea', 'prep'),
#   ('a', 'sailor', 'det'),
#   ('merchant', 'sailor', 'compound'),
#   ('sailor', 'as', 'pobj'),
#   (',', 'take', 'punct'),
#   ('I', 'take', 'nsubj'),
#   ('should', 'take', 'aux'),
#   ('now', 'take', 'advmod'),
#   ('take', 'was', 'ccomp'),
#   ('it', 'take', 'dobj'),
#   ('into', 'take', 'prep'),
#   ('my', 'head', 'poss'),
#   ('head', 'into', 'pobj'),
#   ('to', 'go', 'aux'),
#   ('go', 'take', 'advcl'),
#   ('on', 'go', 'prep'),
#   ('a', 'voyage', 'det'),
#   ('whaling', 'voyage', 'amod'),
#   ('voyage', 'on', 'pobj'),
#   (';', 'answer', 'punct'),
#   ('this', 'officer', 'det'),
#   ('the', 'officer', 'det'),
#   ('invisible', 'officer', 'amod'),
#   ('police', 'officer', 'compound'),
#   ('officer', 'answer', 'nsubj'),
#   ('of', 'officer', 'prep'),
#   ('the', 'Fates', 'det'),
#   ('Fates', 'of', 'pobj'),
#   (',', 'Fates', 'punct'),
#   ('who', 'has', 'nsubj'),
#   ('has', 'Fates', 'relcl'),
#   ('the', 'surveillance', 'det'),
#   ('constant', 'surveillance', 'amod'),
#   ('surveillance', 'has', 'dobj'),
#   ('of', 'surveillance', 'prep'),
#   ('me', 'of', 'pobj'),
#   (',', 'has', 'punct'),
#   ('and', 'has', 'cc'),
#   ('secretly', 'dogs', 'advmod'),
#   ('dogs', 'has', 'conj'),
#   ('me', 'dogs', 'dobj'),
#   (',', 'dogs', 'punct'),
#   ('and', 'dogs', 'cc'),
#   ('influences', 'dogs', 'conj'),
#   ('me', 'influences', 'dobj'),
#   ('in', 'influences', 'prep'),
#   ('some', 'way', 'det'),
#   ('unaccountable', 'way', 'amod'),
#   ('way', 'in', 'pobj'),
#   ('--', 'answer', 'punct'),
#   ('he', 'answer', 'nsubj'),
#   ('can', 'answer', 'aux'),
#   ('better', 'answer', 'advmod'),
#   ('answer', 'answer', 'ROOT'),
#   ('than', 'answer', 'prep'),
#   ('any', 'one', 'det'),
#   ('one', 'than', 'pobj'),
#   ('else', 'one', 'advmod'),
#   ('.', 'answer', 'punct')],
#  [('And', 'formed', 'cc'),
#   (',', 'formed', 'punct'),
#   ('doubtless', 'formed', 'npadvmod'),
#   (',', 'formed', 'punct'),
#   ('my', 'going', 'nsubj'),
#   ('going', 'formed', 'advcl'),
#   ('on', 'going', 'prep'),
#   ('this', 'voyage', 'det'),
#   ('whaling', 'voyage', 'compound'),
#   ('voyage', 'on', 'pobj'),
#   (',', 'formed', 'punct'),
#   ('formed', 'formed', 'ROOT'),
#   ('part', 'formed', 'dobj'),
#   ('of', 'part', 'prep'),
#   ('the', 'programme', 'det'),
#   ('grand', 'programme', 'amod'),
#   ('programme', 'of', 'pobj'),
#   ('of', 'programme', 'prep'),
#   ('Providence', 'of', 'pobj'),
#   ('that', 'drawn', 'nsubjpass'),
#   ('was', 'drawn', 'auxpass'),
#   ('drawn', 'programme', 'relcl'),
#   ('up', 'drawn', 'prt'),
#   ('a', 'time', 'det'),
#   ('long', 'time', 'amod'),
#   ('time', 'ago', 'npadvmod'),
#   ('ago', 'drawn', 'advmod'),
#   ('.', 'formed', 'punct')],
#  [('It', 'came', 'nsubj'),
#   ('came', 'came', 'ROOT'),
#   ('in', 'came', 'prt'),
#   ('as', 'came', 'prep'),
#   ('a', 'sort', 'det'),
#   ('sort', 'as', 'pobj'),
#   ('of', 'sort', 'prep'),
#   ('brief', 'interlude', 'amod'),
#   ('interlude', 'of', 'pobj'),
#   ('and', 'interlude', 'cc'),
#   ('solo', 'interlude', 'conj'),
#   ('between', 'interlude', 'prep'),
#   ('more', 'extensive', 'advmod'),
#   ('extensive', 'performances', 'amod'),
#   ('performances', 'between', 'pobj'),
#   ('.', 'came', 'punct')],
#  [('I', 'take', 'nsubj'),
#   ('take', 'take', 'ROOT'),
#   ('it', 'take', 'dobj'),
#   ('that', 'run', 'mark'),
#   ('this', 'part', 'det'),
#   ('part', 'run', 'nsubj'),
#   ('of', 'part', 'prep'),
#   ('the', 'bill', 'det'),
#   ('bill', 'of', 'pobj'),
#   ('must', 'run', 'aux'),
#   ('have', 'run', 'aux'),
#   ('run', 'take', 'ccomp'),
#   ('something', 'run', 'dobj'),
#   ('like', 'something', 'prep'),
#   ('this', 'like', 'pobj'),
#   (':', 'take', 'punct')],
#  [('"', 'ELECTION', 'punct'),
#   ('GRAND', 'ELECTION', 'compound'),
#   ('CONTESTED', 'ELECTION', 'compound'),
#   ('ELECTION', 'ELECTION', 'ROOT'),
#   ('FOR', 'ELECTION', 'prep'),
#   ('THE', 'PRESIDENCY', 'det'),
#   ('PRESIDENCY', 'FOR', 'pobj'),
#   ('OF', 'PRESIDENCY', 'prep'),
#   ('THE', 'STATES', 'det'),
#   ('UNITED', 'STATES', 'compound'),
#   ('STATES', 'OF', 'pobj'),
#   ('.', 'ELECTION', 'punct')],
#  [('"', 'WHALING', 'punct'),
#   ('WHALING', 'WHALING', 'ROOT'),
#   ('VOYAGE', 'WHALING', 'dobj'),
#   ('BY', 'WHALING', 'prep'),
#   ('ONE', 'ISHMAEL', 'nummod'),
#   ('ISHMAEL', 'BY', 'pobj'),
#   ('.', 'WHALING', 'punct')],
#  [('"', 'BATTLE', 'punct'),
#   ('BLOODY', 'BATTLE', 'amod'),
#   ('BATTLE', 'BATTLE', 'ROOT'),
#   ('IN', 'BATTLE', 'prep'),
#   ('AFFGHANISTAN', 'IN', 'pobj'),
#   ('.', 'BATTLE', 'punct'),
#   ('"', 'BATTLE', 'punct')],
#  [('Though', 'tell', 'mark'),
#   ('I', 'tell', 'nsubj'),
#   ('can', 'tell', 'aux'),
#   ('not', 'tell', 'neg'),
#   ('tell', 'think', 'advcl'),
#   ('why', 'was', 'advmod'),
#   ('it', 'was', 'nsubj'),
#   ('was', 'tell', 'ccomp'),
#   ('exactly', 'was', 'advmod'),
#   ('that', 'put', 'mark'),
#   ('those', 'managers', 'det'),
#   ('stage', 'managers', 'compound'),
#   ('managers', 'put', 'nsubj'),
#   (',', 'managers', 'punct'),
#   ('the', 'Fates', 'det'),
#   ('Fates', 'managers', 'appos'),
#   (',', 'put', 'punct'),
#   ('put', 'tell', 'ccomp'),
#   ('me', 'put', 'dobj'),
#   ('down', 'put', 'prt'),
#   ('for', 'put', 'prep'),
#   ('this', 'part', 'det'),
#   ('shabby', 'part', 'amod'),
#   ('part', 'for', 'pobj'),
#   ('of', 'part', 'prep'),
#   ('a', 'voyage', 'det'),
#   ('whaling', 'voyage', 'compound'),
#   ('voyage', 'of', 'pobj'),
#   (',', 'voyage', 'punct'),
#   ('when', 'set', 'advmod'),
#   ('others', 'set', 'nsubjpass'),
#   ('were', 'set', 'auxpass'),
#   ('set', 'voyage', 'relcl'),
#   ('down', 'set', 'prt'),
#   ('for', 'set', 'prep'),
#   ('magnificent', 'parts', 'amod'),
#   ('parts', 'for', 'pobj'),
#   ('in', 'parts', 'prep'),
#   ('high', 'tragedies', 'amod'),
#   ('tragedies', 'in', 'pobj'),
#   (',', 'set', 'punct'),
#   ('and', 'set', 'cc'),
#   ('short', 'parts', 'amod'),
#   ('and', 'short', 'cc'),
#   ('easy', 'short', 'conj'),
#   ('parts', 'set', 'conj'),
#   ('in', 'parts', 'prep'),
#   ('genteel', 'comedies', 'amod'),
#   ('comedies', 'in', 'pobj'),
#   (',', 'parts', 'punct'),
#   ('and', 'parts', 'cc'),
#   ('jolly', 'parts', 'amod'),
#   ('parts', 'parts', 'conj'),
#   ('in', 'parts', 'prep'),
#   ('farces', 'in', 'pobj'),
#   ('--', 'put', 'punct'),
#   ('though', 'tell', 'mark'),
#   ('I', 'tell', 'nsubj'),
#   ('can', 'tell', 'aux'),
#   ('not', 'tell', 'neg'),
#   ('tell', 'put', 'advcl'),
#   ('why', 'was', 'advmod'),
#   ('this', 'was', 'nsubj'),
#   ('was', 'tell', 'ccomp'),
#   ('exactly', 'was', 'advmod'),
#   (';', 'tell', 'punct'),
#   ('yet', 'tell', 'cc'),
#   (',', 'tell', 'punct'),
#   ('now', 'recall', 'advmod'),
#   ('that', 'recall', 'mark'),
#   ('I', 'recall', 'nsubj'),
#   ('recall', 'tell', 'ccomp'),
#   ('all', 'circumstances', 'predet'),
#   ('the', 'circumstances', 'det'),
#   ('circumstances', 'recall', 'dobj'),
#   (',', 'think', 'punct'),
#   ('I', 'think', 'nsubj'),
#   ('think', 'think', 'ROOT'),
#   ('I', 'see', 'nsubj'),
#   ('can', 'see', 'aux'),
#   ('see', 'think', 'ccomp'),
#   ('a', 'little', 'det'),
#   ('little', 'see', 'dobj'),
#   ('into', 'see', 'prep'),
#   ('the', 'springs', 'det'),
#   ('springs', 'into', 'pobj'),
#   ('and', 'springs', 'cc'),
#   ('motives', 'springs', 'conj'),
#   ('which', 'presented', 'nsubjpass'),
#   ('being', 'presented', 'auxpass'),
#   ('cunningly', 'presented', 'advmod'),
#   ('presented', 'springs', 'relcl'),
#   ('to', 'presented', 'dative'),
#   ('me', 'to', 'pobj'),
#   ('under', 'presented', 'prep'),
#   ('various', 'disguises', 'amod'),
#   ('disguises', 'under', 'pobj'),
#   (',', 'see', 'punct'),
#   ('induced', 'see', 'dep'),
#   ('me', 'induced', 'dobj'),
#   ('to', 'set', 'aux'),
#   ('set', 'induced', 'xcomp'),
#   ('about', 'set', 'prep'),
#   ('performing', 'about', 'pcomp'),
#   ('the', 'part', 'det'),
#   ('part', 'performing', 'dobj'),
#   ('I', 'did', 'nsubj'),
#   ('did', 'part', 'relcl'),
#   (',', 'set', 'punct'),
#   ('besides', 'set', 'prep'),
#   ('cajoling', 'besides', 'pcomp'),
#   ('me', 'cajoling', 'dobj'),
#   ('into', 'cajoling', 'prep'),
#   ('the', 'delusion', 'det'),
#   ('delusion', 'into', 'pobj'),
#   ('that', 'was', 'mark'),
#   ('it', 'was', 'nsubj'),
#   ('was', 'delusion', 'acl'),
#   ('a', 'choice', 'det'),
#   ('choice', 'was', 'attr'),
#   ('resulting', 'choice', 'acl'),
#   ('from', 'resulting', 'prep'),
#   ('my', 'freewill', 'poss'),
#   ('own', 'freewill', 'amod'),
#   ('unbiased', 'freewill', 'amod'),
#   ('freewill', 'from', 'pobj'),
#   ('and', 'resulting', 'cc'),
#   ('discriminating', 'resulting', 'conj'),
#   ('judgment', 'discriminating', 'dobj'),
#   ('.', 'think', 'punct')],
#  [('Chief', 'was', 'nsubj'),
#   ('among', 'Chief', 'prep'),
#   ('these', 'motives', 'det'),
#   ('motives', 'among', 'pobj'),
#   ('was', 'was', 'ROOT'),
#   ('the', 'idea', 'det'),
#   ('overwhelming', 'idea', 'amod'),
#   ('idea', 'was', 'attr'),
#   ('of', 'idea', 'prep'),
#   ('the', 'whale', 'det'),
#   ('great', 'whale', 'amod'),
#   ('whale', 'of', 'pobj'),
#   ('himself', 'whale', 'appos'),
#   ('.', 'was', 'punct')],
#  [('Such', 'monster', 'predet'),
#   ('a', 'monster', 'det'),
#   ('portentous', 'monster', 'amod'),
#   ('and', 'portentous', 'cc'),
#   ('mysterious', 'portentous', 'conj'),
#   ('monster', 'roused', 'nsubj'),
#   ('roused', 'roused', 'ROOT'),
#   ('all', 'curiosity', 'predet'),
#   ('my', 'curiosity', 'poss'),
#   ('curiosity', 'roused', 'dobj'),
#   ('.', 'roused', 'punct')],
#  [('Then', 'helped', 'advmod'),
#   ('the', 'seas', 'det'),
#   ('wild', 'seas', 'amod'),
#   ('and', 'wild', 'cc'),
#   ('distant', 'wild', 'conj'),
#   ('seas', 'Then', 'intj'),
#   ('where', 'rolled', 'advmod'),
#   ('he', 'rolled', 'nsubj'),
#   ('rolled', 'seas', 'relcl'),
#   ('his', 'bulk', 'poss'),
#   ('island', 'bulk', 'compound'),
#   ('bulk', 'rolled', 'dobj'),
#   (';', 'helped', 'punct'),
#   ('the', 'perils', 'det'),
#   ('undeliverable', 'perils', 'amod'),
#   (',', 'perils', 'punct'),
#   ('nameless', 'perils', 'compound'),
#   ('perils', 'helped', 'nsubj'),
#   ('of', 'perils', 'prep'),
#   ('the', 'whale', 'det'),
#   ('whale', 'of', 'pobj'),
#   (';', 'perils', 'punct'),
#   ('these', 'helped', 'nsubj'),
#   (',', 'helped', 'punct'),
#   ('with', 'helped', 'prep'),
#   ('all', 'marvels', 'predet'),
#   ('the', 'marvels', 'det'),
#   ('attending', 'marvels', 'amod'),
#   ('marvels', 'with', 'pobj'),
#   ('of', 'marvels', 'prep'),
#   ('a', 'thousand', 'quantmod'),
#   ('thousand', 'sights', 'nummod'),
#   ('Patagonian', 'sights', 'amod'),
#   ('sights', 'of', 'pobj'),
#   ('and', 'sights', 'cc'),
#   ('sounds', 'sights', 'conj'),
#   (',', 'helped', 'punct'),
#   ('helped', 'helped', 'ROOT'),
#   ('to', 'sway', 'aux'),
#   ('sway', 'helped', 'xcomp'),
#   ('me', 'sway', 'dobj'),
#   ('to', 'sway', 'prep'),
#   ('my', 'wish', 'poss'),
#   ('wish', 'to', 'pobj'),
#   ('.', 'helped', 'punct')],
#  [('With', 'been', 'prep'),
#   ('other', 'men', 'amod'),
#   ('men', 'With', 'pobj'),
#   (',', 'been', 'punct'),
#   ('perhaps', 'been', 'advmod'),
#   (',', 'been', 'punct'),
#   ('such', 'things', 'amod'),
#   ('things', 'been', 'nsubj'),
#   ('would', 'been', 'aux'),
#   ('not', 'been', 'neg'),
#   ('have', 'been', 'aux'),
#   ('been', 'been', 'ROOT'),
#   ('inducements', 'been', 'attr'),
#   (';', 'been', 'punct'),
#   ('but', 'been', 'cc'),
#   ('as', 'tormented', 'prep'),
#   ('for', 'as', 'prep'),
#   ('me', 'for', 'pobj'),
#   (',', 'tormented', 'punct'),
#   ('I', 'tormented', 'nsubjpass'),
#   ('am', 'tormented', 'auxpass'),
#   ('tormented', 'been', 'conj'),
#   ('with', 'tormented', 'prep'),
#   ('an', 'itch', 'det'),
#   ('everlasting', 'itch', 'amod'),
#   ('itch', 'with', 'pobj'),
#   ('for', 'itch', 'prep'),
#   ('things', 'for', 'pobj'),
#   ('remote', 'things', 'amod'),
#   ('.', 'tormented', 'punct')]]

# %% [markdown]
# Instead of doing this at a word-by-word basis, we can do it by larger chunks, the noun phrases.

# %%
[[(c.text, c.root.head.text, c.root.dep_) for c in nlp(sentence).noun_chunks] 
 for sentence in documents[:100]]
# Out:
# [[('Loomings', 'Loomings', 'ROOT')],
#  [('me', 'Call', 'dobj')],
#  [('little or no money', 'having', 'dobj'),
#   ('my purse', 'in', 'pobj'),
#   ('me', 'interest', 'dobj'),
#   ('shore', 'on', 'pobj'),
#   ('I', 'thought', 'nsubj'),
#   ('I', 'sail', 'nsubj'),
#   ('the watery part', 'see', 'dobj'),
#   ('the world', 'of', 'pobj')],
#  [('It', 'is', 'nsubj'),
#   ('a way', 'is', 'attr'),
#   ('I', 'have', 'nsubj'),
#   ('the spleen', 'driving', 'dobj'),
#   ('the circulation', 'regulating', 'dobj')],
#  [('I', 'find', 'nsubj'),
#   ('myself', 'growing', 'nsubj'),
#   ('the mouth', 'about', 'pobj'),
#   ('it', 'is', 'nsubj'),
#   ('a damp', 'is', 'attr'),
#   ('my soul', 'in', 'pobj'),
#   ('I', 'find', 'nsubj'),
#   ('myself', 'pausing', 'nsubj'),
#   ('coffin warehouses', 'before', 'pobj'),
#   ('the rear', 'bringing', 'dobj'),
#   ('every funeral', 'of', 'pobj'),
#   ('I', 'meet', 'nsubj'),
#   ('my hypos', 'get', 'nsubj'),
#   ('such an upper hand', 'get', 'dobj'),
#   ('me', 'of', 'pobj'),
#   ('it', 'requires', 'nsubj'),
#   ('a strong moral principle', 'requires', 'dobj'),
#   ('me', 'prevent', 'dobj'),
#   ('the street', 'into', 'pobj'),
#   ("people ' s hats", 'knocking', 'dobj'),
#   ('I', 'account', 'nsubj'),
#   ('it', 'account', 'dobj'),
#   ('sea', 'to', 'pobj'),
#   ('I', 'can', 'nsubj')],
#  [('my substitute', 'is', 'attr'),
#   ('pistol', 'for', 'pobj'),
#   ('ball', 'pistol', 'conj')],
#  [('Cato', 'throws', 'nsubj'),
#   ('himself', 'throws', 'dobj'),
#   ('his sword', 'upon', 'pobj'),
#   ('I', 'take', 'nsubj'),
#   ('the ship', 'to', 'pobj')],
#  [('nothing', 'is', 'attr')],
#  [('they', 'knew', 'nsubj'),
#   ('it', 'knew', 'dobj'),
#   ('almost all men', 'cherish', 'nsubj'),
#   ('their degree', 'in', 'pobj'),
#   ('some time', 'men', 'conj'),
#   ('very nearly the same feelings', 'cherish', 'dobj'),
#   ('the ocean', 'towards', 'pobj'),
#   ('me', 'with', 'pobj')],
#  [('your insular city', 'is', 'attr'),
#   ('the Manhattoes', 'of', 'pobj'),
#   ('wharves', 'by', 'pobj'),
#   ('Indian isles', 'as', 'pobj'),
#   ('coral reefs', 'by', 'pobj'),
#   ('commerce', 'surrounds', 'nsubj'),
#   ('it', 'surrounds', 'dobj'),
#   ('her surf', 'with', 'pobj')],
#  [('the streets', 'take', 'nsubj'), ('you', 'take', 'dobj')],
#  [('Its extreme downtown', 'is', 'nsubj'),
#   ('the battery', 'is', 'attr'),
#   ('that noble mole', 'washed', 'nsubjpass'),
#   ('waves', 'by', 'pobj'),
#   ('breezes', 'by', 'pobj'),
#   ('sight', 'of', 'pobj'),
#   ('land', 'of', 'pobj')],
#  [('the crowds', 'at', 'pobj'), ('water - gazers', 'of', 'pobj')],
#  [('the city', 'Circumambulate', 'dobj')],
#  [('Corlears Hook', 'from', 'pobj'),
#   ('thence', 'from', 'pobj'),
#   ('Whitehall', 'by', 'pobj')],
#  [('What', 'see', 'dobj'),
#   ('you', 'see', 'nsubj'),
#   ('silent sentinels', 'like', 'pobj'),
#   ('the town', 'around', 'pobj'),
#   ('thousands', 'upon', 'pobj'),
#   ('mortal men', 'of', 'pobj'),
#   ('ocean reveries', 'in', 'pobj')],
#  [('the spiles', 'against', 'pobj'),
#   ('the pier - heads', 'upon', 'pobj'),
#   ('the bulwarks', 'over', 'pobj'),
#   ('ships', 'of', 'pobj'),
#   ('China', 'from', 'pobj'),
#   ('the rigging', 'in', 'pobj'),
#   ('a still better seaward peep', 'get', 'dobj')],
#  [('landsmen', 'are', 'attr'),
#   ('week days', 'of', 'pobj'),
#   ('lath', 'in', 'pobj'),
#   ('plaster', 'lath', 'conj'),
#   ('counters', 'to', 'pobj'),
#   ('benches', 'to', 'pobj'),
#   ('desks', 'to', 'pobj')],
#  [],
#  [('the green fields', 'gone', 'nsubj')],
#  [('What', 'do', 'nsubj'), ('they', 'do', 'nsubj')],
#  [],
#  [('more crowds', 'come', 'nsubj'),
#   ('the water', 'for', 'pobj'),
#   ('a dive', 'for', 'pobj')],
#  [],
#  [('Nothing', 'content', 'nsubj'),
#   ('them', 'content', 'dobj'),
#   ('the extremest limit', 'suffice', 'nsubj'),
#   ('the land', 'of', 'pobj'),
#   ('the shady lee', 'under', 'pobj'),
#   ('yonder warehouses', 'of', 'pobj')],
#  [],
#  [('They', 'get', 'nsubj'),
#   ('just as nigh the water', 'get', 'dobj'),
#   ('they', 'can', 'nsubj')],
#  [('they', 'stand', 'nsubj'), ('them', 'of', 'pobj')],
#  [('they', 'come', 'nsubj'),
#   ('lanes', 'from', 'pobj'),
#   ('alleys', 'lanes', 'conj'),
#   ('streets', 'lanes', 'conj'),
#   ('avenues', 'streets', 'conj'),
#   ('north', 'lanes', 'appos'),
#   ('east', 'north', 'conj'),
#   ('south', 'east', 'conj'),
#   ('west', 'south', 'conj')],
#  [('they', 'unite', 'nsubj')],
#  [('me', 'Tell', 'dobj'),
#   ('the magnetic virtue', 'attract', 'nsubj'),
#   ('the needles', 'of', 'pobj'),
#   ('the compasses', 'of', 'pobj'),
#   ('all those ships', 'of', 'pobj'),
#   ('them', 'attract', 'dobj')],
#  [],
#  [('you', 'are', 'nsubj'),
#   ('the country', 'in', 'pobj'),
#   ('some high land', 'in', 'pobj'),
#   ('lakes', 'of', 'pobj')],
#  [('almost any path', 'Take', 'dobj'),
#   ('you', 'please', 'nsubj'),
#   ('it', 'carries', 'nsubj'),
#   ('you', 'carries', 'dobj'),
#   ('a dale', 'in', 'pobj'),
#   ('you', 'leaves', 'dobj'),
#   ('a pool', 'by', 'pobj'),
#   ('the stream', 'in', 'pobj')],
#  [('magic', 'is', 'attr'), ('it', 'in', 'pobj')],
#  [('men', 'of', 'pobj'),
#   ('his deepest reveries', 'in', 'pobj'),
#   ('that man', 'set', 'nsubj'),
#   ('his legs', 'on', 'pobj'),
#   ('his feet', 'set', 'dobj'),
#   ('a - going', 'set', 'dobj'),
#   ('he', 'lead', 'nsubj'),
#   ('you', 'lead', 'dobj'),
#   ('water', 'to', 'pobj'),
#   ('water', 'be', 'nsubj'),
#   ('all that region', 'in', 'pobj')],
#  [('you', 'be', 'nsubj'),
#   ('the great American desert', 'in', 'pobj'),
#   ('this experiment', 'try', 'dobj'),
#   ('your caravan', 'happen', 'nsubj'),
#   ('a metaphysical professor', 'with', 'pobj')],
#  [('every one', 'knows', 'nsubj'),
#   ('meditation', 'wedded', 'nsubjpass'),
#   ('water', 'meditation', 'conj')],
#  [('an artist', 'is', 'attr')],
#  [('He', 'desires', 'nsubj'),
#   ('you', 'paint', 'dative'),
#   ('the dreamiest , shadiest , quietest , most enchanting bit',
#    'paint',
#    'dobj'),
#   ('romantic landscape', 'of', 'pobj'),
#   ('all the valley', 'in', 'pobj'),
#   ('the Saco', 'of', 'pobj')],
#  [('What', 'is', 'attr'),
#   ('the chief element', 'is', 'nsubj'),
#   ('he', 'employs', 'nsubj')],
#  [('his trees', 'stand', 'dobj'),
#   ('a hollow trunk', 'with', 'pobj'),
#   ('a hermit', 'were', 'nsubj'),
#   ('a crucifix', 'hermit', 'conj'),
#   ('his meadow', 'sleeps', 'dobj'),
#   ('his cattle', 'sleep', 'dobj'),
#   ('yonder cottage', 'from', 'pobj'),
#   ('a sleepy smoke', 'goes', 'dobj')],
#  [('distant woodlands', 'into', 'pobj'),
#   ('overlapping spurs', 'to', 'pobj'),
#   ('mountains', 'of', 'pobj'),
#   ('their hill - side blue', 'in', 'pobj')],
#  [('the picture', 'lies', 'nsubj'),
#   ('this pine - tree', 'shakes', 'nsubj'),
#   ('its sighs', 'shakes', 'dobj'),
#   ('leaves', 'like', 'pobj'),
#   ("this shepherd ' s head", 'upon', 'pobj'),
#   ("the shepherd ' s eye", 'fixed', 'nsubjpass'),
#   ('the magic stream', 'upon', 'pobj'),
#   ('him', 'before', 'pobj')],
#  [('the Prairies', 'visit', 'dobj'),
#   ('June', 'in', 'pobj'),
#   ('scores', 'for', 'pobj'),
#   ('scores', 'on', 'pobj'),
#   ('miles', 'of', 'pobj'),
#   ('you', 'wade', 'nsubj'),
#   ('Tiger - lilies', 'among', 'pobj'),
#   ('what', 'is', 'attr'),
#   ('a drop', 'is', 'attr'),
#   ('water', 'of', 'pobj')],
#  [('Niagara', 'Were', 'nsubj'),
#   ('a cataract', 'Niagara', 'conj'),
#   ('sand', 'of', 'pobj'),
#   ('you', 'travel', 'nsubj'),
#   ('your thousand miles', 'travel', 'dobj'),
#   ('it', 'see', 'dobj')],
#  [('the poor poet', 'deliberate', 'nsubj'),
#   ('Tennessee', 'of', 'pobj'),
#   ('two handfuls', 'receiving', 'dobj'),
#   ('silver', 'of', 'pobj'),
#   ('him', 'buy', 'dative'),
#   ('a coat', 'buy', 'dobj'),
#   ('he', 'needed', 'nsubj'),
#   ('his money', 'invest', 'dobj'),
#   ('a pedestrian trip', 'in', 'pobj'),
#   ('Rockaway Beach', 'to', 'pobj')],
#  [('almost every robust healthy boy', 'is', 'attr'),
#   ('a robust healthy soul', 'with', 'pobj'),
#   ('him', 'in', 'pobj'),
#   ('some time', 'at', 'pobj'),
#   ('sea', 'to', 'pobj')],
#  [('your first voyage', 'upon', 'pobj'),
#   ('a passenger', 'as', 'pobj'),
#   ('you', 'feel', 'nsubj'),
#   ('yourself', 'you', 'appos'),
#   ('such a mystical vibration', 'feel', 'dobj'),
#   ('you', 'were', 'nsubj'),
#   ('your ship', 'you', 'conj'),
#   ('sight', 'of', 'pobj'),
#   ('land', 'of', 'pobj')],
#  [('the old Persians', 'hold', 'nsubj'), ('the sea', 'hold', 'dobj')],
#  [('the Greeks', 'give', 'nsubj'),
#   ('it', 'give', 'dative'),
#   ('a separate deity', 'give', 'dobj'),
#   ('brother', 'own', 'dobj'),
#   ('Jove', 'of', 'pobj')],
#  [],
#  [('the meaning', 'deeper', 'dobj'),
#   ('that story', 'of', 'pobj'),
#   ('Narcissus', 'of', 'pobj'),
#   ('who', 'grasp', 'nsubj'),
#   ('he', 'grasp', 'nsubj'),
#   ('the tormenting', 'grasp', 'dobj'),
#   ('mild image', 'story', 'appos'),
#   ('he', 'saw', 'nsubj'),
#   ('the fountain', 'in', 'pobj'),
#   ('it', 'into', 'pobj')],
#  [('we', 'see', 'nsubj'),
#   ('ourselves', 'we', 'appos'),
#   ('all rivers', 'in', 'pobj'),
#   ('oceans', 'rivers', 'conj')],
#  [('It', 'is', 'nsubj'),
#   ('the image', 'is', 'attr'),
#   ('the ungraspable phantom', 'of', 'pobj'),
#   ('life', 'of', 'pobj'),
#   ('the key', 'is', 'attr'),
#   ('it', 'to', 'pobj')],
#  [('I', 'say', 'nsubj'),
#   ('I', 'am', 'nsubj'),
#   ('the habit', 'in', 'pobj'),
#   ('sea', 'to', 'pobj'),
#   ('I', 'begin', 'nsubj'),
#   ('the eyes', 'about', 'pobj'),
#   ('my lungs', 'of', 'pobj'),
#   ('I', 'mean', 'nsubj'),
#   ('it', 'inferred', 'nsubj'),
#   ('I', 'go', 'nsubj'),
#   ('sea', 'to', 'pobj'),
#   ('a passenger', 'as', 'pobj')],
#  [('a passenger', 'as', 'pobj'),
#   ('you', 'needs', 'nsubj'),
#   ('a purse', 'have', 'dobj'),
#   ('a purse', 'is', 'nsubj'),
#   ('a rag', 'is', 'conj'),
#   ('you', 'have', 'nsubj'),
#   ('something', 'have', 'dobj'),
#   ('it', 'in', 'pobj')],
#  [('passengers', 'get', 'nsubj'),
#   ('sea - sick -- grow quarrelsome', 'get', 'dobj'),
#   ("don ' t sleep", 'quarrelsome', 'appos'),
#   ('nights', 'of', 'pobj'),
#   ('themselves', 'enjoy', 'dobj'),
#   ('a general thing', 'as', 'pobj'),
#   ('I', 'go', 'nsubj'),
#   ('a passenger', 'as', 'pobj'),
#   ('I', 'am', 'nsubj'),
#   ('something', 'am', 'attr'),
#   ('a salt', 'of', 'pobj'),
#   ('I', 'go', 'nsubj'),
#   ('sea', 'to', 'pobj'),
#   ('a Commodore', 'as', 'pobj'),
#   ('a Captain', 'Commodore', 'conj'),
#   ('a Cook', 'Captain', 'conj')],
#  [('I', 'abandon', 'nsubj'),
#   ('the glory', 'abandon', 'dobj'),
#   ('distinction', 'glory', 'conj'),
#   ('such offices', 'of', 'pobj'),
#   ('who', 'like', 'nsubj'),
#   ('them', 'like', 'dobj')],
#  [('my part', 'For', 'pobj'),
#   ('I', 'abominate', 'nsubj'),
#   ('all honourable respectable toils', 'abominate', 'dobj'),
#   ('trials', 'toils', 'conj'),
#   ('tribulations', 'trials', 'conj'),
#   ('every kind', 'of', 'pobj')],
#  [('It', 'is', 'nsubj'),
#   ('I', 'do', 'nsubj'),
#   ('care', 'take', 'dobj'),
#   ('myself', 'of', 'pobj'),
#   ('care', 'taking', 'dobj'),
#   ('ships', 'of', 'pobj'),
#   ('barques', 'ships', 'conj'),
#   ('brigs', 'barques', 'conj'),
#   ('schooners', 'brigs', 'conj'),
#   ('what', 'schooners', 'conj')],
#  [('as cook', 'going', 'dobj'),
#   ('I', 'confess', 'nsubj'),
#   ('considerable glory', 'is', 'attr'),
#   ('a cook', 'being', 'nsubj'),
#   ('a sort', 'being', 'attr'),
#   ('officer', 'of', 'pobj'),
#   ('ship - board', 'on', 'pobj'),
#   ('I', 'fancied', 'nsubj'),
#   ('broiling fowls', 'fancied', 'dobj'),
#   ('no one', 'is', 'attr'),
#   ('who', 'speak', 'nsubj'),
#   ('a broiled fowl', 'of', 'pobj'),
#   ('I', 'will', 'nsubj')],
#  [('It', 'is', 'nsubj'),
#   ('the idolatrous dotings', 'of', 'pobj'),
#   ('the old Egyptians', 'of', 'pobj'),
#   ('broiled ibis and roasted river horse', 'upon', 'pobj'),
#   ('you', 'see', 'nsubj'),
#   ('the mummies', 'see', 'dobj'),
#   ('those creatures', 'of', 'pobj'),
#   ('their huge bake - houses', 'in', 'pobj'),
#   ('the pyramids', 'in', 'pobj')],
#  [('I', 'go', 'nsubj'),
#   ('sea', 'to', 'pobj'),
#   ('I', 'go', 'nsubj'),
#   ('a simple sailor', 'as', 'pobj'),
#   ('the mast', 'before', 'pobj'),
#   ('the forecastle', 'into', 'pobj'),
#   ('the royal mast - head', 'to', 'pobj')],
#  [('they', 'order', 'nsubj'),
#   ('me', 'order', 'dobj'),
#   ('me', 'jump', 'nsubj'),
#   ('spar', 'to', 'pobj'),
#   ('a grasshopper', 'like', 'pobj'),
#   ('a May meadow', 'in', 'pobj')],
#  [('this sort', 'is', 'nsubj'), ('thing', 'of', 'pobj')],
#  [('It', 'touches', 'nsubj'),
#   ("one ' s sense", 'touches', 'dobj'),
#   ('honour', 'of', 'pobj'),
#   ('you', 'come', 'nsubj'),
#   ('an old established family', 'of', 'pobj'),
#   ('the land', 'in', 'pobj'),
#   ('the Van Rensselaers', 'family', 'conj'),
#   ('Randolphs', 'Rensselaers', 'conj'),
#   ('Hardicanutes', 'Randolphs', 'conj')],
#  [('your hand', 'putting', 'dobj'),
#   ('the tar - pot', 'into', 'pobj'),
#   ('you', 'lording', 'nsubj'),
#   ('it', 'lording', 'dobj'),
#   ('a country schoolmaster', 'as', 'pobj'),
#   ('the tallest boys', 'stand', 'nsubj'),
#   ('awe', 'in', 'pobj'),
#   ('you', 'of', 'pobj')],
#  [('The transition', 'is', 'nsubj'),
#   ('a keen one', 'is', 'attr'),
#   ('I', 'assure', 'nsubj'),
#   ('you', 'assure', 'dobj'),
#   ('a schoolmaster', 'from', 'pobj'),
#   ('a sailor', 'to', 'pobj'),
#   ('a strong decoction', 'requires', 'dobj'),
#   ('Seneca', 'of', 'pobj'),
#   ('the Stoics', 'Seneca', 'conj'),
#   ('you', 'enable', 'dobj'),
#   ('it', 'bear', 'dobj')],
#  [('time', 'in', 'pobj')],
#  [('What', 'What', 'ROOT'),
#   ('it', 'of', 'pobj'),
#   ('some old hunks', 'get', 'nsubj'),
#   ('me', 'orders', 'dobj'),
#   ('a broom', 'get', 'dobj'),
#   ('the decks', 'sweep', 'dobj')],
#  [('What', 'What', 'ROOT'),
#   ('that indignity amount', 'does', 'dobj'),
#   ('I', 'mean', 'nsubj'),
#   ('the scales', 'in', 'pobj'),
#   ('the New Testament', 'of', 'pobj')],
#  [('you', 'think', 'nsubj'),
#   ('the archangel', 'thinks', 'nsubj'),
#   ('Gabriel', 'archangel', 'appos'),
#   ('anything', 'less', 'nsubj'),
#   ('me', 'of', 'pobj'),
#   ('I', 'obey', 'nsubj'),
#   ('that old hunks', 'obey', 'dobj'),
#   ('that particular instance', 'in', 'pobj')],
#  [('Who', 'Who', 'ROOT'), ('a slave', 't', 'dobj')],
#  [('me', 'Tell', 'dobj')],
#  [('the old sea - captains', 'order', 'nsubj'),
#   ('me', 'order', 'dobj'),
#   ('they', 'thump', 'nsubj'),
#   ('me', 'punch', 'dobj'),
#   ('I', 'have', 'nsubj'),
#   ('the satisfaction', 'have', 'dobj'),
#   ('it', 'is', 'nsubj'),
#   ('everybody', 'is', 'nsubj'),
#   ('one way', 'is', 'attr'),
#   ('a physical or metaphysical point', 'in', 'pobj'),
#   ('view', 'of', 'pobj'),
#   ('the universal thump', 'passed', 'nsubjpass'),
#   ('all hands', 'rub', 'nsubj'),
#   ("each other ' s shoulder - blades", 'rub', 'dobj')],
#  [('I', 'go', 'nsubj'),
#   ('sea', 'to', 'pobj'),
#   ('a sailor', 'as', 'pobj'),
#   ('they', 'make', 'nsubj'),
#   ('a point', 'make', 'dobj'),
#   ('me', 'paying', 'dobj'),
#   ('my trouble', 'for', 'pobj'),
#   ('they', 'pay', 'nsubj'),
#   ('passengers', 'pay', 'dative'),
#   ('a single penny', 'pay', 'dobj'),
#   ('I', 'heard', 'nsubj')],
#  [('the contrary', 'On', 'pobj'),
#   ('passengers', 'pay', 'nsubj'),
#   ('themselves', 'passengers', 'appos')],
#  [('all the difference', 'is', 'attr'), ('the world', 'in', 'pobj')],
#  [('The act', 'is', 'nsubj'),
#   ('the most uncomfortable infliction', 'is', 'attr'),
#   ('the two orchard thieves', 'entailed', 'nsubj'),
#   ('us', 'upon', 'pobj')],
#  [('But BEING PAID', 'PAID', 'ROOT'),
#   ('what', 'compare', 'nsubj'),
#   ('it', 'with', 'pobj')],
#  [('The urbane activity', 'is', 'nsubj'),
#   ('a man', 'receives', 'nsubj'),
#   ('money', 'receives', 'dobj'),
#   ('we', 'believe', 'nsubj'),
#   ('money', 'be', 'nsubj'),
#   ('the root', 'be', 'attr'),
#   ('all earthly ills', 'of', 'pobj'),
#   ('no account', 'on', 'pobj'),
#   ('a monied man', 'enter', 'nsubj'),
#   ('heaven', 'enter', 'dobj')],
#  [],
#  [('we', 'consign', 'nsubj'),
#   ('ourselves', 'consign', 'dobj'),
#   ('perdition', 'to', 'pobj')],
#  [('I', 'go', 'nsubj'),
#   ('sea', 'to', 'pobj'),
#   ('a sailor', 'as', 'pobj'),
#   ('the wholesome exercise', 'because', 'pobj'),
#   ('pure air', 'exercise', 'conj'),
#   ('the fore - castle deck', 'of', 'pobj')],
#  [('this world', 'in', 'pobj'),
#   ('head winds', 'are', 'nsubj'),
#   ('winds', 'than', 'pobj'),
#   ('you', 'violate', 'nsubj'),
#   ('the Pythagorean maxim', 'violate', 'dobj'),
#   ('the most part', 'for', 'pobj'),
#   ('the Commodore', 'part', 'appos'),
#   ('the quarter - deck', 'on', 'pobj'),
#   ('his atmosphere', 'gets', 'dobj'),
#   ('second hand', 'at', 'pobj'),
#   ('the sailors', 'from', 'pobj'),
#   ('the forecastle', 'on', 'pobj')],
#  [('He', 'thinks', 'nsubj'),
#   ('he', 'breathes', 'nsubj'),
#   ('it', 'breathes', 'dobj')],
#  [('the same way', 'In', 'pobj'),
#   ('the commonalty', 'lead', 'nsubj'),
#   ('their leaders', 'lead', 'dobj'),
#   ('many other things', 'in', 'pobj'),
#   ('the same time', 'at', 'pobj'),
#   ('the leaders', 'suspect', 'nsubj'),
#   ('it', 'suspect', 'dobj')],
#  [('it', 'was', 'nsubj'),
#   ('the sea', 'smelt', 'dobj'),
#   ('a merchant sailor', 'as', 'pobj'),
#   ('I', 'take', 'nsubj'),
#   ('it', 'take', 'dobj'),
#   ('my head', 'into', 'pobj'),
#   ('a whaling voyage', 'on', 'pobj'),
#   ('this the invisible police officer', 'answer', 'nsubj'),
#   ('the Fates', 'of', 'pobj'),
#   ('who', 'has', 'nsubj'),
#   ('the constant surveillance', 'has', 'dobj'),
#   ('me', 'of', 'pobj'),
#   ('me', 'dogs', 'dobj'),
#   ('me', 'influences', 'dobj'),
#   ('some unaccountable way', 'in', 'pobj'),
#   ('he', 'answer', 'nsubj'),
#   ('any one', 'than', 'pobj')],
#  [('this whaling voyage', 'on', 'pobj'),
#   ('part', 'formed', 'dobj'),
#   ('the grand programme', 'of', 'pobj'),
#   ('Providence', 'of', 'pobj')],
#  [('It', 'came', 'nsubj'),
#   ('a sort', 'as', 'pobj'),
#   ('brief interlude', 'of', 'pobj'),
#   ('solo', 'interlude', 'conj'),
#   ('more extensive performances', 'between', 'pobj')],
#  [('I', 'take', 'nsubj'),
#   ('it', 'take', 'dobj'),
#   ('this part', 'run', 'nsubj'),
#   ('the bill', 'of', 'pobj'),
#   ('something', 'run', 'dobj')],
#  [('" GRAND CONTESTED ELECTION', 'ELECTION', 'ROOT'),
#   ('THE PRESIDENCY', 'FOR', 'pobj'),
#   ('THE UNITED STATES', 'OF', 'pobj')],
#  [('" WHALING', 'WHALING', 'ROOT'),
#   ('VOYAGE', 'WHALING', 'dobj'),
#   ('ONE ISHMAEL', 'BY', 'pobj')],
#  [('" BLOODY BATTLE', 'BATTLE', 'ROOT'), ('AFFGHANISTAN', 'IN', 'pobj')],
#  [('I', 'tell', 'nsubj'),
#   ('it', 'was', 'nsubj'),
#   ('those stage managers', 'put', 'nsubj'),
#   ('the Fates', 'managers', 'appos'),
#   ('me', 'put', 'dobj'),
#   ('this shabby part', 'for', 'pobj'),
#   ('a whaling voyage', 'of', 'pobj'),
#   ('others', 'set', 'nsubjpass'),
#   ('magnificent parts', 'for', 'pobj'),
#   ('high tragedies', 'in', 'pobj'),
#   ('genteel comedies', 'in', 'pobj'),
#   ('farces', 'in', 'pobj'),
#   ('I', 'tell', 'nsubj'),
#   ('I', 'recall', 'nsubj'),
#   ('all the circumstances', 'recall', 'dobj'),
#   ('I', 'think', 'nsubj'),
#   ('I', 'see', 'nsubj'),
#   ('the springs', 'into', 'pobj'),
#   ('motives', 'springs', 'conj'),
#   ('me', 'to', 'pobj'),
#   ('various disguises', 'under', 'pobj'),
#   ('me', 'induced', 'dobj'),
#   ('the part', 'performing', 'dobj'),
#   ('I', 'did', 'nsubj'),
#   ('me', 'cajoling', 'dobj'),
#   ('the delusion', 'into', 'pobj'),
#   ('it', 'was', 'nsubj'),
#   ('a choice', 'was', 'attr'),
#   ('my own unbiased freewill', 'from', 'pobj'),
#   ('judgment', 'discriminating', 'dobj')],
#  [('Chief', 'was', 'nsubj'),
#   ('these motives', 'among', 'pobj'),
#   ('the overwhelming idea', 'was', 'attr'),
#   ('the great whale', 'of', 'pobj'),
#   ('himself', 'whale', 'appos')],
#  [('Such a portentous and mysterious monster', 'roused', 'nsubj'),
#   ('all my curiosity', 'roused', 'dobj')],
#  [('he', 'rolled', 'nsubj'),
#   ('his island bulk', 'rolled', 'dobj'),
#   ('the undeliverable , nameless perils', 'helped', 'nsubj'),
#   ('the whale', 'of', 'pobj'),
#   ('all the attending marvels', 'with', 'pobj'),
#   ('a thousand Patagonian sights', 'of', 'pobj'),
#   ('sounds', 'sights', 'conj'),
#   ('me', 'sway', 'dobj'),
#   ('my wish', 'to', 'pobj')],
#  [('other men', 'With', 'pobj'),
#   ('such things', 'been', 'nsubj'),
#   ('inducements', 'been', 'attr'),
#   ('me', 'for', 'pobj'),
#   ('I', 'tormented', 'nsubjpass'),
#   ('an everlasting itch', 'with', 'pobj'),
#   ('things', 'for', 'pobj')]]

# %% [markdown]
# ## Exercise
# How does Melville describe nouns? Extract all the pairs related by `amod`.

# %%
# your code here
